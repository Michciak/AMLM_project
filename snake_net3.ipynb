# %%
import pygame
import random
import numpy as np

class SnakeGameAI:
    def __init__(self, width=640, height=480, snake_size=20):
        self.width = width
        self.height = height
        self.snake_size = snake_size
        self.reset()

    def reset(self):
        self.x1 = self.width / 2
        self.y1 = self.height / 2
        self.x1_change = 0
        self.y1_change = 0
        self.snake_List = []
        self.Length_of_snake = 1
        self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
        self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
        self.score = 0
        return self.get_state()

    def step(self, action):
        if action == 0:  # LEFT
            self.x1_change = -self.snake_size
            self.y1_change = 0
        elif action == 1:  # RIGHT
            self.x1_change = self.snake_size
            self.y1_change = 0
        elif action == 2:  # UP
            self.y1_change = -self.snake_size
            self.x1_change = 0
        elif action == 3:  # DOWN
            self.y1_change = self.snake_size
            self.x1_change = 0

        self.x1 += self.x1_change
        self.y1 += self.y1_change

        done = self.x1 >= self.width or self.x1 < 0 or self.y1 >= self.height or self.y1 < 0
        snake_Head = [self.x1, self.y1]
        self.snake_List.append(snake_Head)
        if len(self.snake_List) > self.Length_of_snake:
            del self.snake_List[0]

        for x in self.snake_List[:-1]:
            if x == snake_Head:
                done = True

        reward = 0
        if self.x1 == self.foodx and self.y1 == self.foody:
            self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
            self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
            self.Length_of_snake += 1
            reward = 10
            self.score += 1

        if done:
            reward = -10

        state = self.get_state()
        return state, reward, done

    def get_state(self):
        state = [
            self.x1, self.y1, self.foodx, self.foody,
            self.x1_change, self.y1_change,
        ]
        return np.array(state, dtype=np.float32)

    def render(self):
        window = pygame.display.set_mode((self.width, self.height))
        window.fill((0, 0, 0))
        for segment in self.snake_List:
            pygame.draw.rect(window, (0, 255, 0), [segment[0], segment[1], self.snake_size, self.snake_size])
        pygame.draw.rect(window, (255, 255, 255), [self.foodx, self.foody, self.snake_size, self.snake_size])
        pygame.display.update()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LSTMSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.hidden_size).to(device),
                torch.zeros(1, batch_size, self.hidden_size).to(device))

class RNNSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.rnn(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class GRUSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GRUSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.gru(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class DQNAgent:
    def __init__(self, state_size, action_size, hidden_size, model_type='LSTM'):
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        
        if model_type == 'RNN':
            self.model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
        elif model_type == 'GRU':
            self.model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
        else:  # Default to LSTM
            self.model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)

        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state, hidden):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size), hidden
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        action_values, hidden = self.model(state, hidden)
        return torch.argmax(action_values[0]).item(), hidden

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
            next_state = torch.FloatTensor(next_state).unsqueeze(0).unsqueeze(0).to(device)
            target = reward
            if not done:
                next_hidden = self.model.init_hidden(1)
                target = (reward + self.gamma * torch.max(self.model(next_state, next_hidden)[0][0])).item()
            target_f = self.model(state, self.model.init_hidden(1))[0]
            target_f[0][action] = target
            self.optimizer.zero_grad()
            loss = self.criterion(target_f, self.model(state, self.model.init_hidden(1))[0])
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import time
import pygame

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LSTMSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.hidden_size).to(device),
                torch.zeros(1, batch_size, self.hidden_size).to(device))

class RNNSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.rnn(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class GRUSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GRUSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.gru(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class DQNAgent:
    def __init__(self, state_size, action_size, hidden_size, model_type='LSTM'):
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        
        if model_type == 'RNN':
            self.model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
        elif model_type == 'GRU':
            self.model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
        else:  # Default to LSTM
            self.model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)

        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state, hidden):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size), hidden
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        action_values, hidden = self.model(state, hidden)
        return torch.argmax(action_values[0]).item(), hidden

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
            next_state = torch.FloatTensor(next_state).unsqueeze(0).unsqueeze(0).to(device)
            target = reward
            if not done:
                next_hidden = self.model.init_hidden(1)
                target = (reward + self.gamma * torch.max(self.model(next_state, next_hidden)[0][0])).item()
            target_f = self.model(state, self.model.init_hidden(1))[0]
            target_f[0][action] = target
            self.optimizer.zero_grad()
            loss = self.criterion(target_f, self.model(state, self.model.init_hidden(1))[0])
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

class SnakeGameAI:
    def __init__(self, width=640, height=480, snake_size=20):
        self.width = width
        self.height = height
        self.snake_size = snake_size
        self.reset()

    def reset(self):
        self.x1 = self.width / 2
        self.y1 = self.height / 2
        self.x1_change = 0
        self.y1_change = 0
        self.snake_List = []
        self.Length_of_snake = 1
        self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
        self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
        self.score = 0
        return self.get_state()

    def step(self, action):
        if action == 0:  # LEFT
            self.x1_change = -self.snake_size
            self.y1_change = 0
        elif action == 1:  # RIGHT
            self.x1_change = self.snake_size
            self.y1_change = 0
        elif action == 2:  # UP
            self.y1_change = -self.snake_size
            self.x1_change = 0
        elif action == 3:  # DOWN
            self.y1_change = self.snake_size
            self.x1_change = 0

        self.x1 += self.x1_change
        self.y1 += self.y1_change

        done = self.x1 >= self.width or self.x1 < 0 or self.y1 >= self.height or self.y1 < 0
        snake_Head = [self.x1, self.y1]
        self.snake_List.append(snake_Head)
        if len(self.snake_List) > self.Length_of_snake:
            del self.snake_List[0]

        for x in self.snake_List[:-1]:
            if x == snake_Head:
                done = True

        reward = 0
        if self.x1 == self.foodx and self.y1 == self.foody:
            self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
            self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
            self.Length_of_snake += 1
            reward = 10
            self.score += 1

        if done:
            reward = -10

        state = self.get_state()
        return state, reward, done

    def get_state(self):
        state = [
            self.x1, self.y1, self.foodx, self.foody,
            self.x1_change, self.y1_change,
        ]
        return np.array(state, dtype=np.float32)

    def render(self):
        window = pygame.display.set_mode((self.width, self.height))
        window.fill((0, 0, 0))
        for segment in self.snake_List:
            pygame.draw.rect(window, (0, 255, 0), [segment[0], segment[1], self.snake_size, self.snake_size])
        pygame.draw.rect(window, (255, 255, 255), [self.foodx, self.foody, self.snake_size, self.snake_size])
        pygame.display.update()

def train_until_achieve_score(model_type, target_score=10):
    state_size = 6
    hidden_size = 64
    action_size = 4
    batch_size = 32

    agent = DQNAgent(state_size, action_size, hidden_size, model_type=model_type)
    game = SnakeGameAI()
    episode = 0

    start_time = time.time()

    while True:
        episode += 1
        state = game.reset()
        hidden = agent.model.init_hidden(1)
        for time_step in range(500):
            action, hidden = agent.act(state, hidden)
            next_state, reward, done = game.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                print(f"Episode: {episode}, Score: {game.score}, Epsilon: {agent.epsilon:.2}")
                break
            if len(agent.memory) > batch_size:
                agent.replay(batch_size)
        if episode % 1000 == 0:
            torch.save(agent.model.state_dict(), f"{model_type.lower()}_snake_model_{episode}.pth")
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Saved model at episode {episode}")
            print(f"Training time for {model_type} after {episode} episodes: {elapsed_time:.2f} seconds")
            start_time = time.time()
        if game.score >= target_score:
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Model {model_type} achieved a score of {target_score} in episode {episode}")
            print(f"Training time for {model_type}: {elapsed_time:.2f} seconds")
            break

    torch.save(agent.model.state_dict(), f"{model_type.lower()}_snake_model_final.pth")

if __name__ == "__main__":
    for model_type in ['RNN', 'GRU', 'LSTM']:
        train_until_achieve_score(model_type)
# Out:
# Episode: 1, Score: 0, Epsilon: 0.61
# Episode: 2, Score: 0, Epsilon: 0.15
# Episode: 3, Score: 1, Epsilon: 0.1
# Episode: 4, Score: 0, Epsilon: 0.039
# Episode: 5, Score: 0, Epsilon: 0.028
# Episode: 6, Score: 1, Epsilon: 0.016
# Episode: 7, Score: 0, Epsilon: 0.012
# Episode: 8, Score: 1, Epsilon: 0.01
# Episode: 9, Score: 0, Epsilon: 0.01
# Episode: 10, Score: 0, Epsilon: 0.01
# Episode: 11, Score: 0, Epsilon: 0.01
# Episode: 12, Score: 0, Epsilon: 0.01
# Episode: 13, Score: 0, Epsilon: 0.01
# Episode: 14, Score: 0, Epsilon: 0.01
# Episode: 15, Score: 1, Epsilon: 0.01
# Episode: 16, Score: 0, Epsilon: 0.01
# Episode: 17, Score: 0, Epsilon: 0.01
# Episode: 18, Score: 0, Epsilon: 0.01
# Episode: 19, Score: 0, Epsilon: 0.01
# Episode: 20, Score: 0, Epsilon: 0.01
# Episode: 21, Score: 0, Epsilon: 0.01
# Episode: 22, Score: 0, Epsilon: 0.01
# Episode: 23, Score: 0, Epsilon: 0.01
# Episode: 24, Score: 0, Epsilon: 0.01
# Episode: 25, Score: 0, Epsilon: 0.01
# Episode: 26, Score: 0, Epsilon: 0.01
# Episode: 27, Score: 0, Epsilon: 0.01
# Episode: 28, Score: 0, Epsilon: 0.01
# Episode: 29, Score: 0, Epsilon: 0.01
# Episode: 30, Score: 0, Epsilon: 0.01
# Episode: 31, Score: 0, Epsilon: 0.01
# Episode: 32, Score: 0, Epsilon: 0.01
# Episode: 33, Score: 0, Epsilon: 0.01
# Episode: 35, Score: 0, Epsilon: 0.01
# Episode: 36, Score: 1, Epsilon: 0.01
# Episode: 37, Score: 0, Epsilon: 0.01
# Episode: 38, Score: 0, Epsilon: 0.01
# Episode: 39, Score: 0, Epsilon: 0.01
# Episode: 40, Score: 0, Epsilon: 0.01
# Episode: 41, Score: 0, Epsilon: 0.01
# Episode: 42, Score: 0, Epsilon: 0.01
# Episode: 43, Score: 0, Epsilon: 0.01
# Episode: 44, Score: 0, Epsilon: 0.01
# Episode: 45, Score: 0, Epsilon: 0.01
# Episode: 46, Score: 1, Epsilon: 0.01
# Episode: 47, Score: 0, Epsilon: 0.01
# Episode: 48, Score: 0, Epsilon: 0.01
# Episode: 49, Score: 0, Epsilon: 0.01
# Episode: 50, Score: 0, Epsilon: 0.01
# Episode: 51, Score: 0, Epsilon: 0.01
# Episode: 53, Score: 0, Epsilon: 0.01
# Episode: 54, Score: 1, Epsilon: 0.01
# Episode: 55, Score: 0, Epsilon: 0.01
# Episode: 56, Score: 0, Epsilon: 0.01
# Episode: 57, Score: 0, Epsilon: 0.01
# Episode: 58, Score: 0, Epsilon: 0.01
# Episode: 59, Score: 0, Epsilon: 0.01
# Episode: 60, Score: 0, Epsilon: 0.01
# Episode: 61, Score: 0, Epsilon: 0.01
# Episode: 62, Score: 0, Epsilon: 0.01
# Episode: 63, Score: 0, Epsilon: 0.01
# Episode: 65, Score: 0, Epsilon: 0.01
# Episode: 66, Score: 0, Epsilon: 0.01
# Episode: 67, Score: 0, Epsilon: 0.01
# Episode: 68, Score: 0, Epsilon: 0.01
# Episode: 69, Score: 0, Epsilon: 0.01
# Episode: 70, Score: 0, Epsilon: 0.01
# Episode: 71, Score: 0, Epsilon: 0.01
# Episode: 72, Score: 0, Epsilon: 0.01
# Episode: 73, Score: 0, Epsilon: 0.01
# Episode: 74, Score: 0, Epsilon: 0.01
# Episode: 75, Score: 0, Epsilon: 0.01
# Episode: 76, Score: 0, Epsilon: 0.01
# Episode: 77, Score: 0, Epsilon: 0.01
# Episode: 78, Score: 0, Epsilon: 0.01
# Episode: 79, Score: 0, Epsilon: 0.01
# Episode: 80, Score: 0, Epsilon: 0.01
# Episode: 81, Score: 0, Epsilon: 0.01
# Episode: 82, Score: 0, Epsilon: 0.01
# Episode: 83, Score: 0, Epsilon: 0.01
# Episode: 84, Score: 0, Epsilon: 0.01
# Episode: 85, Score: 0, Epsilon: 0.01
# Episode: 86, Score: 0, Epsilon: 0.01
# Episode: 87, Score: 0, Epsilon: 0.01
# Episode: 88, Score: 0, Epsilon: 0.01
# Episode: 89, Score: 0, Epsilon: 0.01
# Episode: 90, Score: 0, Epsilon: 0.01
# Episode: 91, Score: 0, Epsilon: 0.01
# Episode: 92, Score: 0, Epsilon: 0.01
# Episode: 93, Score: 0, Epsilon: 0.01
# Episode: 94, Score: 0, Epsilon: 0.01
# Episode: 95, Score: 0, Epsilon: 0.01
# Episode: 96, Score: 0, Epsilon: 0.01
# Episode: 97, Score: 0, Epsilon: 0.01
# Episode: 98, Score: 0, Epsilon: 0.01
# Episode: 99, Score: 0, Epsilon: 0.01
# Episode: 100, Score: 0, Epsilon: 0.01
# Episode: 101, Score: 0, Epsilon: 0.01
# Episode: 102, Score: 0, Epsilon: 0.01
# Episode: 103, Score: 0, Epsilon: 0.01
# Episode: 104, Score: 0, Epsilon: 0.01
# Episode: 105, Score: 0, Epsilon: 0.01
# Episode: 106, Score: 0, Epsilon: 0.01
# Episode: 107, Score: 0, Epsilon: 0.01
# Episode: 108, Score: 0, Epsilon: 0.01
# Episode: 109, Score: 0, Epsilon: 0.01
# Episode: 110, Score: 0, Epsilon: 0.01
# Episode: 111, Score: 0, Epsilon: 0.01
# Episode: 112, Score: 0, Epsilon: 0.01
# Episode: 113, Score: 0, Epsilon: 0.01
# Episode: 114, Score: 0, Epsilon: 0.01
# Episode: 115, Score: 0, Epsilon: 0.01
# Episode: 116, Score: 0, Epsilon: 0.01
# Episode: 117, Score: 0, Epsilon: 0.01
# Episode: 118, Score: 0, Epsilon: 0.01
# Episode: 119, Score: 0, Epsilon: 0.01
# Episode: 120, Score: 0, Epsilon: 0.01
# Episode: 121, Score: 0, Epsilon: 0.01
# Episode: 122, Score: 1, Epsilon: 0.01
# Episode: 123, Score: 0, Epsilon: 0.01
# Episode: 124, Score: 0, Epsilon: 0.01
# Episode: 125, Score: 0, Epsilon: 0.01
# Episode: 126, Score: 0, Epsilon: 0.01
# Episode: 127, Score: 0, Epsilon: 0.01
# Episode: 128, Score: 0, Epsilon: 0.01
# Episode: 129, Score: 0, Epsilon: 0.01
# Episode: 130, Score: 0, Epsilon: 0.01
# Episode: 131, Score: 0, Epsilon: 0.01
# Episode: 132, Score: 0, Epsilon: 0.01
# Episode: 133, Score: 0, Epsilon: 0.01
# Episode: 134, Score: 0, Epsilon: 0.01
# Episode: 135, Score: 0, Epsilon: 0.01
# Episode: 136, Score: 0, Epsilon: 0.01
# Episode: 137, Score: 0, Epsilon: 0.01
# Episode: 138, Score: 0, Epsilon: 0.01
# Episode: 139, Score: 0, Epsilon: 0.01
# Episode: 140, Score: 0, Epsilon: 0.01
# Episode: 141, Score: 0, Epsilon: 0.01
# Episode: 142, Score: 0, Epsilon: 0.01
# Episode: 143, Score: 0, Epsilon: 0.01
# Episode: 144, Score: 0, Epsilon: 0.01
# Episode: 145, Score: 0, Epsilon: 0.01
# Episode: 146, Score: 0, Epsilon: 0.01
# Episode: 147, Score: 0, Epsilon: 0.01
# Episode: 148, Score: 0, Epsilon: 0.01
# Episode: 149, Score: 0, Epsilon: 0.01
# Episode: 150, Score: 0, Epsilon: 0.01
# Episode: 151, Score: 0, Epsilon: 0.01
# Episode: 152, Score: 0, Epsilon: 0.01
# Episode: 153, Score: 0, Epsilon: 0.01
# Episode: 154, Score: 0, Epsilon: 0.01
# Episode: 155, Score: 1, Epsilon: 0.01
# Episode: 156, Score: 0, Epsilon: 0.01
# Episode: 157, Score: 0, Epsilon: 0.01
# Episode: 158, Score: 0, Epsilon: 0.01
# Episode: 159, Score: 0, Epsilon: 0.01
# Episode: 160, Score: 0, Epsilon: 0.01
# Episode: 161, Score: 0, Epsilon: 0.01
# Episode: 162, Score: 0, Epsilon: 0.01
# Episode: 163, Score: 0, Epsilon: 0.01
# Episode: 164, Score: 0, Epsilon: 0.01
# Episode: 165, Score: 1, Epsilon: 0.01
# Episode: 166, Score: 0, Epsilon: 0.01
# Episode: 167, Score: 1, Epsilon: 0.01
# Episode: 168, Score: 0, Epsilon: 0.01
# Episode: 169, Score: 0, Epsilon: 0.01
# Episode: 170, Score: 0, Epsilon: 0.01
# Episode: 171, Score: 0, Epsilon: 0.01
# Episode: 172, Score: 0, Epsilon: 0.01
# Episode: 173, Score: 0, Epsilon: 0.01
# Episode: 174, Score: 0, Epsilon: 0.01
# Episode: 175, Score: 0, Epsilon: 0.01
# Episode: 176, Score: 0, Epsilon: 0.01
# Episode: 177, Score: 0, Epsilon: 0.01
# Episode: 178, Score: 0, Epsilon: 0.01
# Episode: 179, Score: 0, Epsilon: 0.01
# Episode: 180, Score: 0, Epsilon: 0.01
# Episode: 181, Score: 0, Epsilon: 0.01
# Episode: 182, Score: 0, Epsilon: 0.01
# Episode: 183, Score: 0, Epsilon: 0.01
# Episode: 184, Score: 0, Epsilon: 0.01
# Episode: 185, Score: 1, Epsilon: 0.01
# Episode: 186, Score: 0, Epsilon: 0.01
# Episode: 187, Score: 0, Epsilon: 0.01
# Episode: 188, Score: 0, Epsilon: 0.01
# Episode: 189, Score: 0, Epsilon: 0.01
# Episode: 190, Score: 0, Epsilon: 0.01
# Episode: 191, Score: 0, Epsilon: 0.01
# Episode: 192, Score: 0, Epsilon: 0.01
# Episode: 193, Score: 1, Epsilon: 0.01
# Episode: 194, Score: 0, Epsilon: 0.01
# Episode: 195, Score: 0, Epsilon: 0.01
# Episode: 196, Score: 0, Epsilon: 0.01
# Episode: 197, Score: 0, Epsilon: 0.01
# Episode: 198, Score: 0, Epsilon: 0.01
# Episode: 199, Score: 1, Epsilon: 0.01
# Episode: 200, Score: 0, Epsilon: 0.01
# Episode: 201, Score: 0, Epsilon: 0.01
# Episode: 202, Score: 0, Epsilon: 0.01
# Episode: 203, Score: 0, Epsilon: 0.01
# Episode: 204, Score: 0, Epsilon: 0.01
# Episode: 205, Score: 0, Epsilon: 0.01
# Episode: 206, Score: 0, Epsilon: 0.01
# Episode: 207, Score: 0, Epsilon: 0.01
# Episode: 208, Score: 0, Epsilon: 0.01
# Episode: 209, Score: 0, Epsilon: 0.01
# Episode: 210, Score: 0, Epsilon: 0.01
# Episode: 211, Score: 1, Epsilon: 0.01
# Episode: 212, Score: 0, Epsilon: 0.01
# Episode: 213, Score: 0, Epsilon: 0.01
# Episode: 214, Score: 0, Epsilon: 0.01
# Episode: 215, Score: 1, Epsilon: 0.01
# Episode: 216, Score: 0, Epsilon: 0.01
# Episode: 217, Score: 0, Epsilon: 0.01
# Episode: 218, Score: 0, Epsilon: 0.01
# Episode: 219, Score: 0, Epsilon: 0.01
# Episode: 220, Score: 0, Epsilon: 0.01
# Episode: 221, Score: 0, Epsilon: 0.01
# Episode: 222, Score: 0, Epsilon: 0.01
# Episode: 223, Score: 0, Epsilon: 0.01
# Episode: 224, Score: 0, Epsilon: 0.01
# Episode: 225, Score: 1, Epsilon: 0.01
# Episode: 226, Score: 0, Epsilon: 0.01
# Episode: 227, Score: 0, Epsilon: 0.01
# Episode: 228, Score: 0, Epsilon: 0.01
# Episode: 229, Score: 0, Epsilon: 0.01
# Episode: 230, Score: 0, Epsilon: 0.01
# Episode: 231, Score: 0, Epsilon: 0.01
# Episode: 232, Score: 1, Epsilon: 0.01
# Episode: 233, Score: 0, Epsilon: 0.01
# Episode: 234, Score: 0, Epsilon: 0.01
# Episode: 235, Score: 0, Epsilon: 0.01
# Episode: 236, Score: 0, Epsilon: 0.01
# Episode: 237, Score: 0, Epsilon: 0.01
# Episode: 238, Score: 0, Epsilon: 0.01
# Episode: 239, Score: 0, Epsilon: 0.01
# Episode: 240, Score: 0, Epsilon: 0.01
# Episode: 241, Score: 0, Epsilon: 0.01
# Episode: 242, Score: 0, Epsilon: 0.01
# Episode: 243, Score: 0, Epsilon: 0.01
# Episode: 244, Score: 0, Epsilon: 0.01
# Episode: 245, Score: 0, Epsilon: 0.01
# Episode: 246, Score: 0, Epsilon: 0.01
# Episode: 247, Score: 0, Epsilon: 0.01
# Episode: 249, Score: 0, Epsilon: 0.01
# Episode: 250, Score: 0, Epsilon: 0.01
# Episode: 251, Score: 0, Epsilon: 0.01
# Episode: 252, Score: 0, Epsilon: 0.01
# Episode: 253, Score: 0, Epsilon: 0.01
# Episode: 254, Score: 0, Epsilon: 0.01
# Episode: 255, Score: 0, Epsilon: 0.01
# Episode: 256, Score: 0, Epsilon: 0.01
# Episode: 257, Score: 0, Epsilon: 0.01
# Episode: 258, Score: 0, Epsilon: 0.01
# Episode: 259, Score: 0, Epsilon: 0.01
# Episode: 260, Score: 0, Epsilon: 0.01
# Episode: 261, Score: 0, Epsilon: 0.01
# Episode: 262, Score: 0, Epsilon: 0.01
# Episode: 263, Score: 0, Epsilon: 0.01
# Episode: 264, Score: 0, Epsilon: 0.01
# Episode: 265, Score: 0, Epsilon: 0.01
# Episode: 266, Score: 0, Epsilon: 0.01
# Episode: 267, Score: 0, Epsilon: 0.01
# Episode: 268, Score: 0, Epsilon: 0.01
# Episode: 269, Score: 1, Epsilon: 0.01
# Episode: 270, Score: 0, Epsilon: 0.01
# Episode: 271, Score: 0, Epsilon: 0.01
# Episode: 272, Score: 0, Epsilon: 0.01
# Episode: 273, Score: 0, Epsilon: 0.01
# Episode: 274, Score: 0, Epsilon: 0.01
# Episode: 275, Score: 0, Epsilon: 0.01
# Episode: 276, Score: 0, Epsilon: 0.01
# Episode: 277, Score: 1, Epsilon: 0.01
# Episode: 278, Score: 0, Epsilon: 0.01
# Episode: 279, Score: 0, Epsilon: 0.01
# Episode: 280, Score: 0, Epsilon: 0.01
# Episode: 281, Score: 0, Epsilon: 0.01
# Episode: 282, Score: 0, Epsilon: 0.01
# Episode: 283, Score: 1, Epsilon: 0.01
# Episode: 284, Score: 0, Epsilon: 0.01
# Episode: 285, Score: 0, Epsilon: 0.01
# Episode: 286, Score: 0, Epsilon: 0.01
# Episode: 287, Score: 0, Epsilon: 0.01
# Episode: 288, Score: 0, Epsilon: 0.01
# Episode: 289, Score: 1, Epsilon: 0.01
# Episode: 290, Score: 0, Epsilon: 0.01
# Episode: 291, Score: 0, Epsilon: 0.01
# Episode: 292, Score: 0, Epsilon: 0.01
# Episode: 293, Score: 0, Epsilon: 0.01
# Episode: 294, Score: 0, Epsilon: 0.01
# Episode: 295, Score: 0, Epsilon: 0.01
# Episode: 296, Score: 0, Epsilon: 0.01
# Episode: 297, Score: 0, Epsilon: 0.01
# Episode: 298, Score: 0, Epsilon: 0.01
# Episode: 299, Score: 0, Epsilon: 0.01
# Episode: 300, Score: 0, Epsilon: 0.01
# Episode: 301, Score: 0, Epsilon: 0.01
# Episode: 302, Score: 0, Epsilon: 0.01
# Episode: 303, Score: 0, Epsilon: 0.01
# Episode: 304, Score: 0, Epsilon: 0.01
# Episode: 305, Score: 0, Epsilon: 0.01
# Episode: 306, Score: 0, Epsilon: 0.01
# Episode: 307, Score: 0, Epsilon: 0.01
# Episode: 308, Score: 0, Epsilon: 0.01
# Episode: 309, Score: 0, Epsilon: 0.01
# Episode: 310, Score: 0, Epsilon: 0.01
# Episode: 311, Score: 0, Epsilon: 0.01
# Episode: 312, Score: 0, Epsilon: 0.01
# Episode: 313, Score: 0, Epsilon: 0.01
# Episode: 314, Score: 0, Epsilon: 0.01
# Episode: 315, Score: 0, Epsilon: 0.01
# Episode: 316, Score: 0, Epsilon: 0.01
# Episode: 317, Score: 0, Epsilon: 0.01
# Episode: 318, Score: 0, Epsilon: 0.01
# Episode: 319, Score: 1, Epsilon: 0.01
# Episode: 320, Score: 0, Epsilon: 0.01
# Episode: 321, Score: 0, Epsilon: 0.01
# Episode: 322, Score: 2, Epsilon: 0.01
# Episode: 323, Score: 0, Epsilon: 0.01
# Episode: 324, Score: 1, Epsilon: 0.01
# Episode: 325, Score: 0, Epsilon: 0.01
# Episode: 326, Score: 0, Epsilon: 0.01
# Episode: 327, Score: 0, Epsilon: 0.01
# Episode: 328, Score: 0, Epsilon: 0.01
# Episode: 329, Score: 0, Epsilon: 0.01
# Episode: 330, Score: 0, Epsilon: 0.01
# Episode: 331, Score: 0, Epsilon: 0.01
# Episode: 332, Score: 0, Epsilon: 0.01
# Episode: 333, Score: 0, Epsilon: 0.01
# Episode: 334, Score: 0, Epsilon: 0.01
# Episode: 335, Score: 1, Epsilon: 0.01
# Episode: 336, Score: 0, Epsilon: 0.01
# Episode: 337, Score: 0, Epsilon: 0.01
# Episode: 338, Score: 1, Epsilon: 0.01
# Episode: 339, Score: 0, Epsilon: 0.01
# Episode: 340, Score: 0, Epsilon: 0.01
# Episode: 341, Score: 0, Epsilon: 0.01
# Episode: 342, Score: 0, Epsilon: 0.01
# Episode: 343, Score: 0, Epsilon: 0.01
# Episode: 344, Score: 0, Epsilon: 0.01
# Episode: 345, Score: 0, Epsilon: 0.01
# Episode: 346, Score: 0, Epsilon: 0.01
# Episode: 347, Score: 0, Epsilon: 0.01
# Episode: 348, Score: 0, Epsilon: 0.01
# Episode: 349, Score: 0, Epsilon: 0.01
# Episode: 350, Score: 0, Epsilon: 0.01
# Episode: 351, Score: 0, Epsilon: 0.01
# Episode: 352, Score: 0, Epsilon: 0.01
# Episode: 353, Score: 0, Epsilon: 0.01
# Episode: 354, Score: 0, Epsilon: 0.01
# Episode: 355, Score: 0, Epsilon: 0.01
# Episode: 356, Score: 0, Epsilon: 0.01
# Episode: 357, Score: 0, Epsilon: 0.01
# Episode: 358, Score: 0, Epsilon: 0.01
# Episode: 359, Score: 0, Epsilon: 0.01
# Episode: 360, Score: 0, Epsilon: 0.01
# Episode: 361, Score: 0, Epsilon: 0.01
# Episode: 362, Score: 0, Epsilon: 0.01
# Episode: 363, Score: 2, Epsilon: 0.01
# Episode: 365, Score: 0, Epsilon: 0.01
# Episode: 367, Score: 0, Epsilon: 0.01
# Episode: 368, Score: 0, Epsilon: 0.01
# Episode: 369, Score: 0, Epsilon: 0.01
# Episode: 370, Score: 0, Epsilon: 0.01
# Episode: 371, Score: 0, Epsilon: 0.01
# Episode: 372, Score: 0, Epsilon: 0.01
# Episode: 373, Score: 0, Epsilon: 0.01
# Episode: 374, Score: 0, Epsilon: 0.01
# Episode: 375, Score: 0, Epsilon: 0.01
# Episode: 376, Score: 0, Epsilon: 0.01
# Episode: 377, Score: 0, Epsilon: 0.01
# Episode: 378, Score: 0, Epsilon: 0.01
# Episode: 379, Score: 0, Epsilon: 0.01
# Episode: 380, Score: 0, Epsilon: 0.01
# Episode: 381, Score: 0, Epsilon: 0.01
# Episode: 382, Score: 0, Epsilon: 0.01
# Episode: 383, Score: 0, Epsilon: 0.01
# Episode: 384, Score: 0, Epsilon: 0.01
# Episode: 385, Score: 1, Epsilon: 0.01
# Episode: 386, Score: 0, Epsilon: 0.01
# Episode: 387, Score: 0, Epsilon: 0.01
# Episode: 388, Score: 0, Epsilon: 0.01
# Episode: 389, Score: 0, Epsilon: 0.01
# Episode: 390, Score: 0, Epsilon: 0.01
# Episode: 391, Score: 0, Epsilon: 0.01
# Episode: 392, Score: 1, Epsilon: 0.01
# Episode: 393, Score: 0, Epsilon: 0.01
# Episode: 394, Score: 0, Epsilon: 0.01
# Episode: 395, Score: 0, Epsilon: 0.01
# Episode: 396, Score: 0, Epsilon: 0.01
# Episode: 397, Score: 0, Epsilon: 0.01
# Episode: 398, Score: 0, Epsilon: 0.01
# Episode: 399, Score: 0, Epsilon: 0.01
# Episode: 400, Score: 2, Epsilon: 0.01
# Episode: 401, Score: 1, Epsilon: 0.01
# Episode: 402, Score: 0, Epsilon: 0.01
# Episode: 403, Score: 0, Epsilon: 0.01
# Episode: 404, Score: 0, Epsilon: 0.01
# Episode: 405, Score: 0, Epsilon: 0.01
# Episode: 406, Score: 0, Epsilon: 0.01
# Episode: 407, Score: 0, Epsilon: 0.01
# Episode: 408, Score: 0, Epsilon: 0.01
# Episode: 409, Score: 0, Epsilon: 0.01
# Episode: 410, Score: 0, Epsilon: 0.01
# Episode: 411, Score: 0, Epsilon: 0.01
# Episode: 412, Score: 0, Epsilon: 0.01
# Episode: 413, Score: 0, Epsilon: 0.01
# Episode: 414, Score: 0, Epsilon: 0.01
# Episode: 415, Score: 0, Epsilon: 0.01
# Episode: 416, Score: 1, Epsilon: 0.01
# Episode: 417, Score: 0, Epsilon: 0.01
# Episode: 418, Score: 0, Epsilon: 0.01
# Episode: 419, Score: 0, Epsilon: 0.01
# Episode: 420, Score: 0, Epsilon: 0.01
# Episode: 421, Score: 0, Epsilon: 0.01
# Episode: 422, Score: 0, Epsilon: 0.01
# Episode: 423, Score: 0, Epsilon: 0.01
# Episode: 424, Score: 0, Epsilon: 0.01
# Episode: 425, Score: 0, Epsilon: 0.01
# Episode: 426, Score: 0, Epsilon: 0.01
# Episode: 427, Score: 0, Epsilon: 0.01
# Episode: 428, Score: 0, Epsilon: 0.01
# Episode: 429, Score: 0, Epsilon: 0.01
# Episode: 430, Score: 0, Epsilon: 0.01
# Episode: 431, Score: 0, Epsilon: 0.01
# Episode: 432, Score: 0, Epsilon: 0.01
# Episode: 433, Score: 0, Epsilon: 0.01
# Episode: 434, Score: 0, Epsilon: 0.01
# Episode: 435, Score: 0, Epsilon: 0.01
# Episode: 436, Score: 0, Epsilon: 0.01
# Episode: 437, Score: 0, Epsilon: 0.01
# Episode: 438, Score: 0, Epsilon: 0.01
# Episode: 439, Score: 0, Epsilon: 0.01
# Episode: 440, Score: 0, Epsilon: 0.01
# Episode: 441, Score: 0, Epsilon: 0.01
# Episode: 442, Score: 0, Epsilon: 0.01
# Episode: 443, Score: 0, Epsilon: 0.01
# Episode: 444, Score: 0, Epsilon: 0.01
# Episode: 445, Score: 0, Epsilon: 0.01
# Episode: 446, Score: 0, Epsilon: 0.01
# Episode: 447, Score: 0, Epsilon: 0.01
# Episode: 448, Score: 0, Epsilon: 0.01
# Episode: 449, Score: 1, Epsilon: 0.01
# Episode: 450, Score: 0, Epsilon: 0.01
# Episode: 451, Score: 1, Epsilon: 0.01
# Episode: 452, Score: 0, Epsilon: 0.01
# Episode: 453, Score: 0, Epsilon: 0.01
# Episode: 454, Score: 0, Epsilon: 0.01
# Episode: 455, Score: 0, Epsilon: 0.01
# Episode: 456, Score: 1, Epsilon: 0.01
# Episode: 457, Score: 0, Epsilon: 0.01
# Episode: 458, Score: 0, Epsilon: 0.01
# Episode: 459, Score: 0, Epsilon: 0.01
# Episode: 460, Score: 0, Epsilon: 0.01
# Episode: 461, Score: 0, Epsilon: 0.01
# Episode: 462, Score: 0, Epsilon: 0.01
# Episode: 463, Score: 0, Epsilon: 0.01
# Episode: 464, Score: 0, Epsilon: 0.01
# Episode: 465, Score: 0, Epsilon: 0.01
# Episode: 466, Score: 0, Epsilon: 0.01
# Episode: 467, Score: 0, Epsilon: 0.01
# Episode: 468, Score: 0, Epsilon: 0.01
# Episode: 469, Score: 0, Epsilon: 0.01
# Episode: 470, Score: 0, Epsilon: 0.01
# Episode: 471, Score: 0, Epsilon: 0.01
# Episode: 472, Score: 0, Epsilon: 0.01
# Episode: 473, Score: 1, Epsilon: 0.01
# Episode: 474, Score: 0, Epsilon: 0.01
# Episode: 475, Score: 1, Epsilon: 0.01
# Episode: 476, Score: 1, Epsilon: 0.01
# Episode: 477, Score: 0, Epsilon: 0.01
# Episode: 478, Score: 2, Epsilon: 0.01
# Episode: 479, Score: 0, Epsilon: 0.01
# Episode: 480, Score: 0, Epsilon: 0.01
# Episode: 481, Score: 0, Epsilon: 0.01
# Episode: 482, Score: 0, Epsilon: 0.01
# Episode: 483, Score: 0, Epsilon: 0.01
# Episode: 484, Score: 0, Epsilon: 0.01
# Episode: 485, Score: 0, Epsilon: 0.01
# Episode: 486, Score: 0, Epsilon: 0.01
# Episode: 487, Score: 0, Epsilon: 0.01
# Episode: 488, Score: 0, Epsilon: 0.01
# Episode: 489, Score: 0, Epsilon: 0.01
# Episode: 490, Score: 0, Epsilon: 0.01
# Episode: 491, Score: 0, Epsilon: 0.01
# Episode: 492, Score: 1, Epsilon: 0.01
# Episode: 493, Score: 0, Epsilon: 0.01
# Episode: 494, Score: 0, Epsilon: 0.01
# Episode: 495, Score: 0, Epsilon: 0.01
# Episode: 496, Score: 0, Epsilon: 0.01
# Episode: 497, Score: 0, Epsilon: 0.01
# Episode: 498, Score: 0, Epsilon: 0.01
# Episode: 499, Score: 0, Epsilon: 0.01
# Episode: 500, Score: 0, Epsilon: 0.01
# Episode: 501, Score: 0, Epsilon: 0.01
# Episode: 502, Score: 0, Epsilon: 0.01
# Episode: 503, Score: 1, Epsilon: 0.01
# Episode: 504, Score: 0, Epsilon: 0.01
# Episode: 505, Score: 0, Epsilon: 0.01
# Episode: 506, Score: 0, Epsilon: 0.01
# Episode: 507, Score: 0, Epsilon: 0.01
# Episode: 508, Score: 1, Epsilon: 0.01
# Episode: 509, Score: 0, Epsilon: 0.01
# Episode: 510, Score: 0, Epsilon: 0.01
# Episode: 511, Score: 0, Epsilon: 0.01
# Episode: 512, Score: 0, Epsilon: 0.01
# Episode: 513, Score: 0, Epsilon: 0.01
# Episode: 514, Score: 0, Epsilon: 0.01
# Episode: 515, Score: 1, Epsilon: 0.01
# Episode: 516, Score: 0, Epsilon: 0.01
# Episode: 517, Score: 0, Epsilon: 0.01
# Episode: 518, Score: 0, Epsilon: 0.01
# Episode: 519, Score: 2, Epsilon: 0.01
# Episode: 520, Score: 0, Epsilon: 0.01
# Episode: 521, Score: 0, Epsilon: 0.01
# Episode: 522, Score: 0, Epsilon: 0.01
# Episode: 523, Score: 1, Epsilon: 0.01
# Episode: 524, Score: 1, Epsilon: 0.01
# Episode: 525, Score: 0, Epsilon: 0.01
# Episode: 526, Score: 0, Epsilon: 0.01
# Episode: 527, Score: 0, Epsilon: 0.01
# Episode: 528, Score: 0, Epsilon: 0.01
# Episode: 529, Score: 0, Epsilon: 0.01
# Episode: 530, Score: 0, Epsilon: 0.01
# Episode: 531, Score: 0, Epsilon: 0.01
# Episode: 532, Score: 0, Epsilon: 0.01
# Episode: 533, Score: 0, Epsilon: 0.01
# Episode: 534, Score: 0, Epsilon: 0.01
# Episode: 535, Score: 0, Epsilon: 0.01
# Episode: 536, Score: 0, Epsilon: 0.01
# Episode: 537, Score: 0, Epsilon: 0.01
# Episode: 538, Score: 0, Epsilon: 0.01
# Episode: 539, Score: 0, Epsilon: 0.01
# Episode: 540, Score: 0, Epsilon: 0.01
# Episode: 541, Score: 0, Epsilon: 0.01
# Episode: 542, Score: 0, Epsilon: 0.01
# Episode: 543, Score: 1, Epsilon: 0.01
# Episode: 544, Score: 0, Epsilon: 0.01
# Episode: 545, Score: 0, Epsilon: 0.01
# Episode: 546, Score: 0, Epsilon: 0.01
# Episode: 547, Score: 0, Epsilon: 0.01
# Episode: 548, Score: 0, Epsilon: 0.01
# Episode: 549, Score: 0, Epsilon: 0.01
# Episode: 550, Score: 0, Epsilon: 0.01
# Episode: 551, Score: 0, Epsilon: 0.01
# Episode: 552, Score: 0, Epsilon: 0.01
# Episode: 553, Score: 0, Epsilon: 0.01
# Episode: 554, Score: 0, Epsilon: 0.01
# Episode: 555, Score: 0, Epsilon: 0.01
# Episode: 556, Score: 0, Epsilon: 0.01
# Episode: 557, Score: 0, Epsilon: 0.01
# Episode: 558, Score: 1, Epsilon: 0.01
# Episode: 559, Score: 0, Epsilon: 0.01
# Episode: 560, Score: 0, Epsilon: 0.01
# Episode: 561, Score: 0, Epsilon: 0.01
# Episode: 562, Score: 0, Epsilon: 0.01
# Episode: 563, Score: 0, Epsilon: 0.01
# Episode: 564, Score: 0, Epsilon: 0.01
# Episode: 565, Score: 0, Epsilon: 0.01
# Episode: 566, Score: 0, Epsilon: 0.01
# Episode: 567, Score: 1, Epsilon: 0.01
# Episode: 568, Score: 0, Epsilon: 0.01
# Episode: 569, Score: 1, Epsilon: 0.01
# Episode: 570, Score: 0, Epsilon: 0.01
# Episode: 571, Score: 0, Epsilon: 0.01
# Episode: 572, Score: 0, Epsilon: 0.01
# Episode: 573, Score: 0, Epsilon: 0.01
# Episode: 574, Score: 0, Epsilon: 0.01
# Episode: 575, Score: 1, Epsilon: 0.01
# Episode: 576, Score: 0, Epsilon: 0.01
# Episode: 577, Score: 0, Epsilon: 0.01
# Episode: 578, Score: 0, Epsilon: 0.01
# Episode: 579, Score: 0, Epsilon: 0.01
# Episode: 580, Score: 0, Epsilon: 0.01
# Episode: 581, Score: 0, Epsilon: 0.01
# Episode: 582, Score: 0, Epsilon: 0.01
# Episode: 583, Score: 0, Epsilon: 0.01
# Episode: 584, Score: 0, Epsilon: 0.01
# Episode: 585, Score: 0, Epsilon: 0.01
# Episode: 586, Score: 2, Epsilon: 0.01
# Episode: 587, Score: 0, Epsilon: 0.01
# Episode: 588, Score: 0, Epsilon: 0.01
# Episode: 589, Score: 0, Epsilon: 0.01
# Episode: 590, Score: 0, Epsilon: 0.01
# Episode: 591, Score: 0, Epsilon: 0.01
# Episode: 592, Score: 0, Epsilon: 0.01
# Episode: 593, Score: 0, Epsilon: 0.01
# Episode: 594, Score: 0, Epsilon: 0.01
# Episode: 596, Score: 0, Epsilon: 0.01
# Episode: 597, Score: 0, Epsilon: 0.01
# Episode: 598, Score: 0, Epsilon: 0.01
# Episode: 599, Score: 0, Epsilon: 0.01
# Episode: 600, Score: 0, Epsilon: 0.01
# Episode: 601, Score: 0, Epsilon: 0.01
# Episode: 603, Score: 1, Epsilon: 0.01
# Episode: 604, Score: 0, Epsilon: 0.01
# Episode: 605, Score: 0, Epsilon: 0.01
# Episode: 606, Score: 1, Epsilon: 0.01
# Episode: 607, Score: 0, Epsilon: 0.01
# Episode: 608, Score: 0, Epsilon: 0.01
# Episode: 609, Score: 0, Epsilon: 0.01
# Episode: 610, Score: 1, Epsilon: 0.01
# Episode: 611, Score: 0, Epsilon: 0.01
# Episode: 612, Score: 0, Epsilon: 0.01
# Episode: 613, Score: 1, Epsilon: 0.01
# Episode: 614, Score: 0, Epsilon: 0.01
# Episode: 615, Score: 0, Epsilon: 0.01
# Episode: 616, Score: 0, Epsilon: 0.01
# Episode: 617, Score: 0, Epsilon: 0.01
# Episode: 618, Score: 0, Epsilon: 0.01
# Episode: 619, Score: 0, Epsilon: 0.01
# Episode: 620, Score: 0, Epsilon: 0.01
# Episode: 621, Score: 0, Epsilon: 0.01
# Episode: 622, Score: 0, Epsilon: 0.01
# Episode: 623, Score: 0, Epsilon: 0.01
# Episode: 624, Score: 0, Epsilon: 0.01
# Episode: 625, Score: 0, Epsilon: 0.01
# Episode: 626, Score: 0, Epsilon: 0.01
# Episode: 627, Score: 0, Epsilon: 0.01
# Episode: 628, Score: 0, Epsilon: 0.01
# Episode: 629, Score: 0, Epsilon: 0.01
# Episode: 630, Score: 0, Epsilon: 0.01
# Episode: 631, Score: 0, Epsilon: 0.01
# Episode: 632, Score: 1, Epsilon: 0.01
# Episode: 633, Score: 0, Epsilon: 0.01
# Episode: 634, Score: 1, Epsilon: 0.01
# Episode: 635, Score: 0, Epsilon: 0.01
# Episode: 636, Score: 0, Epsilon: 0.01
# Episode: 637, Score: 0, Epsilon: 0.01
# Episode: 638, Score: 0, Epsilon: 0.01
# Episode: 639, Score: 2, Epsilon: 0.01
# Episode: 640, Score: 0, Epsilon: 0.01
# Episode: 641, Score: 1, Epsilon: 0.01
# Episode: 642, Score: 0, Epsilon: 0.01
# Episode: 643, Score: 0, Epsilon: 0.01
# Episode: 644, Score: 0, Epsilon: 0.01
# Episode: 645, Score: 0, Epsilon: 0.01
# Episode: 646, Score: 0, Epsilon: 0.01
# Episode: 647, Score: 0, Epsilon: 0.01
# Episode: 648, Score: 0, Epsilon: 0.01
# Episode: 649, Score: 0, Epsilon: 0.01
# Episode: 650, Score: 0, Epsilon: 0.01
# Episode: 651, Score: 0, Epsilon: 0.01
# Episode: 652, Score: 0, Epsilon: 0.01
# Episode: 653, Score: 0, Epsilon: 0.01
# Episode: 654, Score: 1, Epsilon: 0.01
# Episode: 656, Score: 0, Epsilon: 0.01
# Episode: 657, Score: 2, Epsilon: 0.01
# Episode: 658, Score: 1, Epsilon: 0.01
# Episode: 659, Score: 0, Epsilon: 0.01
# Episode: 660, Score: 0, Epsilon: 0.01
# Episode: 661, Score: 0, Epsilon: 0.01
# Episode: 662, Score: 0, Epsilon: 0.01
# Episode: 663, Score: 1, Epsilon: 0.01
# Episode: 664, Score: 0, Epsilon: 0.01
# Episode: 665, Score: 0, Epsilon: 0.01
# Episode: 666, Score: 1, Epsilon: 0.01
# Episode: 667, Score: 0, Epsilon: 0.01
# Episode: 668, Score: 0, Epsilon: 0.01
# Episode: 669, Score: 0, Epsilon: 0.01
# Episode: 670, Score: 0, Epsilon: 0.01
# Episode: 671, Score: 1, Epsilon: 0.01
# Episode: 672, Score: 0, Epsilon: 0.01
# Episode: 673, Score: 0, Epsilon: 0.01
# Episode: 674, Score: 0, Epsilon: 0.01
# Episode: 675, Score: 0, Epsilon: 0.01
# Episode: 676, Score: 0, Epsilon: 0.01
# Episode: 677, Score: 0, Epsilon: 0.01
# Episode: 678, Score: 0, Epsilon: 0.01
# Episode: 679, Score: 0, Epsilon: 0.01
# Episode: 680, Score: 0, Epsilon: 0.01
# Episode: 681, Score: 0, Epsilon: 0.01
# Episode: 682, Score: 0, Epsilon: 0.01
# Episode: 683, Score: 0, Epsilon: 0.01
# Episode: 684, Score: 0, Epsilon: 0.01
# Episode: 685, Score: 0, Epsilon: 0.01
# Episode: 686, Score: 1, Epsilon: 0.01
# Episode: 687, Score: 0, Epsilon: 0.01
# Episode: 688, Score: 0, Epsilon: 0.01
# Episode: 689, Score: 0, Epsilon: 0.01
# Episode: 690, Score: 0, Epsilon: 0.01
# Episode: 691, Score: 0, Epsilon: 0.01
# Episode: 692, Score: 1, Epsilon: 0.01
# Episode: 693, Score: 0, Epsilon: 0.01
# Episode: 694, Score: 0, Epsilon: 0.01
# Episode: 695, Score: 0, Epsilon: 0.01
# Episode: 696, Score: 0, Epsilon: 0.01
# Episode: 698, Score: 0, Epsilon: 0.01
# Episode: 699, Score: 0, Epsilon: 0.01
# Episode: 700, Score: 0, Epsilon: 0.01
# Episode: 701, Score: 0, Epsilon: 0.01
# Episode: 702, Score: 0, Epsilon: 0.01
# Episode: 703, Score: 0, Epsilon: 0.01
# Episode: 704, Score: 0, Epsilon: 0.01
# Episode: 705, Score: 0, Epsilon: 0.01
# Episode: 706, Score: 0, Epsilon: 0.01
# Episode: 707, Score: 0, Epsilon: 0.01
# Episode: 708, Score: 0, Epsilon: 0.01
# Episode: 709, Score: 0, Epsilon: 0.01
# Episode: 711, Score: 0, Epsilon: 0.01
# Episode: 712, Score: 0, Epsilon: 0.01
# Episode: 713, Score: 0, Epsilon: 0.01
# Episode: 714, Score: 1, Epsilon: 0.01
# Episode: 716, Score: 0, Epsilon: 0.01
# Episode: 717, Score: 0, Epsilon: 0.01
# Episode: 718, Score: 0, Epsilon: 0.01
# Episode: 719, Score: 0, Epsilon: 0.01
# Episode: 720, Score: 0, Epsilon: 0.01
# Episode: 721, Score: 0, Epsilon: 0.01
# Episode: 722, Score: 0, Epsilon: 0.01
# Episode: 724, Score: 0, Epsilon: 0.01
# Episode: 726, Score: 0, Epsilon: 0.01
# Episode: 727, Score: 0, Epsilon: 0.01
# Episode: 729, Score: 0, Epsilon: 0.01
# Episode: 730, Score: 0, Epsilon: 0.01
# Episode: 731, Score: 0, Epsilon: 0.01
# Episode: 732, Score: 0, Epsilon: 0.01
# Episode: 733, Score: 0, Epsilon: 0.01
# Episode: 734, Score: 0, Epsilon: 0.01
# Episode: 735, Score: 0, Epsilon: 0.01
# Episode: 736, Score: 0, Epsilon: 0.01
# Episode: 737, Score: 0, Epsilon: 0.01
# Episode: 738, Score: 0, Epsilon: 0.01
# Episode: 739, Score: 0, Epsilon: 0.01
# Episode: 740, Score: 0, Epsilon: 0.01
# Episode: 741, Score: 0, Epsilon: 0.01
# Episode: 742, Score: 0, Epsilon: 0.01
# Episode: 743, Score: 0, Epsilon: 0.01
# Episode: 744, Score: 0, Epsilon: 0.01
# Episode: 745, Score: 1, Epsilon: 0.01
# Episode: 746, Score: 0, Epsilon: 0.01
# Episode: 747, Score: 0, Epsilon: 0.01
# Episode: 748, Score: 1, Epsilon: 0.01
# Episode: 749, Score: 0, Epsilon: 0.01
# Episode: 750, Score: 0, Epsilon: 0.01
# Episode: 751, Score: 0, Epsilon: 0.01
# Episode: 752, Score: 0, Epsilon: 0.01
# Episode: 753, Score: 1, Epsilon: 0.01
# Episode: 754, Score: 0, Epsilon: 0.01
# Episode: 755, Score: 0, Epsilon: 0.01
# Episode: 756, Score: 0, Epsilon: 0.01
# Episode: 757, Score: 1, Epsilon: 0.01
# Episode: 758, Score: 0, Epsilon: 0.01
# Episode: 759, Score: 0, Epsilon: 0.01
# Episode: 760, Score: 0, Epsilon: 0.01
# Episode: 761, Score: 1, Epsilon: 0.01
# Episode: 762, Score: 0, Epsilon: 0.01
# Episode: 763, Score: 0, Epsilon: 0.01
# Episode: 764, Score: 0, Epsilon: 0.01
# Episode: 765, Score: 0, Epsilon: 0.01
# Episode: 766, Score: 0, Epsilon: 0.01
# Episode: 768, Score: 0, Epsilon: 0.01
# Episode: 770, Score: 1, Epsilon: 0.01
# Episode: 771, Score: 0, Epsilon: 0.01
# Episode: 772, Score: 0, Epsilon: 0.01
# Episode: 773, Score: 0, Epsilon: 0.01
# Episode: 774, Score: 0, Epsilon: 0.01
# Episode: 775, Score: 0, Epsilon: 0.01
# Episode: 776, Score: 0, Epsilon: 0.01
# Episode: 777, Score: 0, Epsilon: 0.01
# Episode: 778, Score: 0, Epsilon: 0.01
# Episode: 779, Score: 0, Epsilon: 0.01
# Episode: 780, Score: 0, Epsilon: 0.01
# Episode: 781, Score: 1, Epsilon: 0.01
# Episode: 782, Score: 0, Epsilon: 0.01
# Episode: 783, Score: 0, Epsilon: 0.01
# Episode: 784, Score: 0, Epsilon: 0.01
# Episode: 785, Score: 0, Epsilon: 0.01
# Episode: 786, Score: 0, Epsilon: 0.01
# Episode: 787, Score: 1, Epsilon: 0.01
# Episode: 788, Score: 0, Epsilon: 0.01
# Episode: 789, Score: 0, Epsilon: 0.01
# Episode: 790, Score: 0, Epsilon: 0.01
# Episode: 791, Score: 1, Epsilon: 0.01
# Episode: 792, Score: 0, Epsilon: 0.01
# Episode: 793, Score: 0, Epsilon: 0.01
# Episode: 794, Score: 0, Epsilon: 0.01
# Episode: 795, Score: 0, Epsilon: 0.01
# Episode: 796, Score: 0, Epsilon: 0.01
# Episode: 797, Score: 0, Epsilon: 0.01
# Episode: 798, Score: 0, Epsilon: 0.01
# Episode: 799, Score: 0, Epsilon: 0.01
# Episode: 800, Score: 0, Epsilon: 0.01
# Episode: 801, Score: 0, Epsilon: 0.01
# Episode: 802, Score: 0, Epsilon: 0.01
# Episode: 803, Score: 0, Epsilon: 0.01
# Episode: 804, Score: 0, Epsilon: 0.01
# Episode: 805, Score: 0, Epsilon: 0.01
# Episode: 806, Score: 0, Epsilon: 0.01
# Episode: 807, Score: 0, Epsilon: 0.01
# Episode: 808, Score: 0, Epsilon: 0.01
# Episode: 809, Score: 0, Epsilon: 0.01
# Episode: 810, Score: 0, Epsilon: 0.01
# Episode: 811, Score: 0, Epsilon: 0.01
# Episode: 812, Score: 0, Epsilon: 0.01
# Episode: 813, Score: 0, Epsilon: 0.01
# Episode: 814, Score: 0, Epsilon: 0.01
# Episode: 815, Score: 0, Epsilon: 0.01
# Episode: 816, Score: 0, Epsilon: 0.01
# Episode: 817, Score: 0, Epsilon: 0.01
# Episode: 818, Score: 0, Epsilon: 0.01
# Episode: 819, Score: 0, Epsilon: 0.01
# Episode: 820, Score: 0, Epsilon: 0.01
# Episode: 821, Score: 0, Epsilon: 0.01
# Episode: 822, Score: 0, Epsilon: 0.01
# Episode: 823, Score: 0, Epsilon: 0.01
# Episode: 824, Score: 0, Epsilon: 0.01
# Episode: 825, Score: 0, Epsilon: 0.01
# Episode: 826, Score: 0, Epsilon: 0.01
# Episode: 827, Score: 0, Epsilon: 0.01
# Episode: 828, Score: 1, Epsilon: 0.01
# Episode: 829, Score: 0, Epsilon: 0.01
# Episode: 830, Score: 0, Epsilon: 0.01
# Episode: 831, Score: 0, Epsilon: 0.01
# Episode: 832, Score: 0, Epsilon: 0.01
# Episode: 833, Score: 0, Epsilon: 0.01
# Episode: 834, Score: 0, Epsilon: 0.01
# Episode: 835, Score: 0, Epsilon: 0.01
# Episode: 836, Score: 0, Epsilon: 0.01
# Episode: 837, Score: 0, Epsilon: 0.01
# Episode: 838, Score: 0, Epsilon: 0.01
# Episode: 839, Score: 0, Epsilon: 0.01
# Episode: 840, Score: 0, Epsilon: 0.01
# Episode: 841, Score: 0, Epsilon: 0.01
# Episode: 842, Score: 0, Epsilon: 0.01
# Episode: 843, Score: 0, Epsilon: 0.01
# Episode: 844, Score: 0, Epsilon: 0.01
# Episode: 845, Score: 0, Epsilon: 0.01
# Episode: 846, Score: 0, Epsilon: 0.01
# Episode: 847, Score: 0, Epsilon: 0.01
# Episode: 848, Score: 0, Epsilon: 0.01
# Episode: 849, Score: 0, Epsilon: 0.01
# Episode: 850, Score: 0, Epsilon: 0.01
# Episode: 851, Score: 0, Epsilon: 0.01
# Episode: 852, Score: 0, Epsilon: 0.01
# Episode: 853, Score: 0, Epsilon: 0.01
# Episode: 854, Score: 0, Epsilon: 0.01
# Episode: 855, Score: 0, Epsilon: 0.01
# Episode: 856, Score: 0, Epsilon: 0.01
# Episode: 857, Score: 0, Epsilon: 0.01
# Episode: 858, Score: 0, Epsilon: 0.01
# Episode: 859, Score: 0, Epsilon: 0.01
# Episode: 860, Score: 1, Epsilon: 0.01
# Episode: 861, Score: 0, Epsilon: 0.01
# Episode: 862, Score: 0, Epsilon: 0.01
# Episode: 863, Score: 0, Epsilon: 0.01
# Episode: 864, Score: 0, Epsilon: 0.01
# Episode: 865, Score: 0, Epsilon: 0.01
# Episode: 866, Score: 0, Epsilon: 0.01
# Episode: 867, Score: 0, Epsilon: 0.01
# Episode: 868, Score: 0, Epsilon: 0.01
# Episode: 871, Score: 0, Epsilon: 0.01
# Episode: 872, Score: 0, Epsilon: 0.01
# Episode: 873, Score: 0, Epsilon: 0.01
# Episode: 874, Score: 0, Epsilon: 0.01
# Episode: 875, Score: 0, Epsilon: 0.01
# Episode: 876, Score: 0, Epsilon: 0.01
# Episode: 877, Score: 0, Epsilon: 0.01
# Episode: 878, Score: 1, Epsilon: 0.01
# Episode: 879, Score: 0, Epsilon: 0.01
# Episode: 880, Score: 0, Epsilon: 0.01
# Episode: 881, Score: 1, Epsilon: 0.01
# Episode: 882, Score: 0, Epsilon: 0.01
# Episode: 883, Score: 2, Epsilon: 0.01
# Episode: 884, Score: 0, Epsilon: 0.01
# Episode: 885, Score: 0, Epsilon: 0.01
# Episode: 886, Score: 0, Epsilon: 0.01
# Episode: 887, Score: 0, Epsilon: 0.01
# Episode: 888, Score: 0, Epsilon: 0.01
# Episode: 889, Score: 0, Epsilon: 0.01
# Episode: 891, Score: 0, Epsilon: 0.01
# Episode: 892, Score: 0, Epsilon: 0.01
# Episode: 893, Score: 0, Epsilon: 0.01
# Episode: 894, Score: 0, Epsilon: 0.01
# Episode: 895, Score: 0, Epsilon: 0.01
# Episode: 896, Score: 0, Epsilon: 0.01
# Episode: 897, Score: 0, Epsilon: 0.01
# Episode: 898, Score: 0, Epsilon: 0.01
# Episode: 899, Score: 0, Epsilon: 0.01
# Episode: 900, Score: 0, Epsilon: 0.01
# Episode: 901, Score: 0, Epsilon: 0.01
# Episode: 902, Score: 1, Epsilon: 0.01
# Episode: 903, Score: 0, Epsilon: 0.01
# Episode: 904, Score: 0, Epsilon: 0.01
# Episode: 905, Score: 0, Epsilon: 0.01
# Episode: 906, Score: 1, Epsilon: 0.01
# Episode: 909, Score: 1, Epsilon: 0.01
# Episode: 910, Score: 0, Epsilon: 0.01
# Episode: 911, Score: 0, Epsilon: 0.01
# Episode: 912, Score: 0, Epsilon: 0.01
# Episode: 913, Score: 0, Epsilon: 0.01
# Episode: 914, Score: 0, Epsilon: 0.01
# Episode: 915, Score: 0, Epsilon: 0.01
# Episode: 916, Score: 0, Epsilon: 0.01
# Episode: 917, Score: 0, Epsilon: 0.01
# Episode: 918, Score: 0, Epsilon: 0.01
# Episode: 919, Score: 1, Epsilon: 0.01
# Episode: 920, Score: 0, Epsilon: 0.01
# Episode: 921, Score: 0, Epsilon: 0.01
# Episode: 923, Score: 0, Epsilon: 0.01
# Episode: 925, Score: 0, Epsilon: 0.01
# Episode: 926, Score: 0, Epsilon: 0.01
# Episode: 927, Score: 0, Epsilon: 0.01
# Episode: 928, Score: 0, Epsilon: 0.01
# Episode: 929, Score: 0, Epsilon: 0.01
# Episode: 930, Score: 0, Epsilon: 0.01
# Episode: 931, Score: 0, Epsilon: 0.01
# Episode: 932, Score: 0, Epsilon: 0.01
# Episode: 933, Score: 0, Epsilon: 0.01
# Episode: 934, Score: 0, Epsilon: 0.01
# Episode: 935, Score: 0, Epsilon: 0.01
# Episode: 936, Score: 1, Epsilon: 0.01
# Episode: 937, Score: 0, Epsilon: 0.01
# Episode: 938, Score: 1, Epsilon: 0.01
# Episode: 939, Score: 0, Epsilon: 0.01
# Episode: 940, Score: 0, Epsilon: 0.01
# Episode: 941, Score: 0, Epsilon: 0.01
# Episode: 942, Score: 0, Epsilon: 0.01
# Episode: 943, Score: 0, Epsilon: 0.01
# Episode: 944, Score: 0, Epsilon: 0.01
# Episode: 945, Score: 0, Epsilon: 0.01
# Episode: 950, Score: 0, Epsilon: 0.01
# Episode: 951, Score: 0, Epsilon: 0.01
# Episode: 952, Score: 0, Epsilon: 0.01
# Episode: 953, Score: 0, Epsilon: 0.01
# Episode: 954, Score: 0, Epsilon: 0.01
# Episode: 955, Score: 0, Epsilon: 0.01
# Episode: 956, Score: 0, Epsilon: 0.01
# Episode: 957, Score: 0, Epsilon: 0.01
# Episode: 958, Score: 0, Epsilon: 0.01
# Episode: 959, Score: 0, Epsilon: 0.01
# Episode: 960, Score: 0, Epsilon: 0.01
# Episode: 961, Score: 0, Epsilon: 0.01
# Episode: 962, Score: 0, Epsilon: 0.01
# Episode: 963, Score: 0, Epsilon: 0.01
# Episode: 964, Score: 0, Epsilon: 0.01
# Episode: 965, Score: 0, Epsilon: 0.01
# Episode: 966, Score: 0, Epsilon: 0.01
# Episode: 967, Score: 0, Epsilon: 0.01
# Episode: 968, Score: 0, Epsilon: 0.01
# Episode: 969, Score: 0, Epsilon: 0.01
# Episode: 970, Score: 0, Epsilon: 0.01
# Episode: 971, Score: 0, Epsilon: 0.01
# Episode: 972, Score: 0, Epsilon: 0.01
# Episode: 973, Score: 0, Epsilon: 0.01
# Episode: 974, Score: 0, Epsilon: 0.01
# Episode: 975, Score: 0, Epsilon: 0.01
# Episode: 976, Score: 0, Epsilon: 0.01
# Episode: 977, Score: 0, Epsilon: 0.01
# Episode: 979, Score: 0, Epsilon: 0.01
# Episode: 980, Score: 0, Epsilon: 0.01
# Episode: 981, Score: 0, Epsilon: 0.01
# Episode: 982, Score: 0, Epsilon: 0.01
# Episode: 983, Score: 1, Epsilon: 0.01
# Episode: 984, Score: 0, Epsilon: 0.01
# Episode: 985, Score: 0, Epsilon: 0.01
# Episode: 986, Score: 0, Epsilon: 0.01
# Episode: 987, Score: 0, Epsilon: 0.01
# Episode: 988, Score: 0, Epsilon: 0.01
# Episode: 989, Score: 0, Epsilon: 0.01
# Episode: 990, Score: 0, Epsilon: 0.01
# Episode: 991, Score: 0, Epsilon: 0.01
# Episode: 992, Score: 0, Epsilon: 0.01
# Episode: 993, Score: 0, Epsilon: 0.01
# Episode: 994, Score: 0, Epsilon: 0.01
# Episode: 995, Score: 0, Epsilon: 0.01
# Episode: 997, Score: 1, Epsilon: 0.01
# Episode: 998, Score: 0, Epsilon: 0.01
# Episode: 999, Score: 0, Epsilon: 0.01
# Episode: 1000, Score: 0, Epsilon: 0.01
# Saved model at episode 1000
# Training time for RNN after 1000 episodes: 14297.88 seconds
# Episode: 1001, Score: 0, Epsilon: 0.01
# Episode: 1002, Score: 0, Epsilon: 0.01
# Episode: 1003, Score: 0, Epsilon: 0.01
# Episode: 1004, Score: 0, Epsilon: 0.01
# Episode: 1005, Score: 0, Epsilon: 0.01
# Episode: 1006, Score: 0, Epsilon: 0.01
# Episode: 1007, Score: 0, Epsilon: 0.01
# Episode: 1008, Score: 0, Epsilon: 0.01
# Episode: 1009, Score: 0, Epsilon: 0.01
# Episode: 1010, Score: 0, Epsilon: 0.01
# Episode: 1011, Score: 0, Epsilon: 0.01
# Episode: 1012, Score: 0, Epsilon: 0.01
# Episode: 1013, Score: 0, Epsilon: 0.01
# Episode: 1014, Score: 0, Epsilon: 0.01
# Episode: 1015, Score: 0, Epsilon: 0.01
# Episode: 1016, Score: 0, Epsilon: 0.01
# Episode: 1017, Score: 0, Epsilon: 0.01
# Episode: 1018, Score: 0, Epsilon: 0.01
# Episode: 1019, Score: 0, Epsilon: 0.01
# Episode: 1020, Score: 0, Epsilon: 0.01
# Episode: 1021, Score: 0, Epsilon: 0.01
# Episode: 1023, Score: 0, Epsilon: 0.01
# Episode: 1025, Score: 0, Epsilon: 0.01
# Episode: 1026, Score: 0, Epsilon: 0.01
# Episode: 1027, Score: 0, Epsilon: 0.01
# Episode: 1028, Score: 0, Epsilon: 0.01
# Episode: 1029, Score: 0, Epsilon: 0.01
# Episode: 1030, Score: 0, Epsilon: 0.01
# Episode: 1031, Score: 1, Epsilon: 0.01
# Episode: 1032, Score: 0, Epsilon: 0.01
# Episode: 1033, Score: 0, Epsilon: 0.01
# Episode: 1034, Score: 1, Epsilon: 0.01
# Episode: 1036, Score: 0, Epsilon: 0.01
# Episode: 1037, Score: 0, Epsilon: 0.01
# Episode: 1038, Score: 0, Epsilon: 0.01
# Episode: 1039, Score: 0, Epsilon: 0.01
# Episode: 1040, Score: 0, Epsilon: 0.01
# Episode: 1041, Score: 0, Epsilon: 0.01
# Episode: 1042, Score: 0, Epsilon: 0.01
# Episode: 1043, Score: 0, Epsilon: 0.01
# Episode: 1044, Score: 0, Epsilon: 0.01
# Episode: 1045, Score: 0, Epsilon: 0.01
# Episode: 1046, Score: 0, Epsilon: 0.01
# Episode: 1047, Score: 0, Epsilon: 0.01
# Episode: 1048, Score: 0, Epsilon: 0.01
# Episode: 1049, Score: 0, Epsilon: 0.01
# Episode: 1050, Score: 0, Epsilon: 0.01
# Episode: 1051, Score: 0, Epsilon: 0.01
# Episode: 1052, Score: 2, Epsilon: 0.01
# Episode: 1053, Score: 0, Epsilon: 0.01
# Episode: 1054, Score: 0, Epsilon: 0.01
# Episode: 1055, Score: 0, Epsilon: 0.01
# Episode: 1056, Score: 0, Epsilon: 0.01
# Episode: 1057, Score: 0, Epsilon: 0.01
# Episode: 1058, Score: 1, Epsilon: 0.01
# Episode: 1059, Score: 0, Epsilon: 0.01
# Episode: 1060, Score: 0, Epsilon: 0.01
# Episode: 1061, Score: 0, Epsilon: 0.01
# Episode: 1062, Score: 0, Epsilon: 0.01
# Episode: 1063, Score: 0, Epsilon: 0.01
# Episode: 1064, Score: 1, Epsilon: 0.01
# Episode: 1065, Score: 0, Epsilon: 0.01
# Episode: 1066, Score: 0, Epsilon: 0.01
# Episode: 1067, Score: 0, Epsilon: 0.01
# Episode: 1068, Score: 0, Epsilon: 0.01
# Episode: 1069, Score: 0, Epsilon: 0.01
# Episode: 1070, Score: 0, Epsilon: 0.01
# Episode: 1071, Score: 0, Epsilon: 0.01
# Episode: 1072, Score: 0, Epsilon: 0.01
# Episode: 1073, Score: 0, Epsilon: 0.01
# Episode: 1074, Score: 0, Epsilon: 0.01
# Episode: 1075, Score: 0, Epsilon: 0.01
# Episode: 1076, Score: 0, Epsilon: 0.01
# Episode: 1077, Score: 0, Epsilon: 0.01
# Episode: 1078, Score: 0, Epsilon: 0.01
# Episode: 1079, Score: 0, Epsilon: 0.01
# Episode: 1080, Score: 0, Epsilon: 0.01
# Episode: 1081, Score: 0, Epsilon: 0.01
# Episode: 1082, Score: 0, Epsilon: 0.01
# Episode: 1083, Score: 0, Epsilon: 0.01
# Episode: 1084, Score: 0, Epsilon: 0.01
# Episode: 1085, Score: 0, Epsilon: 0.01
# Episode: 1086, Score: 0, Epsilon: 0.01
# Episode: 1087, Score: 0, Epsilon: 0.01
# Episode: 1088, Score: 0, Epsilon: 0.01
# Episode: 1089, Score: 0, Epsilon: 0.01
# Episode: 1090, Score: 0, Epsilon: 0.01
# Episode: 1091, Score: 0, Epsilon: 0.01
# Episode: 1092, Score: 0, Epsilon: 0.01
# Episode: 1093, Score: 0, Epsilon: 0.01
# Episode: 1094, Score: 0, Epsilon: 0.01
# Episode: 1095, Score: 0, Epsilon: 0.01
# Episode: 1096, Score: 0, Epsilon: 0.01
# Episode: 1097, Score: 0, Epsilon: 0.01
# Episode: 1098, Score: 0, Epsilon: 0.01
# Episode: 1099, Score: 0, Epsilon: 0.01
# Episode: 1102, Score: 0, Epsilon: 0.01
# Episode: 1103, Score: 0, Epsilon: 0.01
# Episode: 1104, Score: 0, Epsilon: 0.01
# Episode: 1105, Score: 0, Epsilon: 0.01
# Episode: 1106, Score: 0, Epsilon: 0.01
# Episode: 1107, Score: 0, Epsilon: 0.01
# Episode: 1108, Score: 0, Epsilon: 0.01
# Episode: 1109, Score: 0, Epsilon: 0.01
# Episode: 1110, Score: 0, Epsilon: 0.01
# Episode: 1111, Score: 0, Epsilon: 0.01
# Episode: 1112, Score: 0, Epsilon: 0.01
# Episode: 1113, Score: 0, Epsilon: 0.01
# Episode: 1114, Score: 0, Epsilon: 0.01
# Episode: 1115, Score: 1, Epsilon: 0.01
# Episode: 1116, Score: 0, Epsilon: 0.01
# Episode: 1117, Score: 0, Epsilon: 0.01
# Episode: 1118, Score: 0, Epsilon: 0.01
# Episode: 1119, Score: 1, Epsilon: 0.01
# Episode: 1120, Score: 0, Epsilon: 0.01
# Episode: 1121, Score: 0, Epsilon: 0.01
# Episode: 1122, Score: 0, Epsilon: 0.01
# Episode: 1123, Score: 0, Epsilon: 0.01
# Episode: 1124, Score: 1, Epsilon: 0.01
# Episode: 1125, Score: 0, Epsilon: 0.01
# Episode: 1126, Score: 0, Epsilon: 0.01
# Episode: 1127, Score: 0, Epsilon: 0.01
# Episode: 1128, Score: 1, Epsilon: 0.01
# Episode: 1129, Score: 0, Epsilon: 0.01
# Episode: 1130, Score: 0, Epsilon: 0.01
# Episode: 1131, Score: 0, Epsilon: 0.01
# Episode: 1132, Score: 0, Epsilon: 0.01
# Episode: 1133, Score: 0, Epsilon: 0.01
# Episode: 1134, Score: 0, Epsilon: 0.01
# Episode: 1135, Score: 1, Epsilon: 0.01
# Episode: 1136, Score: 0, Epsilon: 0.01
# Episode: 1137, Score: 0, Epsilon: 0.01
# Episode: 1138, Score: 0, Epsilon: 0.01
# Episode: 1139, Score: 0, Epsilon: 0.01
# Episode: 1140, Score: 0, Epsilon: 0.01
# Episode: 1141, Score: 0, Epsilon: 0.01
# Episode: 1142, Score: 0, Epsilon: 0.01
# Episode: 1143, Score: 0, Epsilon: 0.01
# Episode: 1144, Score: 0, Epsilon: 0.01
# Episode: 1145, Score: 0, Epsilon: 0.01
# Episode: 1146, Score: 0, Epsilon: 0.01
# Episode: 1147, Score: 0, Epsilon: 0.01
# Episode: 1148, Score: 0, Epsilon: 0.01
# Episode: 1149, Score: 0, Epsilon: 0.01
# Episode: 1150, Score: 0, Epsilon: 0.01
# Episode: 1151, Score: 0, Epsilon: 0.01
# Episode: 1152, Score: 0, Epsilon: 0.01
# Episode: 1153, Score: 0, Epsilon: 0.01
# Episode: 1154, Score: 0, Epsilon: 0.01
# Episode: 1155, Score: 0, Epsilon: 0.01
# Episode: 1156, Score: 0, Epsilon: 0.01
# Episode: 1157, Score: 0, Epsilon: 0.01
# Episode: 1158, Score: 0, Epsilon: 0.01
# Episode: 1159, Score: 0, Epsilon: 0.01
# Episode: 1160, Score: 0, Epsilon: 0.01
# Episode: 1161, Score: 0, Epsilon: 0.01
# Episode: 1162, Score: 0, Epsilon: 0.01
# Episode: 1163, Score: 0, Epsilon: 0.01
# Episode: 1164, Score: 0, Epsilon: 0.01
# Episode: 1165, Score: 0, Epsilon: 0.01
# Episode: 1166, Score: 0, Epsilon: 0.01
# Episode: 1167, Score: 0, Epsilon: 0.01
# Episode: 1168, Score: 1, Epsilon: 0.01
# Episode: 1169, Score: 0, Epsilon: 0.01
# Episode: 1170, Score: 0, Epsilon: 0.01
# Episode: 1171, Score: 0, Epsilon: 0.01
# Episode: 1172, Score: 0, Epsilon: 0.01
# Episode: 1173, Score: 0, Epsilon: 0.01
# Episode: 1174, Score: 0, Epsilon: 0.01
# Episode: 1175, Score: 0, Epsilon: 0.01
# Episode: 1176, Score: 0, Epsilon: 0.01
# Episode: 1177, Score: 1, Epsilon: 0.01
# Episode: 1178, Score: 0, Epsilon: 0.01
# Episode: 1179, Score: 0, Epsilon: 0.01
# Episode: 1180, Score: 0, Epsilon: 0.01
# Episode: 1181, Score: 0, Epsilon: 0.01
# Episode: 1182, Score: 0, Epsilon: 0.01
# Episode: 1183, Score: 0, Epsilon: 0.01
# Episode: 1184, Score: 0, Epsilon: 0.01
# Episode: 1185, Score: 1, Epsilon: 0.01
# Episode: 1186, Score: 0, Epsilon: 0.01
# Episode: 1187, Score: 0, Epsilon: 0.01
# Episode: 1188, Score: 0, Epsilon: 0.01
# Episode: 1189, Score: 0, Epsilon: 0.01
# Episode: 1190, Score: 0, Epsilon: 0.01
# Episode: 1191, Score: 0, Epsilon: 0.01
# Episode: 1192, Score: 0, Epsilon: 0.01
# Episode: 1193, Score: 0, Epsilon: 0.01
# Episode: 1194, Score: 0, Epsilon: 0.01
# Episode: 1195, Score: 0, Epsilon: 0.01
# Episode: 1196, Score: 0, Epsilon: 0.01
# Episode: 1197, Score: 0, Epsilon: 0.01
# Episode: 1198, Score: 0, Epsilon: 0.01
# Episode: 1199, Score: 1, Epsilon: 0.01
# Episode: 1200, Score: 0, Epsilon: 0.01
# Episode: 1201, Score: 0, Epsilon: 0.01
# Episode: 1202, Score: 0, Epsilon: 0.01
# Episode: 1203, Score: 0, Epsilon: 0.01
# Episode: 1204, Score: 0, Epsilon: 0.01
# Episode: 1205, Score: 0, Epsilon: 0.01
# Episode: 1206, Score: 0, Epsilon: 0.01
# Episode: 1207, Score: 0, Epsilon: 0.01
# Episode: 1208, Score: 0, Epsilon: 0.01
# Episode: 1209, Score: 0, Epsilon: 0.01
# Episode: 1210, Score: 0, Epsilon: 0.01
# Episode: 1211, Score: 0, Epsilon: 0.01
# Episode: 1212, Score: 0, Epsilon: 0.01
# Episode: 1213, Score: 0, Epsilon: 0.01
# Episode: 1214, Score: 0, Epsilon: 0.01
# Episode: 1215, Score: 0, Epsilon: 0.01
# Episode: 1216, Score: 0, Epsilon: 0.01
# Episode: 1217, Score: 0, Epsilon: 0.01
# Episode: 1218, Score: 0, Epsilon: 0.01
# Episode: 1219, Score: 0, Epsilon: 0.01
# Episode: 1220, Score: 0, Epsilon: 0.01
# Episode: 1221, Score: 0, Epsilon: 0.01
# Episode: 1222, Score: 0, Epsilon: 0.01
# Episode: 1223, Score: 0, Epsilon: 0.01
# Episode: 1224, Score: 1, Epsilon: 0.01
# Episode: 1225, Score: 1, Epsilon: 0.01
# Episode: 1226, Score: 0, Epsilon: 0.01
# Episode: 1227, Score: 0, Epsilon: 0.01
# Episode: 1228, Score: 0, Epsilon: 0.01
# Episode: 1229, Score: 0, Epsilon: 0.01
# Episode: 1230, Score: 0, Epsilon: 0.01
# Episode: 1231, Score: 0, Epsilon: 0.01
# Episode: 1232, Score: 0, Epsilon: 0.01
# Episode: 1233, Score: 0, Epsilon: 0.01
# Episode: 1234, Score: 0, Epsilon: 0.01
# Episode: 1235, Score: 0, Epsilon: 0.01
# Episode: 1236, Score: 0, Epsilon: 0.01
# Episode: 1237, Score: 0, Epsilon: 0.01
# Episode: 1238, Score: 0, Epsilon: 0.01
# Episode: 1239, Score: 0, Epsilon: 0.01
# Episode: 1240, Score: 0, Epsilon: 0.01
# Episode: 1241, Score: 0, Epsilon: 0.01
# Episode: 1242, Score: 1, Epsilon: 0.01
# Episode: 1243, Score: 0, Epsilon: 0.01
# Episode: 1244, Score: 0, Epsilon: 0.01
# Episode: 1245, Score: 0, Epsilon: 0.01
# Episode: 1246, Score: 0, Epsilon: 0.01
# Episode: 1247, Score: 0, Epsilon: 0.01
# Episode: 1248, Score: 0, Epsilon: 0.01
# Episode: 1249, Score: 0, Epsilon: 0.01
# Episode: 1250, Score: 0, Epsilon: 0.01
# Episode: 1251, Score: 0, Epsilon: 0.01
# Episode: 1252, Score: 0, Epsilon: 0.01
# Episode: 1253, Score: 0, Epsilon: 0.01
# Episode: 1254, Score: 0, Epsilon: 0.01
# Episode: 1255, Score: 0, Epsilon: 0.01
# Episode: 1256, Score: 0, Epsilon: 0.01
# Episode: 1257, Score: 0, Epsilon: 0.01
# Episode: 1258, Score: 0, Epsilon: 0.01
# Episode: 1259, Score: 0, Epsilon: 0.01
# Episode: 1260, Score: 0, Epsilon: 0.01
# Episode: 1261, Score: 0, Epsilon: 0.01
# Episode: 1262, Score: 0, Epsilon: 0.01
# Episode: 1263, Score: 0, Epsilon: 0.01
# Episode: 1264, Score: 0, Epsilon: 0.01
# Episode: 1265, Score: 0, Epsilon: 0.01
# Episode: 1266, Score: 0, Epsilon: 0.01
# Episode: 1267, Score: 0, Epsilon: 0.01
# Episode: 1268, Score: 0, Epsilon: 0.01
# Episode: 1269, Score: 0, Epsilon: 0.01
# Episode: 1270, Score: 0, Epsilon: 0.01
# Episode: 1271, Score: 0, Epsilon: 0.01
# Episode: 1272, Score: 0, Epsilon: 0.01
# Episode: 1273, Score: 0, Epsilon: 0.01
# Episode: 1274, Score: 0, Epsilon: 0.01
# Episode: 1275, Score: 0, Epsilon: 0.01
# Episode: 1276, Score: 0, Epsilon: 0.01
# Episode: 1277, Score: 0, Epsilon: 0.01
# Episode: 1278, Score: 0, Epsilon: 0.01
# Episode: 1279, Score: 0, Epsilon: 0.01
# Episode: 1280, Score: 1, Epsilon: 0.01
# Episode: 1281, Score: 1, Epsilon: 0.01
# Episode: 1282, Score: 1, Epsilon: 0.01
# Episode: 1283, Score: 0, Epsilon: 0.01
# Episode: 1284, Score: 0, Epsilon: 0.01
# Episode: 1285, Score: 0, Epsilon: 0.01
# Episode: 1286, Score: 0, Epsilon: 0.01
# Episode: 1287, Score: 0, Epsilon: 0.01
# Episode: 1288, Score: 0, Epsilon: 0.01
# Episode: 1289, Score: 0, Epsilon: 0.01
# Episode: 1290, Score: 0, Epsilon: 0.01
# ...
# Episode: 3088, Score: 0, Epsilon: 0.01
# Episode: 3089, Score: 0, Epsilon: 0.01
# Episode: 3090, Score: 0, Epsilon: 0.01
# Episode: 3091, Score: 0, Epsilon: 0.01
# Episode: 3092, Score: 0, Epsilon: 0.01
# Episode: 3093, Score: 0, Epsilon: 0.01
# Episode: 3094, Score: 1, Epsilon: 0.01
# Episode: 3095, Score: 0, Epsilon: 0.01
# Episode: 3096, Score: 0, Epsilon: 0.01
# Episode: 3097, Score: 0, Epsilon: 0.01
# Episode: 3098, Score: 0, Epsilon: 0.01
# Episode: 3099, Score: 0, Epsilon: 0.01
# Episode: 3100, Score: 0, Epsilon: 0.01
# Episode: 3101, Score: 0, Epsilon: 0.01
# Episode: 3102, Score: 0, Epsilon: 0.01
# Episode: 3103, Score: 0, Epsilon: 0.01
# Episode: 3104, Score: 0, Epsilon: 0.01
# Episode: 3105, Score: 0, Epsilon: 0.01
# Episode: 3106, Score: 0, Epsilon: 0.01
# Episode: 3107, Score: 0, Epsilon: 0.01
# Episode: 3108, Score: 0, Epsilon: 0.01
# Episode: 3109, Score: 0, Epsilon: 0.01
# Episode: 3110, Score: 0, Epsilon: 0.01
# Episode: 3111, Score: 0, Epsilon: 0.01
# Episode: 3112, Score: 0, Epsilon: 0.01
# Episode: 3113, Score: 0, Epsilon: 0.01
# Episode: 3114, Score: 0, Epsilon: 0.01
# Episode: 3115, Score: 0, Epsilon: 0.01
# Episode: 3116, Score: 0, Epsilon: 0.01
# Episode: 3117, Score: 0, Epsilon: 0.01
# Episode: 3118, Score: 0, Epsilon: 0.01
# Episode: 3119, Score: 0, Epsilon: 0.01
# Episode: 3120, Score: 0, Epsilon: 0.01
# Episode: 3121, Score: 0, Epsilon: 0.01
# Episode: 3122, Score: 0, Epsilon: 0.01
# Episode: 3123, Score: 0, Epsilon: 0.01
# Episode: 3124, Score: 0, Epsilon: 0.01
# Episode: 3125, Score: 0, Epsilon: 0.01
# Episode: 3126, Score: 0, Epsilon: 0.01
# Episode: 3127, Score: 0, Epsilon: 0.01
# Episode: 3128, Score: 0, Epsilon: 0.01
# Episode: 3129, Score: 0, Epsilon: 0.01
# Episode: 3130, Score: 0, Epsilon: 0.01
# Episode: 3131, Score: 1, Epsilon: 0.01
# Episode: 3132, Score: 0, Epsilon: 0.01
# Episode: 3133, Score: 1, Epsilon: 0.01
# Episode: 3134, Score: 0, Epsilon: 0.01
# Episode: 3135, Score: 0, Epsilon: 0.01
# Episode: 3136, Score: 0, Epsilon: 0.01
# Episode: 3137, Score: 0, Epsilon: 0.01
# Episode: 3138, Score: 0, Epsilon: 0.01
# Episode: 3139, Score: 0, Epsilon: 0.01
# Episode: 3140, Score: 0, Epsilon: 0.01
# Episode: 3141, Score: 1, Epsilon: 0.01
# Episode: 3142, Score: 0, Epsilon: 0.01
# Episode: 3143, Score: 0, Epsilon: 0.01
# Episode: 3144, Score: 0, Epsilon: 0.01
# Episode: 3145, Score: 0, Epsilon: 0.01
# Episode: 3146, Score: 0, Epsilon: 0.01
# Episode: 3147, Score: 0, Epsilon: 0.01
# Episode: 3148, Score: 0, Epsilon: 0.01
# Episode: 3149, Score: 0, Epsilon: 0.01
# Episode: 3150, Score: 0, Epsilon: 0.01
# Episode: 3151, Score: 0, Epsilon: 0.01
# Episode: 3152, Score: 0, Epsilon: 0.01
# Episode: 3153, Score: 0, Epsilon: 0.01
# Episode: 3154, Score: 0, Epsilon: 0.01
# Episode: 3155, Score: 0, Epsilon: 0.01
# Episode: 3156, Score: 0, Epsilon: 0.01
# Episode: 3157, Score: 0, Epsilon: 0.01
# Episode: 3158, Score: 0, Epsilon: 0.01
# Episode: 3159, Score: 0, Epsilon: 0.01
# Episode: 3160, Score: 1, Epsilon: 0.01
# Episode: 3161, Score: 0, Epsilon: 0.01
# Episode: 3162, Score: 0, Epsilon: 0.01
# Episode: 3163, Score: 0, Epsilon: 0.01
# Episode: 3164, Score: 0, Epsilon: 0.01
# Episode: 3165, Score: 0, Epsilon: 0.01
# Episode: 3166, Score: 0, Epsilon: 0.01
# Episode: 3167, Score: 0, Epsilon: 0.01
# Episode: 3168, Score: 0, Epsilon: 0.01
# Episode: 3169, Score: 0, Epsilon: 0.01
# Episode: 3170, Score: 1, Epsilon: 0.01
# Episode: 3171, Score: 0, Epsilon: 0.01
# Episode: 3172, Score: 0, Epsilon: 0.01
# Episode: 3173, Score: 0, Epsilon: 0.01
# Episode: 3174, Score: 1, Epsilon: 0.01
# Episode: 3175, Score: 0, Epsilon: 0.01
# Episode: 3176, Score: 0, Epsilon: 0.01
# Episode: 3177, Score: 0, Epsilon: 0.01
# Episode: 3178, Score: 0, Epsilon: 0.01
# Episode: 3179, Score: 1, Epsilon: 0.01
# Episode: 3180, Score: 0, Epsilon: 0.01
# Episode: 3181, Score: 0, Epsilon: 0.01
# Episode: 3182, Score: 0, Epsilon: 0.01
# Episode: 3183, Score: 0, Epsilon: 0.01
# Episode: 3184, Score: 0, Epsilon: 0.01
# Episode: 3185, Score: 0, Epsilon: 0.01
# Episode: 3186, Score: 0, Epsilon: 0.01
# Episode: 3187, Score: 0, Epsilon: 0.01
# Episode: 3188, Score: 0, Epsilon: 0.01
# Episode: 3189, Score: 0, Epsilon: 0.01
# Episode: 3190, Score: 0, Epsilon: 0.01
# Episode: 3191, Score: 0, Epsilon: 0.01
# Episode: 3192, Score: 0, Epsilon: 0.01
# Episode: 3193, Score: 0, Epsilon: 0.01
# Episode: 3194, Score: 0, Epsilon: 0.01
# Episode: 3195, Score: 0, Epsilon: 0.01
# Episode: 3196, Score: 0, Epsilon: 0.01
# Episode: 3197, Score: 0, Epsilon: 0.01
# Episode: 3198, Score: 0, Epsilon: 0.01
# Episode: 3199, Score: 0, Epsilon: 0.01
# Episode: 3200, Score: 0, Epsilon: 0.01
# Episode: 3201, Score: 0, Epsilon: 0.01
# Episode: 3202, Score: 0, Epsilon: 0.01
# Episode: 3203, Score: 0, Epsilon: 0.01
# Episode: 3204, Score: 0, Epsilon: 0.01
# Episode: 3205, Score: 0, Epsilon: 0.01
# Episode: 3206, Score: 0, Epsilon: 0.01
# Episode: 3207, Score: 0, Epsilon: 0.01
# Episode: 3208, Score: 0, Epsilon: 0.01
# Episode: 3209, Score: 0, Epsilon: 0.01
# Episode: 3210, Score: 0, Epsilon: 0.01
# Episode: 3211, Score: 0, Epsilon: 0.01
# Episode: 3212, Score: 0, Epsilon: 0.01
# Episode: 3213, Score: 0, Epsilon: 0.01
# Episode: 3214, Score: 0, Epsilon: 0.01
# Episode: 3215, Score: 0, Epsilon: 0.01
# Episode: 3216, Score: 0, Epsilon: 0.01
# Episode: 3217, Score: 0, Epsilon: 0.01
# Episode: 3218, Score: 0, Epsilon: 0.01
# Episode: 3219, Score: 0, Epsilon: 0.01
# Episode: 3220, Score: 0, Epsilon: 0.01
# Episode: 3221, Score: 0, Epsilon: 0.01
# Episode: 3222, Score: 0, Epsilon: 0.01
# Episode: 3223, Score: 0, Epsilon: 0.01
# Episode: 3224, Score: 0, Epsilon: 0.01
# Episode: 3225, Score: 0, Epsilon: 0.01
# Episode: 3226, Score: 0, Epsilon: 0.01
# Episode: 3227, Score: 0, Epsilon: 0.01
# Episode: 3228, Score: 0, Epsilon: 0.01
# Episode: 3229, Score: 0, Epsilon: 0.01
# Episode: 3230, Score: 0, Epsilon: 0.01
# Episode: 3231, Score: 0, Epsilon: 0.01
# Episode: 3232, Score: 0, Epsilon: 0.01
# Episode: 3233, Score: 0, Epsilon: 0.01
# Episode: 3234, Score: 0, Epsilon: 0.01
# Episode: 3235, Score: 0, Epsilon: 0.01
# Episode: 3236, Score: 0, Epsilon: 0.01
# Episode: 3237, Score: 0, Epsilon: 0.01
# Episode: 3238, Score: 0, Epsilon: 0.01
# Episode: 3239, Score: 0, Epsilon: 0.01
# Episode: 3240, Score: 0, Epsilon: 0.01
# Episode: 3241, Score: 0, Epsilon: 0.01
# Episode: 3242, Score: 0, Epsilon: 0.01
# Episode: 3243, Score: 1, Epsilon: 0.01
# Episode: 3244, Score: 0, Epsilon: 0.01
# Episode: 3245, Score: 0, Epsilon: 0.01
# Episode: 3246, Score: 0, Epsilon: 0.01
# Episode: 3247, Score: 1, Epsilon: 0.01
# Episode: 3248, Score: 0, Epsilon: 0.01
# Episode: 3249, Score: 0, Epsilon: 0.01
# Episode: 3250, Score: 0, Epsilon: 0.01
# Episode: 3251, Score: 0, Epsilon: 0.01
# Episode: 3252, Score: 0, Epsilon: 0.01
# Episode: 3253, Score: 0, Epsilon: 0.01
# Episode: 3254, Score: 0, Epsilon: 0.01
# Episode: 3255, Score: 0, Epsilon: 0.01
# Episode: 3256, Score: 0, Epsilon: 0.01
# Episode: 3257, Score: 0, Epsilon: 0.01
# Episode: 3258, Score: 0, Epsilon: 0.01
# Episode: 3259, Score: 0, Epsilon: 0.01
# Episode: 3260, Score: 0, Epsilon: 0.01
# Episode: 3261, Score: 1, Epsilon: 0.01
# Episode: 3262, Score: 0, Epsilon: 0.01
# Episode: 3263, Score: 0, Epsilon: 0.01
# Episode: 3264, Score: 0, Epsilon: 0.01
# Episode: 3265, Score: 0, Epsilon: 0.01
# Episode: 3266, Score: 0, Epsilon: 0.01
# Episode: 3267, Score: 0, Epsilon: 0.01
# Episode: 3268, Score: 0, Epsilon: 0.01
# Episode: 3269, Score: 1, Epsilon: 0.01
# Episode: 3270, Score: 0, Epsilon: 0.01
# Episode: 3271, Score: 0, Epsilon: 0.01
# Episode: 3272, Score: 0, Epsilon: 0.01
# Episode: 3273, Score: 1, Epsilon: 0.01
# Episode: 3274, Score: 1, Epsilon: 0.01
# Episode: 3275, Score: 0, Epsilon: 0.01
# Episode: 3276, Score: 0, Epsilon: 0.01
# Episode: 3277, Score: 0, Epsilon: 0.01
# Episode: 3278, Score: 1, Epsilon: 0.01
# Episode: 3279, Score: 0, Epsilon: 0.01
# Episode: 3280, Score: 0, Epsilon: 0.01
# Episode: 3281, Score: 0, Epsilon: 0.01
# Episode: 3282, Score: 0, Epsilon: 0.01
# Episode: 3283, Score: 0, Epsilon: 0.01
# Episode: 3284, Score: 0, Epsilon: 0.01
# Episode: 3285, Score: 0, Epsilon: 0.01
# Episode: 3286, Score: 0, Epsilon: 0.01
# Episode: 3287, Score: 0, Epsilon: 0.01
# Episode: 3288, Score: 0, Epsilon: 0.01
# Episode: 3289, Score: 0, Epsilon: 0.01
# Episode: 3290, Score: 1, Epsilon: 0.01
# Episode: 3291, Score: 0, Epsilon: 0.01
# Episode: 3292, Score: 0, Epsilon: 0.01
# Episode: 3293, Score: 0, Epsilon: 0.01
# Episode: 3294, Score: 0, Epsilon: 0.01
# Episode: 3295, Score: 0, Epsilon: 0.01
# Episode: 3296, Score: 1, Epsilon: 0.01
# Episode: 3297, Score: 0, Epsilon: 0.01
# Episode: 3298, Score: 0, Epsilon: 0.01
# Episode: 3299, Score: 0, Epsilon: 0.01
# Episode: 3300, Score: 0, Epsilon: 0.01
# Episode: 3301, Score: 0, Epsilon: 0.01
# Episode: 3302, Score: 0, Epsilon: 0.01
# Episode: 3303, Score: 0, Epsilon: 0.01
# Episode: 3304, Score: 0, Epsilon: 0.01
# Episode: 3305, Score: 0, Epsilon: 0.01
# Episode: 3306, Score: 0, Epsilon: 0.01
# Episode: 3307, Score: 0, Epsilon: 0.01
# Episode: 3308, Score: 0, Epsilon: 0.01
# Episode: 3309, Score: 0, Epsilon: 0.01
# Episode: 3310, Score: 0, Epsilon: 0.01
# Episode: 3311, Score: 0, Epsilon: 0.01
# Episode: 3312, Score: 0, Epsilon: 0.01
# Episode: 3313, Score: 0, Epsilon: 0.01
# Episode: 3314, Score: 0, Epsilon: 0.01
# Episode: 3315, Score: 1, Epsilon: 0.01
# Episode: 3316, Score: 0, Epsilon: 0.01
# Episode: 3317, Score: 0, Epsilon: 0.01
# Episode: 3318, Score: 2, Epsilon: 0.01
# Episode: 3319, Score: 0, Epsilon: 0.01
# Episode: 3320, Score: 0, Epsilon: 0.01
# Episode: 3321, Score: 0, Epsilon: 0.01
# Episode: 3322, Score: 0, Epsilon: 0.01
# Episode: 3323, Score: 0, Epsilon: 0.01
# Episode: 3324, Score: 0, Epsilon: 0.01
# Episode: 3325, Score: 0, Epsilon: 0.01
# Episode: 3326, Score: 0, Epsilon: 0.01
# Episode: 3328, Score: 0, Epsilon: 0.01
# Episode: 3329, Score: 0, Epsilon: 0.01
# Episode: 3330, Score: 0, Epsilon: 0.01
# Episode: 3331, Score: 0, Epsilon: 0.01
# Episode: 3332, Score: 0, Epsilon: 0.01
# Episode: 3333, Score: 0, Epsilon: 0.01
# Episode: 3335, Score: 0, Epsilon: 0.01
# Episode: 3336, Score: 0, Epsilon: 0.01
# Episode: 3338, Score: 0, Epsilon: 0.01
# Episode: 3339, Score: 0, Epsilon: 0.01
# Episode: 3340, Score: 0, Epsilon: 0.01
# Episode: 3341, Score: 0, Epsilon: 0.01
# Episode: 3342, Score: 0, Epsilon: 0.01
# Episode: 3343, Score: 0, Epsilon: 0.01
# Episode: 3344, Score: 0, Epsilon: 0.01
# Episode: 3345, Score: 0, Epsilon: 0.01
# Episode: 3346, Score: 1, Epsilon: 0.01
# Episode: 3347, Score: 0, Epsilon: 0.01
# Episode: 3348, Score: 0, Epsilon: 0.01
# Episode: 3349, Score: 0, Epsilon: 0.01
# Episode: 3350, Score: 0, Epsilon: 0.01
# Episode: 3351, Score: 0, Epsilon: 0.01
# Episode: 3352, Score: 0, Epsilon: 0.01
# Episode: 3353, Score: 0, Epsilon: 0.01
# Episode: 3354, Score: 0, Epsilon: 0.01
# Episode: 3355, Score: 0, Epsilon: 0.01
# Episode: 3356, Score: 0, Epsilon: 0.01
# Episode: 3357, Score: 0, Epsilon: 0.01
# Episode: 3358, Score: 1, Epsilon: 0.01
# Episode: 3359, Score: 1, Epsilon: 0.01
# Episode: 3360, Score: 0, Epsilon: 0.01
# Episode: 3361, Score: 0, Epsilon: 0.01
# Episode: 3363, Score: 0, Epsilon: 0.01
# Episode: 3364, Score: 0, Epsilon: 0.01
# Episode: 3365, Score: 0, Epsilon: 0.01
# Episode: 3366, Score: 0, Epsilon: 0.01
# Episode: 3367, Score: 0, Epsilon: 0.01
# Episode: 3368, Score: 0, Epsilon: 0.01
# Episode: 3370, Score: 0, Epsilon: 0.01
# Episode: 3371, Score: 0, Epsilon: 0.01
# Episode: 3372, Score: 0, Epsilon: 0.01
# Episode: 3373, Score: 0, Epsilon: 0.01
# Episode: 3374, Score: 0, Epsilon: 0.01
# Episode: 3375, Score: 0, Epsilon: 0.01
# Episode: 3376, Score: 0, Epsilon: 0.01
# Episode: 3377, Score: 0, Epsilon: 0.01
# Episode: 3378, Score: 1, Epsilon: 0.01
# Episode: 3379, Score: 0, Epsilon: 0.01
# Episode: 3380, Score: 1, Epsilon: 0.01
# Episode: 3381, Score: 0, Epsilon: 0.01
# Episode: 3382, Score: 0, Epsilon: 0.01
# Episode: 3383, Score: 0, Epsilon: 0.01
# Episode: 3384, Score: 0, Epsilon: 0.01
# Episode: 3385, Score: 1, Epsilon: 0.01
# Episode: 3386, Score: 0, Epsilon: 0.01
# Episode: 3387, Score: 0, Epsilon: 0.01
# Episode: 3388, Score: 0, Epsilon: 0.01
# Episode: 3389, Score: 0, Epsilon: 0.01
# Episode: 3390, Score: 0, Epsilon: 0.01
# Episode: 3391, Score: 0, Epsilon: 0.01
# Episode: 3392, Score: 0, Epsilon: 0.01
# Episode: 3393, Score: 0, Epsilon: 0.01
# Episode: 3394, Score: 0, Epsilon: 0.01
# Episode: 3395, Score: 1, Epsilon: 0.01
# Episode: 3396, Score: 0, Epsilon: 0.01
# Episode: 3397, Score: 1, Epsilon: 0.01
# Episode: 3398, Score: 0, Epsilon: 0.01
# Episode: 3399, Score: 0, Epsilon: 0.01
# Episode: 3400, Score: 0, Epsilon: 0.01
# Episode: 3401, Score: 0, Epsilon: 0.01
# Episode: 3402, Score: 0, Epsilon: 0.01
# Episode: 3403, Score: 0, Epsilon: 0.01
# Episode: 3404, Score: 0, Epsilon: 0.01
# Episode: 3405, Score: 0, Epsilon: 0.01
# Episode: 3406, Score: 0, Epsilon: 0.01
# Episode: 3407, Score: 1, Epsilon: 0.01
# Episode: 3408, Score: 0, Epsilon: 0.01
# Episode: 3409, Score: 0, Epsilon: 0.01
# Episode: 3410, Score: 0, Epsilon: 0.01
# Episode: 3411, Score: 0, Epsilon: 0.01
# Episode: 3413, Score: 0, Epsilon: 0.01
# Episode: 3414, Score: 0, Epsilon: 0.01
# Episode: 3415, Score: 0, Epsilon: 0.01
# Episode: 3416, Score: 1, Epsilon: 0.01
# Episode: 3417, Score: 1, Epsilon: 0.01
# Episode: 3418, Score: 0, Epsilon: 0.01
# Episode: 3419, Score: 0, Epsilon: 0.01
# Episode: 3420, Score: 0, Epsilon: 0.01
# Episode: 3421, Score: 0, Epsilon: 0.01
# Episode: 3422, Score: 0, Epsilon: 0.01
# Episode: 3423, Score: 0, Epsilon: 0.01
# Episode: 3424, Score: 0, Epsilon: 0.01
# Episode: 3425, Score: 0, Epsilon: 0.01
# Episode: 3426, Score: 0, Epsilon: 0.01
# Episode: 3427, Score: 0, Epsilon: 0.01
# Episode: 3428, Score: 0, Epsilon: 0.01
# Episode: 3429, Score: 0, Epsilon: 0.01
# Episode: 3430, Score: 0, Epsilon: 0.01
# Episode: 3431, Score: 0, Epsilon: 0.01
# Episode: 3432, Score: 0, Epsilon: 0.01
# Episode: 3433, Score: 0, Epsilon: 0.01
# Episode: 3434, Score: 0, Epsilon: 0.01
# Episode: 3435, Score: 0, Epsilon: 0.01
# Episode: 3436, Score: 0, Epsilon: 0.01
# Episode: 3437, Score: 0, Epsilon: 0.01
# Episode: 3439, Score: 0, Epsilon: 0.01
# Episode: 3440, Score: 0, Epsilon: 0.01
# Episode: 3441, Score: 0, Epsilon: 0.01
# Episode: 3442, Score: 0, Epsilon: 0.01
# Episode: 3443, Score: 0, Epsilon: 0.01
# Episode: 3444, Score: 0, Epsilon: 0.01
# Episode: 3445, Score: 0, Epsilon: 0.01
# Episode: 3446, Score: 0, Epsilon: 0.01
# Episode: 3447, Score: 0, Epsilon: 0.01
# Episode: 3448, Score: 0, Epsilon: 0.01
# Episode: 3449, Score: 0, Epsilon: 0.01
# Episode: 3450, Score: 0, Epsilon: 0.01
# Episode: 3451, Score: 0, Epsilon: 0.01
# Episode: 3452, Score: 0, Epsilon: 0.01
# Episode: 3453, Score: 0, Epsilon: 0.01
# Episode: 3454, Score: 0, Epsilon: 0.01
# Episode: 3455, Score: 0, Epsilon: 0.01
# Episode: 3456, Score: 0, Epsilon: 0.01
# Episode: 3457, Score: 0, Epsilon: 0.01
# Episode: 3459, Score: 0, Epsilon: 0.01
# Episode: 3460, Score: 0, Epsilon: 0.01
# Episode: 3461, Score: 0, Epsilon: 0.01
# Episode: 3463, Score: 0, Epsilon: 0.01
# Episode: 3464, Score: 0, Epsilon: 0.01
# Episode: 3465, Score: 1, Epsilon: 0.01
# Episode: 3467, Score: 0, Epsilon: 0.01
# Episode: 3468, Score: 0, Epsilon: 0.01
# Episode: 3469, Score: 0, Epsilon: 0.01
# Episode: 3470, Score: 0, Epsilon: 0.01
# Episode: 3471, Score: 0, Epsilon: 0.01
# Episode: 3473, Score: 0, Epsilon: 0.01
# Episode: 3474, Score: 0, Epsilon: 0.01
# Episode: 3475, Score: 0, Epsilon: 0.01
# Episode: 3476, Score: 0, Epsilon: 0.01
# Episode: 3477, Score: 0, Epsilon: 0.01
# Episode: 3479, Score: 0, Epsilon: 0.01
# Episode: 3480, Score: 0, Epsilon: 0.01
# Episode: 3481, Score: 0, Epsilon: 0.01
# Episode: 3482, Score: 0, Epsilon: 0.01
# Episode: 3483, Score: 0, Epsilon: 0.01
# Episode: 3485, Score: 0, Epsilon: 0.01
# Episode: 3486, Score: 0, Epsilon: 0.01
# Episode: 3487, Score: 0, Epsilon: 0.01
# Episode: 3488, Score: 0, Epsilon: 0.01
# Episode: 3489, Score: 0, Epsilon: 0.01
# Episode: 3490, Score: 0, Epsilon: 0.01
# Episode: 3491, Score: 0, Epsilon: 0.01
# Episode: 3492, Score: 0, Epsilon: 0.01
# Episode: 3495, Score: 0, Epsilon: 0.01
# Episode: 3496, Score: 0, Epsilon: 0.01
# Episode: 3497, Score: 0, Epsilon: 0.01
# Episode: 3498, Score: 0, Epsilon: 0.01
# Episode: 3499, Score: 0, Epsilon: 0.01
# Episode: 3500, Score: 0, Epsilon: 0.01
# Episode: 3501, Score: 0, Epsilon: 0.01
# Episode: 3502, Score: 0, Epsilon: 0.01
# Episode: 3503, Score: 0, Epsilon: 0.01
# Episode: 3505, Score: 0, Epsilon: 0.01
# Episode: 3506, Score: 0, Epsilon: 0.01
# Episode: 3507, Score: 0, Epsilon: 0.01
# Episode: 3508, Score: 0, Epsilon: 0.01
# Episode: 3509, Score: 0, Epsilon: 0.01
# Episode: 3510, Score: 0, Epsilon: 0.01
# Episode: 3511, Score: 0, Epsilon: 0.01
# Episode: 3512, Score: 0, Epsilon: 0.01
# Episode: 3513, Score: 0, Epsilon: 0.01

# %%
def load_model(model_type, model_path, state_size, hidden_size, action_size):
    if model_type == 'RNN':
        model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
    elif model_type == 'GRU':
        model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
    else:  # Default to LSTM
        model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

def play_game(model, game, display=True):
    state = game.reset()
    hidden = model.init_hidden(1)
    done = False
    clock = pygame.time.Clock()
    
    while not done:
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        with torch.no_grad():
            action_values, hidden = model(state, hidden)
        action = torch.argmax(action_values[0]).item()
        
        next_state, _, done = game.step(action)
        state = next_state
        
        if display:
            game.render()
            clock.tick(10) 

    print(f"Final Score: {game.score}")

if __name__ == "__main__":
    model_type = 'RNN'
    model_path = "rnn/rnn_snake_model_10500.pth"

    state_size = 6
    hidden_size = 64
    action_size = 4
    model = load_model(model_type, model_path, state_size, hidden_size, action_size)

    game = SnakeGameAI()

    play_game(model, game)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 41
#      39 hidden_size = 64
#      40 action_size = 4
# ---> 41 model = load_model(model_type, model_path, state_size, hidden_size, action_size)
#      43 # Initialize the game
#      44 game = SnakeGameAI()
#
# Cell In[1], line 3, in load_model(model_type, model_path, state_size, hidden_size, action_size)
#       1 def load_model(model_type, model_path, state_size, hidden_size, action_size):
#       2     if model_type == 'RNN':
# ----> 3         model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
#       4     elif model_type == 'GRU':
#       5         model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
#
# NameError: name 'RNNSnakeNet' is not defined
