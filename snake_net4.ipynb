# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import time
import pygame

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LSTMSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.hidden_size).to(device),
                torch.zeros(1, batch_size, self.hidden_size).to(device))

class RNNSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.rnn(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class GRUSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GRUSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.gru(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class DQNAgent:
    def __init__(self, state_size, action_size, hidden_size, model_type='LSTM'):
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        
        if model_type == 'RNN':
            self.model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
        elif model_type == 'GRU':
            self.model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
        else:  # Default to LSTM
            self.model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)

        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state, hidden):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size), hidden
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        action_values, hidden = self.model(state, hidden)
        return torch.argmax(action_values[0]).item(), hidden

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
            next_state = torch.FloatTensor(next_state).unsqueeze(0).unsqueeze(0).to(device)
            target = reward
            if not done:
                next_hidden = self.model.init_hidden(1)
                target = (reward + self.gamma * torch.max(self.model(next_state, next_hidden)[0][0])).item()
            target_f = self.model(state, self.model.init_hidden(1))[0]
            target_f[0][action] = target
            self.optimizer.zero_grad()
            loss = self.criterion(target_f, self.model(state, self.model.init_hidden(1))[0])
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

class SnakeGameAI:
    def __init__(self, width=640, height=480, snake_size=20):
        self.width = width
        self.height = height
        self.snake_size = snake_size
        self.reset()

    def reset(self):
        self.x1 = self.width / 2
        self.y1 = self.height / 2
        self.x1_change = 0
        self.y1_change = 0
        self.snake_List = []
        self.Length_of_snake = 1
        self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
        self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
        self.score = 0
        return self.get_state()

    def step(self, action):
        if action == 0:  # LEFT
            self.x1_change = -self.snake_size
            self.y1_change = 0
        elif action == 1:  # RIGHT
            self.x1_change = self.snake_size
            self.y1_change = 0
        elif action == 2:  # UP
            self.y1_change = -self.snake_size
            self.x1_change = 0
        elif action == 3:  # DOWN
            self.y1_change = self.snake_size
            self.x1_change = 0

        self.x1 += self.x1_change
        self.y1 += self.y1_change

        done = self.x1 >= self.width or self.x1 < 0 or self.y1 >= self.height or self.y1 < 0
        snake_Head = [self.x1, self.y1]
        self.snake_List.append(snake_Head)
        if len(self.snake_List) > self.Length_of_snake:
            del self.snake_List[0]

        for x in self.snake_List[:-1]:
            if x == snake_Head:
                done = True

        reward = 0
        if self.x1 == self.foodx and self.y1 == self.foody:
            self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
            self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
            self.Length_of_snake += 1
            reward = 10
            self.score += 1

        if done:
            reward = -10

        state = self.get_state()
        return state, reward, done

    def get_state(self):
        state = [
            self.x1, self.y1, self.foodx, self.foody,
            self.x1_change, self.y1_change,
        ]
        return np.array(state, dtype=np.float32)

    def render(self):
        window = pygame.display.set_mode((self.width, self.height))
        window.fill((0, 0, 0))
        for segment in self.snake_List:
            pygame.draw.rect(window, (0, 255, 0), [segment[0], segment[1], self.snake_size, self.snake_size])
        pygame.draw.rect(window, (255, 255, 255), [self.foodx, self.foody, self.snake_size, self.snake_size])
        pygame.display.update()

def train_until_achieve_score(model_type, target_score=10, load_path=None, saved_episode = 0):
    state_size = 6
    hidden_size = 64
    action_size = 4
    batch_size = 32

    agent = DQNAgent(state_size, action_size, hidden_size, model_type=model_type)

    if load_path:
        agent.model.load_state_dict(torch.load(load_path))
        print(f"Loaded model from {load_path}")

    game = SnakeGameAI()
    episode = saved_episode

    start_time = time.time()

    while True:
        episode += 1
        state = game.reset()
        hidden = agent.model.init_hidden(1)
        for time_step in range(500):
            action, hidden = agent.act(state, hidden)
            next_state, reward, done = game.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                print(f"Episode: {episode}, Score: {game.score}, Epsilon: {agent.epsilon:.2}")
                break
            if len(agent.memory) > batch_size:
                agent.replay(batch_size)
        if episode % 250 == 0:
            torch.save(agent.model.state_dict(), f"{model_type.lower()}_snake_model_{episode}.pth")
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Saved model at episode {episode}")
            print(f"Training time for {model_type} after {episode} episodes: {elapsed_time:.2f} seconds")
            start_time = time.time()
        if game.score >= target_score:
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Model {model_type} achieved a score of {target_score} in episode {episode}")
            print(f"Training time for {model_type}: {elapsed_time:.2f} seconds")
            break

    torch.save(agent.model.state_dict(), f"{model_type.lower()}_snake_model_final.pth")

if __name__ == "__main__":
    # 'RNN', 
    load_path = f"{'RNN'.lower()}_snake_model_8000.pth" if torch.cuda.is_available() else None
    train_until_achieve_score('RNN', load_path=load_path, saved_episode = 8000)
    for model_type in ['GRU', 'LSTM']:
        load_path = f"{model_type.lower()}_snake_model_final.pth" if torch.cuda.is_available() else None
        train_until_achieve_score(model_type)
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Loaded model from rnn_snake_model_8000.pth
# Episode: 8001, Score: 0, Epsilon: 0.91
# Episode: 8002, Score: 0, Epsilon: 0.61
# Episode: 8003, Score: 0, Epsilon: 0.27
# Episode: 8004, Score: 0, Epsilon: 0.18
# Episode: 8008, Score: 1, Epsilon: 0.01
# Episode: 8009, Score: 0, Epsilon: 0.01
# Episode: 8010, Score: 0, Epsilon: 0.01
# Episode: 8011, Score: 0, Epsilon: 0.01
# Episode: 8012, Score: 0, Epsilon: 0.01
# Episode: 8013, Score: 0, Epsilon: 0.01
# Episode: 8014, Score: 0, Epsilon: 0.01
# Episode: 8015, Score: 0, Epsilon: 0.01
# Episode: 8016, Score: 0, Epsilon: 0.01
# Episode: 8017, Score: 0, Epsilon: 0.01
# Episode: 8018, Score: 0, Epsilon: 0.01
# Episode: 8020, Score: 0, Epsilon: 0.01
# Episode: 8021, Score: 0, Epsilon: 0.01
# Episode: 8022, Score: 0, Epsilon: 0.01
# Episode: 8023, Score: 0, Epsilon: 0.01
# Episode: 8024, Score: 0, Epsilon: 0.01
# Episode: 8025, Score: 0, Epsilon: 0.01
# Episode: 8026, Score: 0, Epsilon: 0.01
# Episode: 8027, Score: 0, Epsilon: 0.01
# Episode: 8028, Score: 0, Epsilon: 0.01
# Episode: 8029, Score: 0, Epsilon: 0.01
# Episode: 8030, Score: 0, Epsilon: 0.01
# Episode: 8031, Score: 0, Epsilon: 0.01
# Episode: 8032, Score: 0, Epsilon: 0.01
# Episode: 8033, Score: 0, Epsilon: 0.01
# Episode: 8034, Score: 0, Epsilon: 0.01
# Episode: 8035, Score: 0, Epsilon: 0.01
# Episode: 8036, Score: 1, Epsilon: 0.01
# Episode: 8037, Score: 1, Epsilon: 0.01
# Episode: 8038, Score: 1, Epsilon: 0.01
# Episode: 8039, Score: 0, Epsilon: 0.01
# Episode: 8040, Score: 0, Epsilon: 0.01
# Episode: 8041, Score: 0, Epsilon: 0.01
# Episode: 8042, Score: 0, Epsilon: 0.01
# Episode: 8043, Score: 0, Epsilon: 0.01
# Episode: 8044, Score: 0, Epsilon: 0.01
# Episode: 8045, Score: 0, Epsilon: 0.01
# Episode: 8046, Score: 0, Epsilon: 0.01
# Episode: 8047, Score: 0, Epsilon: 0.01
# Episode: 8048, Score: 0, Epsilon: 0.01
# Episode: 8049, Score: 0, Epsilon: 0.01
# Episode: 8050, Score: 0, Epsilon: 0.01
# Episode: 8051, Score: 0, Epsilon: 0.01
# Episode: 8052, Score: 0, Epsilon: 0.01
# Episode: 8053, Score: 1, Epsilon: 0.01
# Episode: 8054, Score: 0, Epsilon: 0.01
# Episode: 8055, Score: 0, Epsilon: 0.01
# Episode: 8056, Score: 0, Epsilon: 0.01
# Episode: 8057, Score: 0, Epsilon: 0.01
# Episode: 8058, Score: 0, Epsilon: 0.01
# Episode: 8059, Score: 0, Epsilon: 0.01
# Episode: 8060, Score: 0, Epsilon: 0.01
# Episode: 8061, Score: 0, Epsilon: 0.01
# Episode: 8062, Score: 0, Epsilon: 0.01
# Episode: 8063, Score: 0, Epsilon: 0.01
# Episode: 8064, Score: 0, Epsilon: 0.01
# Episode: 8065, Score: 0, Epsilon: 0.01
# Episode: 8066, Score: 0, Epsilon: 0.01
# Episode: 8067, Score: 0, Epsilon: 0.01
# Episode: 8068, Score: 0, Epsilon: 0.01
# Episode: 8069, Score: 0, Epsilon: 0.01
# Episode: 8070, Score: 0, Epsilon: 0.01
# Episode: 8072, Score: 1, Epsilon: 0.01
# Episode: 8073, Score: 0, Epsilon: 0.01
# Episode: 8074, Score: 0, Epsilon: 0.01
# Episode: 8075, Score: 0, Epsilon: 0.01
# Episode: 8077, Score: 0, Epsilon: 0.01
# Episode: 8078, Score: 0, Epsilon: 0.01
# Episode: 8079, Score: 0, Epsilon: 0.01
# Episode: 8080, Score: 1, Epsilon: 0.01
# Episode: 8081, Score: 0, Epsilon: 0.01
# Episode: 8082, Score: 0, Epsilon: 0.01
# Episode: 8083, Score: 0, Epsilon: 0.01
# Episode: 8084, Score: 0, Epsilon: 0.01
# Episode: 8085, Score: 0, Epsilon: 0.01
# Episode: 8086, Score: 1, Epsilon: 0.01
# Episode: 8087, Score: 0, Epsilon: 0.01
# Episode: 8088, Score: 0, Epsilon: 0.01
# Episode: 8089, Score: 0, Epsilon: 0.01
# Episode: 8090, Score: 0, Epsilon: 0.01
# Episode: 8091, Score: 0, Epsilon: 0.01
# Episode: 8092, Score: 0, Epsilon: 0.01
# Episode: 8093, Score: 0, Epsilon: 0.01
# Episode: 8094, Score: 0, Epsilon: 0.01
# Episode: 8095, Score: 0, Epsilon: 0.01
# Episode: 8097, Score: 0, Epsilon: 0.01
# Episode: 8098, Score: 0, Epsilon: 0.01
# Episode: 8099, Score: 0, Epsilon: 0.01
# Episode: 8100, Score: 0, Epsilon: 0.01
# Episode: 8101, Score: 0, Epsilon: 0.01
# Episode: 8102, Score: 0, Epsilon: 0.01
# Episode: 8103, Score: 0, Epsilon: 0.01
# Episode: 8104, Score: 0, Epsilon: 0.01
# Episode: 8105, Score: 1, Epsilon: 0.01
# Episode: 8106, Score: 0, Epsilon: 0.01
# Episode: 8107, Score: 0, Epsilon: 0.01
# Episode: 8108, Score: 0, Epsilon: 0.01
# Episode: 8109, Score: 0, Epsilon: 0.01
# Episode: 8110, Score: 0, Epsilon: 0.01
# Episode: 8111, Score: 0, Epsilon: 0.01
# Episode: 8112, Score: 0, Epsilon: 0.01
# Episode: 8113, Score: 0, Epsilon: 0.01
# Episode: 8114, Score: 0, Epsilon: 0.01
# Episode: 8116, Score: 0, Epsilon: 0.01
# Episode: 8117, Score: 0, Epsilon: 0.01
# Episode: 8118, Score: 0, Epsilon: 0.01
# Episode: 8119, Score: 0, Epsilon: 0.01
# Episode: 8120, Score: 1, Epsilon: 0.01
# Episode: 8121, Score: 0, Epsilon: 0.01
# Episode: 8122, Score: 0, Epsilon: 0.01
# Episode: 8123, Score: 0, Epsilon: 0.01
# Episode: 8124, Score: 0, Epsilon: 0.01
# Episode: 8125, Score: 1, Epsilon: 0.01
# Episode: 8126, Score: 0, Epsilon: 0.01
# Episode: 8127, Score: 0, Epsilon: 0.01
# Episode: 8128, Score: 0, Epsilon: 0.01
# Episode: 8129, Score: 0, Epsilon: 0.01
# Episode: 8130, Score: 0, Epsilon: 0.01
# Episode: 8131, Score: 0, Epsilon: 0.01
# Episode: 8132, Score: 0, Epsilon: 0.01
# Episode: 8133, Score: 0, Epsilon: 0.01
# Episode: 8134, Score: 0, Epsilon: 0.01
# Episode: 8135, Score: 0, Epsilon: 0.01
# Episode: 8136, Score: 0, Epsilon: 0.01
# Episode: 8137, Score: 0, Epsilon: 0.01
# Episode: 8138, Score: 0, Epsilon: 0.01
# Episode: 8139, Score: 0, Epsilon: 0.01
# Episode: 8140, Score: 0, Epsilon: 0.01
# Episode: 8141, Score: 0, Epsilon: 0.01
# Episode: 8142, Score: 0, Epsilon: 0.01
# Episode: 8143, Score: 0, Epsilon: 0.01
# Episode: 8144, Score: 0, Epsilon: 0.01
# Episode: 8145, Score: 0, Epsilon: 0.01
# Episode: 8146, Score: 0, Epsilon: 0.01
# Episode: 8147, Score: 0, Epsilon: 0.01
# Episode: 8149, Score: 0, Epsilon: 0.01
# Episode: 8150, Score: 0, Epsilon: 0.01
# Episode: 8151, Score: 0, Epsilon: 0.01
# Episode: 8152, Score: 0, Epsilon: 0.01
# Episode: 8153, Score: 0, Epsilon: 0.01
# Episode: 8154, Score: 0, Epsilon: 0.01
# Episode: 8155, Score: 0, Epsilon: 0.01
# Episode: 8156, Score: 0, Epsilon: 0.01
# Episode: 8157, Score: 0, Epsilon: 0.01
# Episode: 8158, Score: 0, Epsilon: 0.01
# Episode: 8159, Score: 0, Epsilon: 0.01
# Episode: 8160, Score: 0, Epsilon: 0.01
# Episode: 8161, Score: 0, Epsilon: 0.01
# Episode: 8162, Score: 0, Epsilon: 0.01
# Episode: 8163, Score: 0, Epsilon: 0.01
# Episode: 8164, Score: 0, Epsilon: 0.01
# Episode: 8165, Score: 0, Epsilon: 0.01
# Episode: 8166, Score: 0, Epsilon: 0.01
# Episode: 8167, Score: 0, Epsilon: 0.01
# Episode: 8168, Score: 1, Epsilon: 0.01
# Episode: 8169, Score: 0, Epsilon: 0.01
# Episode: 8170, Score: 0, Epsilon: 0.01
# Episode: 8171, Score: 0, Epsilon: 0.01
# Episode: 8172, Score: 0, Epsilon: 0.01
# Episode: 8174, Score: 0, Epsilon: 0.01
# Episode: 8175, Score: 0, Epsilon: 0.01
# Episode: 8176, Score: 0, Epsilon: 0.01
# Episode: 8177, Score: 0, Epsilon: 0.01
# Episode: 8178, Score: 1, Epsilon: 0.01
# Episode: 8179, Score: 0, Epsilon: 0.01
# Episode: 8180, Score: 0, Epsilon: 0.01
# Episode: 8181, Score: 0, Epsilon: 0.01
# Episode: 8182, Score: 0, Epsilon: 0.01
# Episode: 8183, Score: 0, Epsilon: 0.01
# Episode: 8184, Score: 0, Epsilon: 0.01
# Episode: 8185, Score: 0, Epsilon: 0.01
# Episode: 8186, Score: 0, Epsilon: 0.01
# Episode: 8187, Score: 0, Epsilon: 0.01
# Episode: 8188, Score: 0, Epsilon: 0.01
# Episode: 8189, Score: 0, Epsilon: 0.01
# Episode: 8190, Score: 0, Epsilon: 0.01
# Episode: 8191, Score: 0, Epsilon: 0.01
# Episode: 8192, Score: 0, Epsilon: 0.01
# Episode: 8194, Score: 1, Epsilon: 0.01
# Episode: 8195, Score: 0, Epsilon: 0.01
# Episode: 8196, Score: 0, Epsilon: 0.01
# Episode: 8197, Score: 0, Epsilon: 0.01
# Episode: 8198, Score: 0, Epsilon: 0.01
# Episode: 8199, Score: 0, Epsilon: 0.01
# Episode: 8200, Score: 0, Epsilon: 0.01
# Episode: 8201, Score: 0, Epsilon: 0.01
# Episode: 8202, Score: 0, Epsilon: 0.01
# Episode: 8203, Score: 0, Epsilon: 0.01
# Episode: 8204, Score: 0, Epsilon: 0.01
# Episode: 8205, Score: 0, Epsilon: 0.01
# Episode: 8206, Score: 0, Epsilon: 0.01
# Episode: 8207, Score: 0, Epsilon: 0.01
# Episode: 8208, Score: 1, Epsilon: 0.01
# Episode: 8209, Score: 0, Epsilon: 0.01
# Episode: 8210, Score: 0, Epsilon: 0.01
# Episode: 8211, Score: 0, Epsilon: 0.01
# Episode: 8212, Score: 0, Epsilon: 0.01
# Episode: 8213, Score: 0, Epsilon: 0.01
# Episode: 8214, Score: 1, Epsilon: 0.01
# Episode: 8215, Score: 1, Epsilon: 0.01
# Episode: 8216, Score: 0, Epsilon: 0.01
# Episode: 8217, Score: 0, Epsilon: 0.01
# Episode: 8218, Score: 0, Epsilon: 0.01
# Episode: 8219, Score: 0, Epsilon: 0.01
# Episode: 8220, Score: 0, Epsilon: 0.01
# Episode: 8221, Score: 0, Epsilon: 0.01
# Episode: 8222, Score: 0, Epsilon: 0.01
# Episode: 8223, Score: 0, Epsilon: 0.01
# Episode: 8224, Score: 0, Epsilon: 0.01
# Episode: 8225, Score: 0, Epsilon: 0.01
# Episode: 8226, Score: 0, Epsilon: 0.01
# Episode: 8227, Score: 0, Epsilon: 0.01
# Episode: 8228, Score: 0, Epsilon: 0.01
# Episode: 8229, Score: 1, Epsilon: 0.01
# Episode: 8230, Score: 0, Epsilon: 0.01
# Episode: 8231, Score: 1, Epsilon: 0.01
# Episode: 8232, Score: 0, Epsilon: 0.01
# Episode: 8233, Score: 0, Epsilon: 0.01
# Episode: 8234, Score: 0, Epsilon: 0.01
# Episode: 8235, Score: 0, Epsilon: 0.01
# Episode: 8236, Score: 0, Epsilon: 0.01
# Episode: 8237, Score: 0, Epsilon: 0.01
# Episode: 8238, Score: 0, Epsilon: 0.01
# Episode: 8239, Score: 1, Epsilon: 0.01
# Episode: 8240, Score: 0, Epsilon: 0.01
# Episode: 8241, Score: 0, Epsilon: 0.01
# Episode: 8242, Score: 0, Epsilon: 0.01
# Episode: 8243, Score: 0, Epsilon: 0.01
# Episode: 8245, Score: 0, Epsilon: 0.01
# Episode: 8246, Score: 0, Epsilon: 0.01
# Episode: 8247, Score: 1, Epsilon: 0.01
# Episode: 8248, Score: 0, Epsilon: 0.01
# Episode: 8249, Score: 1, Epsilon: 0.01
# Episode: 8250, Score: 0, Epsilon: 0.01
# Saved model at episode 8250
# Training time for RNN after 8250 episodes: 4338.05 seconds
# Episode: 8251, Score: 0, Epsilon: 0.01
# Episode: 8252, Score: 0, Epsilon: 0.01
# Episode: 8253, Score: 0, Epsilon: 0.01
# Episode: 8254, Score: 0, Epsilon: 0.01
# Episode: 8255, Score: 0, Epsilon: 0.01
# Episode: 8256, Score: 0, Epsilon: 0.01
# Episode: 8257, Score: 0, Epsilon: 0.01
# Episode: 8258, Score: 1, Epsilon: 0.01
# Episode: 8259, Score: 1, Epsilon: 0.01
# Episode: 8260, Score: 0, Epsilon: 0.01
# Episode: 8261, Score: 0, Epsilon: 0.01
# Episode: 8262, Score: 0, Epsilon: 0.01
# Episode: 8263, Score: 0, Epsilon: 0.01
# Episode: 8264, Score: 0, Epsilon: 0.01
# Episode: 8265, Score: 0, Epsilon: 0.01
# Episode: 8266, Score: 0, Epsilon: 0.01
# Episode: 8267, Score: 0, Epsilon: 0.01
# Episode: 8268, Score: 0, Epsilon: 0.01
# Episode: 8269, Score: 0, Epsilon: 0.01
# Episode: 8270, Score: 0, Epsilon: 0.01
# Episode: 8271, Score: 0, Epsilon: 0.01
# Episode: 8272, Score: 0, Epsilon: 0.01
# Episode: 8273, Score: 0, Epsilon: 0.01
# Episode: 8274, Score: 1, Epsilon: 0.01
# Episode: 8275, Score: 0, Epsilon: 0.01
# Episode: 8276, Score: 0, Epsilon: 0.01
# Episode: 8277, Score: 0, Epsilon: 0.01
# Episode: 8278, Score: 0, Epsilon: 0.01
# Episode: 8279, Score: 0, Epsilon: 0.01
# Episode: 8280, Score: 0, Epsilon: 0.01
# Episode: 8281, Score: 0, Epsilon: 0.01
# Episode: 8282, Score: 0, Epsilon: 0.01
# Episode: 8283, Score: 1, Epsilon: 0.01
# Episode: 8284, Score: 0, Epsilon: 0.01
# Episode: 8285, Score: 0, Epsilon: 0.01
# Episode: 8286, Score: 0, Epsilon: 0.01
# Episode: 8287, Score: 0, Epsilon: 0.01
# Episode: 8288, Score: 0, Epsilon: 0.01
# Episode: 8289, Score: 1, Epsilon: 0.01
# Episode: 8290, Score: 0, Epsilon: 0.01
# Episode: 8291, Score: 0, Epsilon: 0.01
# Episode: 8292, Score: 0, Epsilon: 0.01
# Episode: 8293, Score: 0, Epsilon: 0.01
# Episode: 8294, Score: 0, Epsilon: 0.01
# Episode: 8295, Score: 0, Epsilon: 0.01
# Episode: 8296, Score: 0, Epsilon: 0.01
# Episode: 8297, Score: 0, Epsilon: 0.01
# Episode: 8298, Score: 1, Epsilon: 0.01
# Episode: 8299, Score: 0, Epsilon: 0.01
# Episode: 8300, Score: 0, Epsilon: 0.01
# Episode: 8301, Score: 0, Epsilon: 0.01
# Episode: 8302, Score: 0, Epsilon: 0.01
# Episode: 8303, Score: 0, Epsilon: 0.01
# Episode: 8304, Score: 0, Epsilon: 0.01
# Episode: 8305, Score: 0, Epsilon: 0.01
# Episode: 8306, Score: 0, Epsilon: 0.01
# Episode: 8307, Score: 0, Epsilon: 0.01
# Episode: 8308, Score: 0, Epsilon: 0.01
# Episode: 8309, Score: 0, Epsilon: 0.01
# Episode: 8310, Score: 0, Epsilon: 0.01
# Episode: 8311, Score: 0, Epsilon: 0.01
# Episode: 8312, Score: 0, Epsilon: 0.01
# Episode: 8313, Score: 0, Epsilon: 0.01
# Episode: 8314, Score: 0, Epsilon: 0.01
# Episode: 8315, Score: 0, Epsilon: 0.01
# Episode: 8316, Score: 0, Epsilon: 0.01
# Episode: 8317, Score: 0, Epsilon: 0.01
# Episode: 8318, Score: 0, Epsilon: 0.01
# Episode: 8319, Score: 0, Epsilon: 0.01
# Episode: 8320, Score: 0, Epsilon: 0.01
# Episode: 8322, Score: 1, Epsilon: 0.01
# Episode: 8323, Score: 0, Epsilon: 0.01
# Episode: 8324, Score: 0, Epsilon: 0.01
# Episode: 8325, Score: 0, Epsilon: 0.01
# Episode: 8326, Score: 0, Epsilon: 0.01
# Episode: 8327, Score: 0, Epsilon: 0.01
# Episode: 8328, Score: 0, Epsilon: 0.01
# Episode: 8329, Score: 0, Epsilon: 0.01
# Episode: 8330, Score: 0, Epsilon: 0.01
# Episode: 8331, Score: 0, Epsilon: 0.01
# Episode: 8332, Score: 0, Epsilon: 0.01
# Episode: 8333, Score: 0, Epsilon: 0.01
# Episode: 8334, Score: 0, Epsilon: 0.01
# Episode: 8335, Score: 0, Epsilon: 0.01
# Episode: 8336, Score: 0, Epsilon: 0.01
# Episode: 8337, Score: 0, Epsilon: 0.01
# Episode: 8338, Score: 0, Epsilon: 0.01
# Episode: 8339, Score: 0, Epsilon: 0.01
# Episode: 8340, Score: 0, Epsilon: 0.01
# Episode: 8341, Score: 0, Epsilon: 0.01
# Episode: 8342, Score: 0, Epsilon: 0.01
# Episode: 8343, Score: 0, Epsilon: 0.01
# Episode: 8344, Score: 0, Epsilon: 0.01
# Episode: 8346, Score: 0, Epsilon: 0.01
# Episode: 8347, Score: 0, Epsilon: 0.01
# Episode: 8348, Score: 0, Epsilon: 0.01
# Episode: 8349, Score: 0, Epsilon: 0.01
# Episode: 8350, Score: 1, Epsilon: 0.01
# Episode: 8351, Score: 0, Epsilon: 0.01
# Episode: 8352, Score: 0, Epsilon: 0.01
# Episode: 8353, Score: 0, Epsilon: 0.01
# Episode: 8354, Score: 0, Epsilon: 0.01
# Episode: 8355, Score: 0, Epsilon: 0.01
# Episode: 8356, Score: 0, Epsilon: 0.01
# Episode: 8357, Score: 0, Epsilon: 0.01
# Episode: 8358, Score: 0, Epsilon: 0.01
# Episode: 8359, Score: 1, Epsilon: 0.01
# Episode: 8360, Score: 0, Epsilon: 0.01
# Episode: 8361, Score: 0, Epsilon: 0.01
# Episode: 8362, Score: 0, Epsilon: 0.01
# Episode: 8363, Score: 0, Epsilon: 0.01
# Episode: 8364, Score: 0, Epsilon: 0.01
# Episode: 8365, Score: 0, Epsilon: 0.01
# Episode: 8366, Score: 0, Epsilon: 0.01
# Episode: 8367, Score: 0, Epsilon: 0.01
# Episode: 8368, Score: 0, Epsilon: 0.01
# Episode: 8369, Score: 0, Epsilon: 0.01
# Episode: 8370, Score: 0, Epsilon: 0.01
# Episode: 8371, Score: 0, Epsilon: 0.01
# Episode: 8372, Score: 0, Epsilon: 0.01
# Episode: 8373, Score: 0, Epsilon: 0.01
# Episode: 8374, Score: 0, Epsilon: 0.01
# Episode: 8375, Score: 0, Epsilon: 0.01
# Episode: 8376, Score: 0, Epsilon: 0.01
# Episode: 8377, Score: 0, Epsilon: 0.01
# Episode: 8378, Score: 0, Epsilon: 0.01
# Episode: 8379, Score: 0, Epsilon: 0.01
# Episode: 8380, Score: 0, Epsilon: 0.01
# Episode: 8381, Score: 0, Epsilon: 0.01
# Episode: 8382, Score: 0, Epsilon: 0.01
# Episode: 8383, Score: 0, Epsilon: 0.01
# Episode: 8384, Score: 0, Epsilon: 0.01
# Episode: 8385, Score: 0, Epsilon: 0.01
# Episode: 8386, Score: 0, Epsilon: 0.01
# Episode: 8387, Score: 0, Epsilon: 0.01
# Episode: 8388, Score: 0, Epsilon: 0.01
# Episode: 8389, Score: 0, Epsilon: 0.01
# Episode: 8390, Score: 1, Epsilon: 0.01
# Episode: 8391, Score: 0, Epsilon: 0.01
# Episode: 8392, Score: 0, Epsilon: 0.01
# Episode: 8393, Score: 0, Epsilon: 0.01
# Episode: 8394, Score: 0, Epsilon: 0.01
# Episode: 8395, Score: 0, Epsilon: 0.01
# Episode: 8396, Score: 0, Epsilon: 0.01
# Episode: 8397, Score: 0, Epsilon: 0.01
# Episode: 8398, Score: 0, Epsilon: 0.01
# Episode: 8399, Score: 0, Epsilon: 0.01
# Episode: 8400, Score: 0, Epsilon: 0.01
# Episode: 8401, Score: 0, Epsilon: 0.01
# Episode: 8402, Score: 0, Epsilon: 0.01
# Episode: 8403, Score: 0, Epsilon: 0.01
# Episode: 8404, Score: 0, Epsilon: 0.01
# Episode: 8405, Score: 0, Epsilon: 0.01
# Episode: 8406, Score: 0, Epsilon: 0.01
# Episode: 8408, Score: 0, Epsilon: 0.01
# Episode: 8409, Score: 0, Epsilon: 0.01
# Episode: 8410, Score: 0, Epsilon: 0.01
# Episode: 8411, Score: 0, Epsilon: 0.01
# Episode: 8412, Score: 0, Epsilon: 0.01
# Episode: 8413, Score: 0, Epsilon: 0.01
# Episode: 8414, Score: 0, Epsilon: 0.01
# Episode: 8415, Score: 0, Epsilon: 0.01
# Episode: 8416, Score: 0, Epsilon: 0.01
# Episode: 8417, Score: 0, Epsilon: 0.01
# Episode: 8418, Score: 0, Epsilon: 0.01
# Episode: 8419, Score: 0, Epsilon: 0.01
# Episode: 8420, Score: 0, Epsilon: 0.01
# Episode: 8421, Score: 0, Epsilon: 0.01
# Episode: 8422, Score: 0, Epsilon: 0.01
# Episode: 8423, Score: 0, Epsilon: 0.01
# Episode: 8424, Score: 0, Epsilon: 0.01
# Episode: 8425, Score: 0, Epsilon: 0.01
# Episode: 8426, Score: 0, Epsilon: 0.01
# Episode: 8427, Score: 0, Epsilon: 0.01
# Episode: 8428, Score: 0, Epsilon: 0.01
# Episode: 8429, Score: 0, Epsilon: 0.01
# Episode: 8430, Score: 0, Epsilon: 0.01
# Episode: 8431, Score: 0, Epsilon: 0.01
# Episode: 8432, Score: 2, Epsilon: 0.01
# Episode: 8433, Score: 0, Epsilon: 0.01
# Episode: 8434, Score: 0, Epsilon: 0.01
# Episode: 8435, Score: 0, Epsilon: 0.01
# Episode: 8436, Score: 1, Epsilon: 0.01
# Episode: 8437, Score: 0, Epsilon: 0.01
# Episode: 8438, Score: 0, Epsilon: 0.01
# Episode: 8439, Score: 0, Epsilon: 0.01
# Episode: 8440, Score: 0, Epsilon: 0.01
# Episode: 8441, Score: 0, Epsilon: 0.01
# Episode: 8442, Score: 0, Epsilon: 0.01
# Episode: 8443, Score: 0, Epsilon: 0.01
# Episode: 8444, Score: 0, Epsilon: 0.01
# Episode: 8445, Score: 0, Epsilon: 0.01
# Episode: 8446, Score: 0, Epsilon: 0.01
# Episode: 8447, Score: 0, Epsilon: 0.01
# Episode: 8448, Score: 0, Epsilon: 0.01
# Episode: 8449, Score: 0, Epsilon: 0.01
# Episode: 8450, Score: 0, Epsilon: 0.01
# Episode: 8451, Score: 0, Epsilon: 0.01
# Episode: 8452, Score: 0, Epsilon: 0.01
# Episode: 8453, Score: 0, Epsilon: 0.01
# Episode: 8454, Score: 0, Epsilon: 0.01
# Episode: 8455, Score: 0, Epsilon: 0.01
# Episode: 8456, Score: 2, Epsilon: 0.01
# Episode: 8457, Score: 0, Epsilon: 0.01
# Episode: 8458, Score: 0, Epsilon: 0.01
# Episode: 8459, Score: 0, Epsilon: 0.01
# Episode: 8460, Score: 0, Epsilon: 0.01
# Episode: 8461, Score: 0, Epsilon: 0.01
# Episode: 8462, Score: 0, Epsilon: 0.01
# Episode: 8463, Score: 0, Epsilon: 0.01
# Episode: 8464, Score: 0, Epsilon: 0.01
# Episode: 8465, Score: 0, Epsilon: 0.01
# Episode: 8466, Score: 0, Epsilon: 0.01
# Episode: 8467, Score: 0, Epsilon: 0.01
# Episode: 8468, Score: 0, Epsilon: 0.01
# Episode: 8469, Score: 0, Epsilon: 0.01
# Episode: 8470, Score: 0, Epsilon: 0.01
# Episode: 8471, Score: 0, Epsilon: 0.01
# Episode: 8472, Score: 0, Epsilon: 0.01
# Episode: 8473, Score: 0, Epsilon: 0.01
# Episode: 8474, Score: 0, Epsilon: 0.01
# Episode: 8475, Score: 0, Epsilon: 0.01
# Episode: 8476, Score: 0, Epsilon: 0.01
# Episode: 8477, Score: 0, Epsilon: 0.01
# Episode: 8478, Score: 0, Epsilon: 0.01
# Episode: 8479, Score: 0, Epsilon: 0.01
# Episode: 8480, Score: 0, Epsilon: 0.01
# Episode: 8481, Score: 0, Epsilon: 0.01
# Episode: 8482, Score: 0, Epsilon: 0.01
# Episode: 8483, Score: 1, Epsilon: 0.01
# Episode: 8484, Score: 0, Epsilon: 0.01
# Episode: 8485, Score: 0, Epsilon: 0.01
# Episode: 8486, Score: 0, Epsilon: 0.01
# Episode: 8487, Score: 0, Epsilon: 0.01
# Episode: 8488, Score: 0, Epsilon: 0.01
# Episode: 8489, Score: 0, Epsilon: 0.01
# Episode: 8490, Score: 0, Epsilon: 0.01
# Episode: 8491, Score: 0, Epsilon: 0.01
# Episode: 8492, Score: 0, Epsilon: 0.01
# Episode: 8493, Score: 0, Epsilon: 0.01
# Episode: 8494, Score: 0, Epsilon: 0.01
# Episode: 8495, Score: 0, Epsilon: 0.01
# Episode: 8496, Score: 0, Epsilon: 0.01
# Episode: 8497, Score: 0, Epsilon: 0.01
# Episode: 8498, Score: 0, Epsilon: 0.01
# Episode: 8499, Score: 0, Epsilon: 0.01
# Episode: 8500, Score: 0, Epsilon: 0.01
# Saved model at episode 8500
# Training time for RNN after 8500 episodes: 3686.90 seconds
# Episode: 8501, Score: 0, Epsilon: 0.01
# Episode: 8502, Score: 0, Epsilon: 0.01
# Episode: 8503, Score: 0, Epsilon: 0.01
# Episode: 8504, Score: 0, Epsilon: 0.01
# Episode: 8505, Score: 0, Epsilon: 0.01
# Episode: 8506, Score: 0, Epsilon: 0.01
# Episode: 8507, Score: 0, Epsilon: 0.01
# Episode: 8508, Score: 0, Epsilon: 0.01
# Episode: 8509, Score: 0, Epsilon: 0.01
# Episode: 8510, Score: 0, Epsilon: 0.01
# Episode: 8511, Score: 0, Epsilon: 0.01
# Episode: 8512, Score: 0, Epsilon: 0.01
# Episode: 8513, Score: 0, Epsilon: 0.01
# Episode: 8514, Score: 1, Epsilon: 0.01
# Episode: 8515, Score: 0, Epsilon: 0.01
# Episode: 8516, Score: 0, Epsilon: 0.01
# Episode: 8517, Score: 0, Epsilon: 0.01
# Episode: 8518, Score: 1, Epsilon: 0.01
# Episode: 8519, Score: 0, Epsilon: 0.01
# Episode: 8520, Score: 0, Epsilon: 0.01
# Episode: 8521, Score: 0, Epsilon: 0.01
# Episode: 8522, Score: 0, Epsilon: 0.01
# Episode: 8523, Score: 0, Epsilon: 0.01
# Episode: 8524, Score: 0, Epsilon: 0.01
# Episode: 8525, Score: 0, Epsilon: 0.01
# Episode: 8526, Score: 0, Epsilon: 0.01
# Episode: 8527, Score: 0, Epsilon: 0.01
# Episode: 8528, Score: 0, Epsilon: 0.01
# Episode: 8529, Score: 0, Epsilon: 0.01
# Episode: 8530, Score: 0, Epsilon: 0.01
# Episode: 8531, Score: 0, Epsilon: 0.01
# Episode: 8532, Score: 0, Epsilon: 0.01
# Episode: 8533, Score: 0, Epsilon: 0.01
# Episode: 8534, Score: 0, Epsilon: 0.01
# Episode: 8535, Score: 0, Epsilon: 0.01
# Episode: 8536, Score: 0, Epsilon: 0.01
# Episode: 8537, Score: 0, Epsilon: 0.01
# Episode: 8538, Score: 0, Epsilon: 0.01
# Episode: 8539, Score: 0, Epsilon: 0.01
# Episode: 8540, Score: 0, Epsilon: 0.01
# Episode: 8541, Score: 0, Epsilon: 0.01
# Episode: 8542, Score: 0, Epsilon: 0.01
# Episode: 8543, Score: 0, Epsilon: 0.01
# Episode: 8544, Score: 0, Epsilon: 0.01
# Episode: 8545, Score: 0, Epsilon: 0.01
# Episode: 8546, Score: 0, Epsilon: 0.01
# Episode: 8547, Score: 0, Epsilon: 0.01
# Episode: 8548, Score: 0, Epsilon: 0.01
# Episode: 8549, Score: 1, Epsilon: 0.01
# Episode: 8550, Score: 0, Epsilon: 0.01
# Episode: 8551, Score: 0, Epsilon: 0.01
# Episode: 8552, Score: 0, Epsilon: 0.01
# Episode: 8553, Score: 0, Epsilon: 0.01
# Episode: 8554, Score: 1, Epsilon: 0.01
# Episode: 8556, Score: 0, Epsilon: 0.01
# Episode: 8557, Score: 0, Epsilon: 0.01
# Episode: 8558, Score: 0, Epsilon: 0.01
# Episode: 8559, Score: 0, Epsilon: 0.01
# Episode: 8560, Score: 1, Epsilon: 0.01
# Episode: 8561, Score: 0, Epsilon: 0.01
# Episode: 8562, Score: 0, Epsilon: 0.01
# Episode: 8563, Score: 0, Epsilon: 0.01
# Episode: 8564, Score: 0, Epsilon: 0.01
# Episode: 8565, Score: 0, Epsilon: 0.01
# Episode: 8566, Score: 0, Epsilon: 0.01
# Episode: 8567, Score: 0, Epsilon: 0.01
# Episode: 8568, Score: 0, Epsilon: 0.01
# Episode: 8569, Score: 0, Epsilon: 0.01
# Episode: 8570, Score: 0, Epsilon: 0.01
# Episode: 8571, Score: 0, Epsilon: 0.01
# Episode: 8572, Score: 0, Epsilon: 0.01
# Episode: 8573, Score: 0, Epsilon: 0.01
# Episode: 8574, Score: 0, Epsilon: 0.01
# Episode: 8575, Score: 0, Epsilon: 0.01
# Episode: 8576, Score: 0, Epsilon: 0.01
# Episode: 8577, Score: 0, Epsilon: 0.01
# Episode: 8578, Score: 1, Epsilon: 0.01
# Episode: 8579, Score: 0, Epsilon: 0.01
# Episode: 8580, Score: 1, Epsilon: 0.01
# Episode: 8581, Score: 0, Epsilon: 0.01
# Episode: 8582, Score: 0, Epsilon: 0.01
# Episode: 8583, Score: 0, Epsilon: 0.01
# Episode: 8584, Score: 0, Epsilon: 0.01
# Episode: 8585, Score: 0, Epsilon: 0.01
# Episode: 8586, Score: 0, Epsilon: 0.01
# Episode: 8587, Score: 0, Epsilon: 0.01
# Episode: 8588, Score: 0, Epsilon: 0.01
# Episode: 8589, Score: 0, Epsilon: 0.01
# Episode: 8590, Score: 0, Epsilon: 0.01
# Episode: 8591, Score: 0, Epsilon: 0.01
# Episode: 8592, Score: 0, Epsilon: 0.01
# Episode: 8593, Score: 0, Epsilon: 0.01
# Episode: 8594, Score: 0, Epsilon: 0.01
# Episode: 8595, Score: 0, Epsilon: 0.01
# Episode: 8596, Score: 0, Epsilon: 0.01
# Episode: 8597, Score: 0, Epsilon: 0.01
# Episode: 8598, Score: 2, Epsilon: 0.01
# Episode: 8599, Score: 0, Epsilon: 0.01
# Episode: 8600, Score: 0, Epsilon: 0.01
# Episode: 8601, Score: 0, Epsilon: 0.01
# Episode: 8602, Score: 0, Epsilon: 0.01
# Episode: 8603, Score: 0, Epsilon: 0.01
# Episode: 8604, Score: 0, Epsilon: 0.01
# Episode: 8605, Score: 0, Epsilon: 0.01
# Episode: 8606, Score: 0, Epsilon: 0.01
# Episode: 8607, Score: 0, Epsilon: 0.01
# Episode: 8608, Score: 0, Epsilon: 0.01
# Episode: 8609, Score: 0, Epsilon: 0.01
# Episode: 8610, Score: 0, Epsilon: 0.01
# Episode: 8611, Score: 0, Epsilon: 0.01
# Episode: 8612, Score: 0, Epsilon: 0.01
# Episode: 8613, Score: 0, Epsilon: 0.01
# Episode: 8614, Score: 0, Epsilon: 0.01
# Episode: 8615, Score: 0, Epsilon: 0.01
# Episode: 8616, Score: 1, Epsilon: 0.01
# Episode: 8617, Score: 1, Epsilon: 0.01
# Episode: 8618, Score: 0, Epsilon: 0.01
# Episode: 8619, Score: 0, Epsilon: 0.01
# Episode: 8620, Score: 0, Epsilon: 0.01
# Episode: 8621, Score: 0, Epsilon: 0.01
# Episode: 8622, Score: 0, Epsilon: 0.01
# Episode: 8623, Score: 1, Epsilon: 0.01
# Episode: 8624, Score: 0, Epsilon: 0.01
# Episode: 8625, Score: 0, Epsilon: 0.01
# Episode: 8626, Score: 0, Epsilon: 0.01
# Episode: 8627, Score: 0, Epsilon: 0.01
# Episode: 8628, Score: 0, Epsilon: 0.01
# Episode: 8629, Score: 0, Epsilon: 0.01
# Episode: 8630, Score: 0, Epsilon: 0.01
# Episode: 8631, Score: 0, Epsilon: 0.01
# Episode: 8632, Score: 0, Epsilon: 0.01
# Episode: 8633, Score: 0, Epsilon: 0.01
# Episode: 8634, Score: 0, Epsilon: 0.01
# Episode: 8635, Score: 0, Epsilon: 0.01
# Episode: 8636, Score: 0, Epsilon: 0.01
# Episode: 8637, Score: 0, Epsilon: 0.01
# Episode: 8638, Score: 0, Epsilon: 0.01
# Episode: 8639, Score: 0, Epsilon: 0.01
# Episode: 8640, Score: 0, Epsilon: 0.01
# Episode: 8641, Score: 0, Epsilon: 0.01
# Episode: 8642, Score: 0, Epsilon: 0.01
# Episode: 8643, Score: 0, Epsilon: 0.01
# Episode: 8644, Score: 0, Epsilon: 0.01
# Episode: 8645, Score: 0, Epsilon: 0.01
# Episode: 8646, Score: 0, Epsilon: 0.01
# Episode: 8648, Score: 0, Epsilon: 0.01
# Episode: 8649, Score: 0, Epsilon: 0.01
# Episode: 8650, Score: 0, Epsilon: 0.01
# Episode: 8651, Score: 0, Epsilon: 0.01
# Episode: 8652, Score: 0, Epsilon: 0.01
# Episode: 8653, Score: 0, Epsilon: 0.01
# Episode: 8654, Score: 0, Epsilon: 0.01
# Episode: 8655, Score: 0, Epsilon: 0.01
# Episode: 8656, Score: 0, Epsilon: 0.01
# Episode: 8657, Score: 0, Epsilon: 0.01
# Episode: 8658, Score: 0, Epsilon: 0.01
# Episode: 8659, Score: 0, Epsilon: 0.01
# Episode: 8660, Score: 0, Epsilon: 0.01
# Episode: 8661, Score: 0, Epsilon: 0.01
# Episode: 8662, Score: 0, Epsilon: 0.01
# Episode: 8663, Score: 0, Epsilon: 0.01
# Episode: 8664, Score: 1, Epsilon: 0.01
# Episode: 8665, Score: 0, Epsilon: 0.01
# Episode: 8666, Score: 0, Epsilon: 0.01
# Episode: 8667, Score: 0, Epsilon: 0.01
# Episode: 8668, Score: 0, Epsilon: 0.01
# Episode: 8669, Score: 0, Epsilon: 0.01
# Episode: 8670, Score: 0, Epsilon: 0.01
# Episode: 8671, Score: 0, Epsilon: 0.01
# Episode: 8672, Score: 0, Epsilon: 0.01
# Episode: 8673, Score: 0, Epsilon: 0.01
# Episode: 8674, Score: 0, Epsilon: 0.01
# Episode: 8675, Score: 0, Epsilon: 0.01
# Episode: 8676, Score: 0, Epsilon: 0.01
# Episode: 8677, Score: 0, Epsilon: 0.01
# Episode: 8678, Score: 0, Epsilon: 0.01
# Episode: 8679, Score: 0, Epsilon: 0.01
# Episode: 8680, Score: 0, Epsilon: 0.01
# Episode: 8681, Score: 0, Epsilon: 0.01
# Episode: 8682, Score: 0, Epsilon: 0.01
# Episode: 8683, Score: 0, Epsilon: 0.01
# Episode: 8684, Score: 0, Epsilon: 0.01
# Episode: 8685, Score: 1, Epsilon: 0.01
# Episode: 8686, Score: 0, Epsilon: 0.01
# Episode: 8687, Score: 1, Epsilon: 0.01
# Episode: 8688, Score: 1, Epsilon: 0.01
# Episode: 8689, Score: 0, Epsilon: 0.01
# Episode: 8690, Score: 0, Epsilon: 0.01
# Episode: 8691, Score: 0, Epsilon: 0.01
# Episode: 8692, Score: 0, Epsilon: 0.01
# Episode: 8693, Score: 0, Epsilon: 0.01
# Episode: 8694, Score: 0, Epsilon: 0.01
# Episode: 8695, Score: 0, Epsilon: 0.01
# Episode: 8696, Score: 0, Epsilon: 0.01
# Episode: 8697, Score: 0, Epsilon: 0.01
# Episode: 8698, Score: 0, Epsilon: 0.01
# Episode: 8699, Score: 0, Epsilon: 0.01
# Episode: 8700, Score: 0, Epsilon: 0.01
# Episode: 8701, Score: 0, Epsilon: 0.01
# Episode: 8702, Score: 0, Epsilon: 0.01
# Episode: 8704, Score: 0, Epsilon: 0.01
# Episode: 8705, Score: 0, Epsilon: 0.01
# Episode: 8706, Score: 0, Epsilon: 0.01
# Episode: 8707, Score: 0, Epsilon: 0.01
# Episode: 8708, Score: 0, Epsilon: 0.01
# Episode: 8709, Score: 0, Epsilon: 0.01
# Episode: 8710, Score: 0, Epsilon: 0.01
# Episode: 8711, Score: 0, Epsilon: 0.01
# Episode: 8712, Score: 0, Epsilon: 0.01
# Episode: 8713, Score: 0, Epsilon: 0.01
# Episode: 8714, Score: 0, Epsilon: 0.01
# Episode: 8715, Score: 0, Epsilon: 0.01
# Episode: 8716, Score: 1, Epsilon: 0.01
# Episode: 8717, Score: 1, Epsilon: 0.01
# Episode: 8718, Score: 0, Epsilon: 0.01
# Episode: 8719, Score: 0, Epsilon: 0.01
# Episode: 8720, Score: 0, Epsilon: 0.01
# Episode: 8721, Score: 0, Epsilon: 0.01
# Episode: 8722, Score: 0, Epsilon: 0.01
# Episode: 8723, Score: 0, Epsilon: 0.01
# Episode: 8724, Score: 0, Epsilon: 0.01
# Episode: 8725, Score: 0, Epsilon: 0.01
# Episode: 8726, Score: 0, Epsilon: 0.01
# Episode: 8727, Score: 0, Epsilon: 0.01
# Episode: 8728, Score: 0, Epsilon: 0.01
# Episode: 8729, Score: 0, Epsilon: 0.01
# Episode: 8730, Score: 1, Epsilon: 0.01
# Episode: 8731, Score: 0, Epsilon: 0.01
# Episode: 8732, Score: 0, Epsilon: 0.01
# Episode: 8733, Score: 0, Epsilon: 0.01
# Episode: 8734, Score: 0, Epsilon: 0.01
# Episode: 8735, Score: 0, Epsilon: 0.01
# Episode: 8736, Score: 0, Epsilon: 0.01
# Episode: 8737, Score: 0, Epsilon: 0.01
# Episode: 8739, Score: 0, Epsilon: 0.01
# Episode: 8740, Score: 0, Epsilon: 0.01
# Episode: 8741, Score: 1, Epsilon: 0.01
# Episode: 8742, Score: 0, Epsilon: 0.01
# Episode: 8743, Score: 0, Epsilon: 0.01
# Episode: 8744, Score: 0, Epsilon: 0.01
# Episode: 8745, Score: 0, Epsilon: 0.01
# Episode: 8746, Score: 0, Epsilon: 0.01
# Episode: 8747, Score: 0, Epsilon: 0.01
# Episode: 8748, Score: 0, Epsilon: 0.01
# Episode: 8749, Score: 0, Epsilon: 0.01
# Episode: 8750, Score: 0, Epsilon: 0.01
# Saved model at episode 8750
# Training time for RNN after 8750 episodes: 3937.88 seconds
# Episode: 8751, Score: 0, Epsilon: 0.01
# Episode: 8752, Score: 0, Epsilon: 0.01
# Episode: 8753, Score: 0, Epsilon: 0.01
# Episode: 8754, Score: 0, Epsilon: 0.01
# Episode: 8755, Score: 0, Epsilon: 0.01
# Episode: 8756, Score: 0, Epsilon: 0.01
# Episode: 8757, Score: 0, Epsilon: 0.01
# Episode: 8758, Score: 0, Epsilon: 0.01
# Episode: 8759, Score: 0, Epsilon: 0.01
# Episode: 8760, Score: 0, Epsilon: 0.01
# Episode: 8761, Score: 0, Epsilon: 0.01
# Episode: 8762, Score: 0, Epsilon: 0.01
# Episode: 8763, Score: 0, Epsilon: 0.01
# Episode: 8764, Score: 0, Epsilon: 0.01
# Episode: 8765, Score: 0, Epsilon: 0.01
# Episode: 8766, Score: 0, Epsilon: 0.01
# Episode: 8767, Score: 0, Epsilon: 0.01
# Episode: 8768, Score: 0, Epsilon: 0.01
# Episode: 8769, Score: 0, Epsilon: 0.01
# Episode: 8770, Score: 0, Epsilon: 0.01
# Episode: 8772, Score: 0, Epsilon: 0.01
# Episode: 8773, Score: 0, Epsilon: 0.01
# Episode: 8774, Score: 0, Epsilon: 0.01
# Episode: 8775, Score: 0, Epsilon: 0.01
# Episode: 8776, Score: 0, Epsilon: 0.01
# Episode: 8777, Score: 0, Epsilon: 0.01
# Episode: 8778, Score: 0, Epsilon: 0.01
# Episode: 8779, Score: 0, Epsilon: 0.01
# Episode: 8780, Score: 0, Epsilon: 0.01
# Episode: 8781, Score: 0, Epsilon: 0.01
# Episode: 8783, Score: 1, Epsilon: 0.01
# Episode: 8784, Score: 0, Epsilon: 0.01
# Episode: 8785, Score: 0, Epsilon: 0.01
# Episode: 8786, Score: 0, Epsilon: 0.01
# Episode: 8787, Score: 0, Epsilon: 0.01
# Episode: 8788, Score: 0, Epsilon: 0.01
# Episode: 8795, Score: 0, Epsilon: 0.01
# Episode: 8796, Score: 2, Epsilon: 0.01
# Episode: 8797, Score: 0, Epsilon: 0.01
# Episode: 8798, Score: 0, Epsilon: 0.01
# Episode: 8799, Score: 0, Epsilon: 0.01
# Episode: 8800, Score: 0, Epsilon: 0.01
# Episode: 8801, Score: 0, Epsilon: 0.01
# Episode: 8802, Score: 0, Epsilon: 0.01
# Episode: 8803, Score: 0, Epsilon: 0.01
# Episode: 8804, Score: 0, Epsilon: 0.01
# Episode: 8805, Score: 0, Epsilon: 0.01
# Episode: 8806, Score: 0, Epsilon: 0.01
# Episode: 8807, Score: 0, Epsilon: 0.01
# Episode: 8808, Score: 0, Epsilon: 0.01
# Episode: 8809, Score: 0, Epsilon: 0.01
# Episode: 8810, Score: 0, Epsilon: 0.01
# Episode: 8812, Score: 0, Epsilon: 0.01
# Episode: 8813, Score: 0, Epsilon: 0.01
# Episode: 8814, Score: 0, Epsilon: 0.01
# Episode: 8815, Score: 0, Epsilon: 0.01
# Episode: 8816, Score: 1, Epsilon: 0.01
# Episode: 8817, Score: 0, Epsilon: 0.01
# Episode: 8818, Score: 1, Epsilon: 0.01
# Episode: 8819, Score: 0, Epsilon: 0.01
# Episode: 8820, Score: 0, Epsilon: 0.01
# Episode: 8821, Score: 0, Epsilon: 0.01
# Episode: 8822, Score: 0, Epsilon: 0.01
# Episode: 8823, Score: 0, Epsilon: 0.01
# Episode: 8824, Score: 0, Epsilon: 0.01
# Episode: 8825, Score: 0, Epsilon: 0.01
# Episode: 8826, Score: 0, Epsilon: 0.01
# Episode: 8827, Score: 0, Epsilon: 0.01
# Episode: 8828, Score: 0, Epsilon: 0.01
# Episode: 8829, Score: 1, Epsilon: 0.01
# Episode: 8830, Score: 0, Epsilon: 0.01
# Episode: 8831, Score: 0, Epsilon: 0.01
# Episode: 8832, Score: 0, Epsilon: 0.01
# Episode: 8833, Score: 0, Epsilon: 0.01
# Episode: 8834, Score: 0, Epsilon: 0.01
# Episode: 8835, Score: 0, Epsilon: 0.01
# Episode: 8836, Score: 0, Epsilon: 0.01
# Episode: 8837, Score: 0, Epsilon: 0.01
# Episode: 8838, Score: 0, Epsilon: 0.01
# Episode: 8839, Score: 0, Epsilon: 0.01
# Episode: 8840, Score: 0, Epsilon: 0.01
# Episode: 8841, Score: 0, Epsilon: 0.01
# Episode: 8842, Score: 0, Epsilon: 0.01
# Episode: 8843, Score: 0, Epsilon: 0.01
# Episode: 8844, Score: 0, Epsilon: 0.01
# Episode: 8845, Score: 0, Epsilon: 0.01
# Episode: 8846, Score: 0, Epsilon: 0.01
# Episode: 8847, Score: 0, Epsilon: 0.01
# Episode: 8848, Score: 0, Epsilon: 0.01
# Episode: 8849, Score: 0, Epsilon: 0.01
# Episode: 8850, Score: 0, Epsilon: 0.01
# Episode: 8851, Score: 0, Epsilon: 0.01
# Episode: 8853, Score: 0, Epsilon: 0.01
# Episode: 8854, Score: 0, Epsilon: 0.01
# Episode: 8855, Score: 0, Epsilon: 0.01
# Episode: 8856, Score: 0, Epsilon: 0.01
# Episode: 8857, Score: 0, Epsilon: 0.01
# Episode: 8858, Score: 0, Epsilon: 0.01
# Episode: 8859, Score: 0, Epsilon: 0.01
# Episode: 8860, Score: 0, Epsilon: 0.01
# Episode: 8862, Score: 0, Epsilon: 0.01
# Episode: 8863, Score: 0, Epsilon: 0.01
# Episode: 8864, Score: 0, Epsilon: 0.01
# Episode: 8866, Score: 0, Epsilon: 0.01
# Episode: 8867, Score: 0, Epsilon: 0.01
# Episode: 8868, Score: 0, Epsilon: 0.01
# Episode: 8869, Score: 0, Epsilon: 0.01
# Episode: 8870, Score: 1, Epsilon: 0.01
# Episode: 8871, Score: 0, Epsilon: 0.01
# Episode: 8872, Score: 0, Epsilon: 0.01
# Episode: 8873, Score: 1, Epsilon: 0.01
# Episode: 8874, Score: 0, Epsilon: 0.01
# Episode: 8875, Score: 0, Epsilon: 0.01
# Episode: 8876, Score: 0, Epsilon: 0.01
# Episode: 8877, Score: 0, Epsilon: 0.01
# Episode: 8878, Score: 0, Epsilon: 0.01
# Episode: 8879, Score: 0, Epsilon: 0.01
# Episode: 8880, Score: 0, Epsilon: 0.01
# Episode: 8881, Score: 0, Epsilon: 0.01
# Episode: 8882, Score: 0, Epsilon: 0.01
# Episode: 8883, Score: 0, Epsilon: 0.01
# Episode: 8884, Score: 0, Epsilon: 0.01
# Episode: 8885, Score: 0, Epsilon: 0.01
# Episode: 8886, Score: 0, Epsilon: 0.01
# Episode: 8887, Score: 1, Epsilon: 0.01
# Episode: 8888, Score: 1, Epsilon: 0.01
# Episode: 8889, Score: 0, Epsilon: 0.01
# Episode: 8890, Score: 0, Epsilon: 0.01
# Episode: 8891, Score: 0, Epsilon: 0.01
# Episode: 8892, Score: 0, Epsilon: 0.01
# Episode: 8893, Score: 0, Epsilon: 0.01
# Episode: 8894, Score: 0, Epsilon: 0.01
# Episode: 8895, Score: 0, Epsilon: 0.01
# Episode: 8896, Score: 0, Epsilon: 0.01
# Episode: 8897, Score: 0, Epsilon: 0.01
# Episode: 8898, Score: 0, Epsilon: 0.01
# Episode: 8899, Score: 0, Epsilon: 0.01
# Episode: 8900, Score: 0, Epsilon: 0.01
# Episode: 8901, Score: 0, Epsilon: 0.01
# Episode: 8903, Score: 0, Epsilon: 0.01
# Episode: 8904, Score: 0, Epsilon: 0.01
# Episode: 8905, Score: 0, Epsilon: 0.01
# Episode: 8906, Score: 0, Epsilon: 0.01
# Episode: 8907, Score: 0, Epsilon: 0.01
# Episode: 8908, Score: 0, Epsilon: 0.01
# Episode: 8909, Score: 0, Epsilon: 0.01
# Episode: 8910, Score: 1, Epsilon: 0.01
# Episode: 8911, Score: 0, Epsilon: 0.01
# Episode: 8912, Score: 1, Epsilon: 0.01
# Episode: 8913, Score: 0, Epsilon: 0.01
# Episode: 8914, Score: 1, Epsilon: 0.01
# Episode: 8915, Score: 0, Epsilon: 0.01
# Episode: 8917, Score: 0, Epsilon: 0.01
# Episode: 8919, Score: 0, Epsilon: 0.01
# Episode: 8920, Score: 0, Epsilon: 0.01
# Episode: 8921, Score: 0, Epsilon: 0.01
# Episode: 8922, Score: 0, Epsilon: 0.01
# Episode: 8923, Score: 0, Epsilon: 0.01
# Episode: 8924, Score: 0, Epsilon: 0.01
# Episode: 8925, Score: 0, Epsilon: 0.01
# Episode: 8927, Score: 0, Epsilon: 0.01
# Episode: 8928, Score: 0, Epsilon: 0.01
# Episode: 8929, Score: 0, Epsilon: 0.01
# Episode: 8930, Score: 0, Epsilon: 0.01
# Episode: 8931, Score: 0, Epsilon: 0.01
# Episode: 8932, Score: 0, Epsilon: 0.01
# Episode: 8933, Score: 0, Epsilon: 0.01
# Episode: 8934, Score: 0, Epsilon: 0.01
# Episode: 8935, Score: 0, Epsilon: 0.01
# Episode: 8936, Score: 0, Epsilon: 0.01
# Episode: 8937, Score: 0, Epsilon: 0.01
# Episode: 8938, Score: 0, Epsilon: 0.01
# Episode: 8939, Score: 2, Epsilon: 0.01
# Episode: 8940, Score: 0, Epsilon: 0.01
# Episode: 8941, Score: 0, Epsilon: 0.01
# Episode: 8942, Score: 0, Epsilon: 0.01
# Episode: 8943, Score: 0, Epsilon: 0.01
# Episode: 8944, Score: 0, Epsilon: 0.01
# Episode: 8945, Score: 0, Epsilon: 0.01
# Episode: 8946, Score: 0, Epsilon: 0.01
# Episode: 8947, Score: 0, Epsilon: 0.01
# Episode: 8948, Score: 0, Epsilon: 0.01
# Episode: 8949, Score: 0, Epsilon: 0.01
# Episode: 8950, Score: 0, Epsilon: 0.01
# Episode: 8951, Score: 0, Epsilon: 0.01
# Episode: 8952, Score: 0, Epsilon: 0.01
# Episode: 8953, Score: 0, Epsilon: 0.01
# Episode: 8954, Score: 0, Epsilon: 0.01
# Episode: 8955, Score: 0, Epsilon: 0.01
# Episode: 8956, Score: 0, Epsilon: 0.01
# Episode: 8957, Score: 0, Epsilon: 0.01
# Episode: 8958, Score: 0, Epsilon: 0.01
# Episode: 8959, Score: 0, Epsilon: 0.01
# Episode: 8960, Score: 0, Epsilon: 0.01
# Episode: 8961, Score: 1, Epsilon: 0.01
# Episode: 8962, Score: 0, Epsilon: 0.01
# Episode: 8963, Score: 0, Epsilon: 0.01
# Episode: 8964, Score: 1, Epsilon: 0.01
# Episode: 8965, Score: 0, Epsilon: 0.01
# Episode: 8966, Score: 0, Epsilon: 0.01
# Episode: 8967, Score: 0, Epsilon: 0.01
# Episode: 8968, Score: 1, Epsilon: 0.01
# Episode: 8969, Score: 0, Epsilon: 0.01
# Episode: 8970, Score: 0, Epsilon: 0.01
# Episode: 8971, Score: 1, Epsilon: 0.01
# Episode: 8972, Score: 0, Epsilon: 0.01
# Episode: 8973, Score: 0, Epsilon: 0.01
# Episode: 8974, Score: 0, Epsilon: 0.01
# Episode: 8975, Score: 1, Epsilon: 0.01
# Episode: 8976, Score: 0, Epsilon: 0.01
# Episode: 8977, Score: 0, Epsilon: 0.01
# Episode: 8978, Score: 0, Epsilon: 0.01
# Episode: 8979, Score: 0, Epsilon: 0.01
# Episode: 8980, Score: 0, Epsilon: 0.01
# Episode: 8981, Score: 0, Epsilon: 0.01
# Episode: 8982, Score: 0, Epsilon: 0.01
# Episode: 8983, Score: 0, Epsilon: 0.01
# Episode: 8984, Score: 0, Epsilon: 0.01
# Episode: 8985, Score: 0, Epsilon: 0.01
# Episode: 8986, Score: 0, Epsilon: 0.01
# Episode: 8987, Score: 0, Epsilon: 0.01
# Episode: 8988, Score: 0, Epsilon: 0.01
# Episode: 8989, Score: 0, Epsilon: 0.01
# Episode: 8990, Score: 0, Epsilon: 0.01
# Episode: 8991, Score: 0, Epsilon: 0.01
# Episode: 8992, Score: 1, Epsilon: 0.01
# Episode: 8993, Score: 0, Epsilon: 0.01
# Episode: 8994, Score: 0, Epsilon: 0.01
# Episode: 8995, Score: 0, Epsilon: 0.01
# Episode: 8996, Score: 0, Epsilon: 0.01
# Episode: 8997, Score: 0, Epsilon: 0.01
# Episode: 8998, Score: 0, Epsilon: 0.01
# Episode: 8999, Score: 0, Epsilon: 0.01
# Episode: 9000, Score: 0, Epsilon: 0.01
# Saved model at episode 9000
# Training time for RNN after 9000 episodes: 3917.22 seconds
# Episode: 9001, Score: 0, Epsilon: 0.01
# Episode: 9002, Score: 0, Epsilon: 0.01
# Episode: 9003, Score: 0, Epsilon: 0.01
# Episode: 9004, Score: 1, Epsilon: 0.01
# Episode: 9005, Score: 0, Epsilon: 0.01
# Episode: 9006, Score: 0, Epsilon: 0.01
# Episode: 9007, Score: 0, Epsilon: 0.01
# Episode: 9008, Score: 0, Epsilon: 0.01
# Episode: 9009, Score: 0, Epsilon: 0.01
# Episode: 9010, Score: 0, Epsilon: 0.01
# Episode: 9011, Score: 0, Epsilon: 0.01
# Episode: 9012, Score: 0, Epsilon: 0.01
# Episode: 9013, Score: 0, Epsilon: 0.01
# Episode: 9014, Score: 0, Epsilon: 0.01
# Episode: 9015, Score: 0, Epsilon: 0.01
# Episode: 9016, Score: 0, Epsilon: 0.01
# Episode: 9017, Score: 0, Epsilon: 0.01
# Episode: 9018, Score: 1, Epsilon: 0.01
# Episode: 9019, Score: 0, Epsilon: 0.01
# Episode: 9020, Score: 0, Epsilon: 0.01
# Episode: 9021, Score: 0, Epsilon: 0.01
# Episode: 9022, Score: 0, Epsilon: 0.01
# Episode: 9023, Score: 0, Epsilon: 0.01
# Episode: 9024, Score: 0, Epsilon: 0.01
# Episode: 9025, Score: 0, Epsilon: 0.01
# Episode: 9026, Score: 0, Epsilon: 0.01
# Episode: 9027, Score: 0, Epsilon: 0.01
# Episode: 9028, Score: 1, Epsilon: 0.01
# Episode: 9029, Score: 0, Epsilon: 0.01
# Episode: 9030, Score: 0, Epsilon: 0.01
# Episode: 9031, Score: 0, Epsilon: 0.01
# Episode: 9032, Score: 0, Epsilon: 0.01
# Episode: 9033, Score: 0, Epsilon: 0.01
# Episode: 9034, Score: 0, Epsilon: 0.01
# Episode: 9035, Score: 0, Epsilon: 0.01
# Episode: 9036, Score: 0, Epsilon: 0.01
# Episode: 9037, Score: 0, Epsilon: 0.01
# Episode: 9038, Score: 0, Epsilon: 0.01
# Episode: 9039, Score: 0, Epsilon: 0.01
# Episode: 9040, Score: 0, Epsilon: 0.01
# Episode: 9041, Score: 0, Epsilon: 0.01
# Episode: 9042, Score: 0, Epsilon: 0.01
# Episode: 9043, Score: 0, Epsilon: 0.01
# Episode: 9044, Score: 0, Epsilon: 0.01
# Episode: 9045, Score: 0, Epsilon: 0.01
# Episode: 9046, Score: 0, Epsilon: 0.01
# Episode: 9047, Score: 0, Epsilon: 0.01
# Episode: 9048, Score: 0, Epsilon: 0.01
# Episode: 9049, Score: 0, Epsilon: 0.01
# Episode: 9050, Score: 0, Epsilon: 0.01
# Episode: 9051, Score: 0, Epsilon: 0.01
# Episode: 9052, Score: 0, Epsilon: 0.01
# Episode: 9053, Score: 0, Epsilon: 0.01
# Episode: 9054, Score: 0, Epsilon: 0.01
# Episode: 9055, Score: 1, Epsilon: 0.01
# Episode: 9056, Score: 0, Epsilon: 0.01
# Episode: 9057, Score: 0, Epsilon: 0.01
# Episode: 9058, Score: 0, Epsilon: 0.01
# Episode: 9059, Score: 1, Epsilon: 0.01
# Episode: 9060, Score: 0, Epsilon: 0.01
# Episode: 9061, Score: 0, Epsilon: 0.01
# Episode: 9062, Score: 0, Epsilon: 0.01
# Episode: 9063, Score: 0, Epsilon: 0.01
# Episode: 9064, Score: 0, Epsilon: 0.01
# Episode: 9065, Score: 0, Epsilon: 0.01
# Episode: 9066, Score: 0, Epsilon: 0.01
# Episode: 9067, Score: 0, Epsilon: 0.01
# Episode: 9068, Score: 0, Epsilon: 0.01
# Episode: 9072, Score: 0, Epsilon: 0.01
# Episode: 9073, Score: 0, Epsilon: 0.01
# Episode: 9074, Score: 0, Epsilon: 0.01
# Episode: 9075, Score: 0, Epsilon: 0.01
# Episode: 9076, Score: 0, Epsilon: 0.01
# Episode: 9077, Score: 0, Epsilon: 0.01
# Episode: 9078, Score: 0, Epsilon: 0.01
# Episode: 9079, Score: 1, Epsilon: 0.01
# Episode: 9082, Score: 0, Epsilon: 0.01
# Episode: 9089, Score: 0, Epsilon: 0.01
# Episode: 9093, Score: 0, Epsilon: 0.01
# Episode: 9094, Score: 0, Epsilon: 0.01
# Episode: 9095, Score: 0, Epsilon: 0.01
# Episode: 9096, Score: 0, Epsilon: 0.01
# Episode: 9097, Score: 0, Epsilon: 0.01
# Episode: 9098, Score: 0, Epsilon: 0.01
# Episode: 9099, Score: 0, Epsilon: 0.01
# Episode: 9100, Score: 0, Epsilon: 0.01
# Episode: 9101, Score: 1, Epsilon: 0.01
# Episode: 9102, Score: 0, Epsilon: 0.01
# Episode: 9103, Score: 0, Epsilon: 0.01
# Episode: 9104, Score: 0, Epsilon: 0.01
# Episode: 9106, Score: 0, Epsilon: 0.01
# Episode: 9107, Score: 0, Epsilon: 0.01
# Episode: 9108, Score: 0, Epsilon: 0.01
# Episode: 9109, Score: 0, Epsilon: 0.01
# Episode: 9110, Score: 0, Epsilon: 0.01
# Episode: 9111, Score: 0, Epsilon: 0.01
# Episode: 9112, Score: 0, Epsilon: 0.01
# Episode: 9113, Score: 0, Epsilon: 0.01
# Episode: 9114, Score: 0, Epsilon: 0.01
# Episode: 9115, Score: 0, Epsilon: 0.01
# Episode: 9116, Score: 0, Epsilon: 0.01
# Episode: 9117, Score: 1, Epsilon: 0.01
# Episode: 9118, Score: 0, Epsilon: 0.01
# Episode: 9119, Score: 0, Epsilon: 0.01
# Episode: 9120, Score: 0, Epsilon: 0.01
# Episode: 9121, Score: 0, Epsilon: 0.01
# Episode: 9122, Score: 0, Epsilon: 0.01
# Episode: 9123, Score: 0, Epsilon: 0.01
# Episode: 9124, Score: 0, Epsilon: 0.01
# Episode: 9125, Score: 0, Epsilon: 0.01
# Episode: 9126, Score: 0, Epsilon: 0.01
# Episode: 9129, Score: 0, Epsilon: 0.01
# Episode: 9130, Score: 0, Epsilon: 0.01
# Episode: 9132, Score: 0, Epsilon: 0.01
# Episode: 9133, Score: 0, Epsilon: 0.01
# Episode: 9134, Score: 0, Epsilon: 0.01
# Episode: 9135, Score: 0, Epsilon: 0.01
# Episode: 9136, Score: 0, Epsilon: 0.01
# Episode: 9137, Score: 0, Epsilon: 0.01
# Episode: 9138, Score: 0, Epsilon: 0.01
# Episode: 9139, Score: 0, Epsilon: 0.01
# Episode: 9140, Score: 0, Epsilon: 0.01
# Episode: 9141, Score: 0, Epsilon: 0.01
# Episode: 9142, Score: 0, Epsilon: 0.01
# Episode: 9143, Score: 0, Epsilon: 0.01
# Episode: 9144, Score: 0, Epsilon: 0.01
# Episode: 9145, Score: 0, Epsilon: 0.01
# Episode: 9147, Score: 0, Epsilon: 0.01
# Episode: 9148, Score: 0, Epsilon: 0.01
# Episode: 9149, Score: 0, Epsilon: 0.01
# Episode: 9150, Score: 0, Epsilon: 0.01
# Episode: 9151, Score: 0, Epsilon: 0.01
# Episode: 9152, Score: 0, Epsilon: 0.01
# Episode: 9153, Score: 0, Epsilon: 0.01
# Episode: 9154, Score: 0, Epsilon: 0.01
# Episode: 9155, Score: 0, Epsilon: 0.01
# Episode: 9156, Score: 1, Epsilon: 0.01
# Episode: 9157, Score: 0, Epsilon: 0.01
# Episode: 9158, Score: 0, Epsilon: 0.01
# Episode: 9159, Score: 0, Epsilon: 0.01
# Episode: 9162, Score: 0, Epsilon: 0.01
# Episode: 9163, Score: 1, Epsilon: 0.01
# Episode: 9165, Score: 0, Epsilon: 0.01
# Episode: 9166, Score: 0, Epsilon: 0.01
# Episode: 9167, Score: 0, Epsilon: 0.01
# Episode: 9168, Score: 0, Epsilon: 0.01
# Episode: 9169, Score: 0, Epsilon: 0.01
# Episode: 9170, Score: 0, Epsilon: 0.01
# Episode: 9171, Score: 1, Epsilon: 0.01
# Episode: 9172, Score: 0, Epsilon: 0.01
# Episode: 9173, Score: 0, Epsilon: 0.01
# Episode: 9174, Score: 0, Epsilon: 0.01
# Episode: 9175, Score: 0, Epsilon: 0.01
# Episode: 9176, Score: 0, Epsilon: 0.01
# Episode: 9177, Score: 0, Epsilon: 0.01
# Episode: 9178, Score: 0, Epsilon: 0.01
# Episode: 9179, Score: 0, Epsilon: 0.01
# Episode: 9181, Score: 0, Epsilon: 0.01
# Episode: 9182, Score: 0, Epsilon: 0.01
# Episode: 9183, Score: 1, Epsilon: 0.01
# Episode: 9184, Score: 0, Epsilon: 0.01
# Episode: 9185, Score: 0, Epsilon: 0.01
# Episode: 9186, Score: 0, Epsilon: 0.01
# Episode: 9187, Score: 0, Epsilon: 0.01
# Episode: 9188, Score: 0, Epsilon: 0.01
# Episode: 9189, Score: 0, Epsilon: 0.01
# Episode: 9190, Score: 0, Epsilon: 0.01
# Episode: 9191, Score: 0, Epsilon: 0.01
# Episode: 9192, Score: 0, Epsilon: 0.01
# Episode: 9193, Score: 0, Epsilon: 0.01
# Episode: 9194, Score: 0, Epsilon: 0.01
# Episode: 9196, Score: 0, Epsilon: 0.01
# Episode: 9197, Score: 0, Epsilon: 0.01
# Episode: 9198, Score: 0, Epsilon: 0.01
# Episode: 9199, Score: 0, Epsilon: 0.01
# Episode: 9200, Score: 0, Epsilon: 0.01
# Episode: 9201, Score: 0, Epsilon: 0.01
# Episode: 9202, Score: 1, Epsilon: 0.01
# Episode: 9203, Score: 0, Epsilon: 0.01
# Episode: 9204, Score: 0, Epsilon: 0.01
# Episode: 9205, Score: 0, Epsilon: 0.01
# Episode: 9206, Score: 0, Epsilon: 0.01
# Episode: 9207, Score: 0, Epsilon: 0.01
# Episode: 9208, Score: 0, Epsilon: 0.01
# Episode: 9209, Score: 1, Epsilon: 0.01
# Episode: 9210, Score: 0, Epsilon: 0.01
# Episode: 9211, Score: 0, Epsilon: 0.01
# Episode: 9212, Score: 0, Epsilon: 0.01
# Episode: 9213, Score: 0, Epsilon: 0.01
# Episode: 9214, Score: 1, Epsilon: 0.01
# Episode: 9215, Score: 0, Epsilon: 0.01
# Episode: 9216, Score: 0, Epsilon: 0.01
# Episode: 9217, Score: 0, Epsilon: 0.01
# Episode: 9218, Score: 0, Epsilon: 0.01
# Episode: 9219, Score: 0, Epsilon: 0.01
# Episode: 9220, Score: 0, Epsilon: 0.01
# Episode: 9222, Score: 0, Epsilon: 0.01
# Episode: 9223, Score: 0, Epsilon: 0.01
# Episode: 9224, Score: 0, Epsilon: 0.01
# Episode: 9225, Score: 0, Epsilon: 0.01
# Episode: 9226, Score: 0, Epsilon: 0.01
# Episode: 9227, Score: 0, Epsilon: 0.01
# Episode: 9228, Score: 0, Epsilon: 0.01
# Episode: 9229, Score: 0, Epsilon: 0.01
# Episode: 9230, Score: 0, Epsilon: 0.01
# Episode: 9232, Score: 0, Epsilon: 0.01
# Episode: 9234, Score: 0, Epsilon: 0.01
# Episode: 9236, Score: 0, Epsilon: 0.01
# Episode: 9237, Score: 0, Epsilon: 0.01
# Episode: 9238, Score: 1, Epsilon: 0.01
# Episode: 9239, Score: 0, Epsilon: 0.01
# Episode: 9240, Score: 0, Epsilon: 0.01
# Episode: 9241, Score: 2, Epsilon: 0.01
# Episode: 9242, Score: 0, Epsilon: 0.01
# Episode: 9243, Score: 1, Epsilon: 0.01
# Episode: 9244, Score: 0, Epsilon: 0.01
# Episode: 9245, Score: 0, Epsilon: 0.01
# Episode: 9246, Score: 0, Epsilon: 0.01
# Episode: 9247, Score: 0, Epsilon: 0.01
# Episode: 9248, Score: 0, Epsilon: 0.01
# Episode: 9249, Score: 0, Epsilon: 0.01
# Episode: 9250, Score: 0, Epsilon: 0.01
# Saved model at episode 9250
# Training time for RNN after 9250 episodes: 5491.68 seconds
# Episode: 9251, Score: 0, Epsilon: 0.01
# Episode: 9252, Score: 0, Epsilon: 0.01
# Episode: 9253, Score: 0, Epsilon: 0.01
# Episode: 9254, Score: 0, Epsilon: 0.01
# Episode: 9255, Score: 0, Epsilon: 0.01
# Episode: 9256, Score: 0, Epsilon: 0.01
# Episode: 9257, Score: 0, Epsilon: 0.01
# Episode: 9258, Score: 0, Epsilon: 0.01
# Episode: 9259, Score: 0, Epsilon: 0.01
# Episode: 9260, Score: 0, Epsilon: 0.01
# Episode: 9261, Score: 0, Epsilon: 0.01
# Episode: 9262, Score: 0, Epsilon: 0.01
# Episode: 9263, Score: 0, Epsilon: 0.01
# Episode: 9266, Score: 0, Epsilon: 0.01
# Episode: 9267, Score: 0, Epsilon: 0.01
# Episode: 9268, Score: 0, Epsilon: 0.01
# Episode: 9269, Score: 0, Epsilon: 0.01
# Episode: 9270, Score: 1, Epsilon: 0.01
# Episode: 9271, Score: 0, Epsilon: 0.01
# Episode: 9272, Score: 0, Epsilon: 0.01
# Episode: 9273, Score: 0, Epsilon: 0.01
# Episode: 9275, Score: 0, Epsilon: 0.01
# Episode: 9276, Score: 0, Epsilon: 0.01
# Episode: 9277, Score: 0, Epsilon: 0.01
# Episode: 9278, Score: 0, Epsilon: 0.01
# Episode: 9279, Score: 0, Epsilon: 0.01
# Episode: 9281, Score: 1, Epsilon: 0.01
# Episode: 9282, Score: 1, Epsilon: 0.01
# ...
# Episode: 10247, Score: 0, Epsilon: 0.01
# Episode: 10248, Score: 0, Epsilon: 0.01
# Episode: 10249, Score: 1, Epsilon: 0.01
# Episode: 10250, Score: 0, Epsilon: 0.01
# Saved model at episode 10250
# Training time for RNN after 10250 episodes: 5063.58 seconds
# Episode: 10251, Score: 0, Epsilon: 0.01
# Episode: 10252, Score: 1, Epsilon: 0.01
# Episode: 10253, Score: 0, Epsilon: 0.01
# Episode: 10254, Score: 0, Epsilon: 0.01
# Episode: 10255, Score: 0, Epsilon: 0.01
# Episode: 10256, Score: 0, Epsilon: 0.01
# Episode: 10257, Score: 0, Epsilon: 0.01
# Episode: 10258, Score: 0, Epsilon: 0.01
# Episode: 10259, Score: 0, Epsilon: 0.01
# Episode: 10260, Score: 0, Epsilon: 0.01
# Episode: 10261, Score: 0, Epsilon: 0.01
# Episode: 10262, Score: 1, Epsilon: 0.01
# Episode: 10263, Score: 0, Epsilon: 0.01
# Episode: 10264, Score: 0, Epsilon: 0.01
# Episode: 10265, Score: 0, Epsilon: 0.01
# Episode: 10266, Score: 0, Epsilon: 0.01
# Episode: 10267, Score: 0, Epsilon: 0.01
# Episode: 10268, Score: 1, Epsilon: 0.01
# Episode: 10269, Score: 0, Epsilon: 0.01
# Episode: 10270, Score: 0, Epsilon: 0.01
# Episode: 10271, Score: 0, Epsilon: 0.01
# Episode: 10272, Score: 0, Epsilon: 0.01
# Episode: 10273, Score: 0, Epsilon: 0.01
# Episode: 10274, Score: 0, Epsilon: 0.01
# Episode: 10275, Score: 0, Epsilon: 0.01
# Episode: 10276, Score: 0, Epsilon: 0.01
# Episode: 10277, Score: 0, Epsilon: 0.01
# Episode: 10278, Score: 0, Epsilon: 0.01
# Episode: 10279, Score: 0, Epsilon: 0.01
# Episode: 10280, Score: 0, Epsilon: 0.01
# Episode: 10281, Score: 0, Epsilon: 0.01
# Episode: 10282, Score: 0, Epsilon: 0.01
# Episode: 10283, Score: 0, Epsilon: 0.01
# Episode: 10284, Score: 0, Epsilon: 0.01
# Episode: 10285, Score: 0, Epsilon: 0.01
# Episode: 10287, Score: 0, Epsilon: 0.01
# Episode: 10288, Score: 0, Epsilon: 0.01
# Episode: 10289, Score: 0, Epsilon: 0.01
# Episode: 10290, Score: 0, Epsilon: 0.01
# Episode: 10291, Score: 0, Epsilon: 0.01
# Episode: 10292, Score: 0, Epsilon: 0.01
# Episode: 10293, Score: 0, Epsilon: 0.01
# Episode: 10294, Score: 0, Epsilon: 0.01
# Episode: 10295, Score: 0, Epsilon: 0.01
# Episode: 10296, Score: 0, Epsilon: 0.01
# Episode: 10297, Score: 0, Epsilon: 0.01
# Episode: 10298, Score: 0, Epsilon: 0.01
# Episode: 10299, Score: 0, Epsilon: 0.01
# Episode: 10300, Score: 0, Epsilon: 0.01
# Episode: 10301, Score: 0, Epsilon: 0.01
# Episode: 10302, Score: 0, Epsilon: 0.01
# Episode: 10303, Score: 0, Epsilon: 0.01
# Episode: 10304, Score: 0, Epsilon: 0.01
# Episode: 10305, Score: 0, Epsilon: 0.01
# Episode: 10306, Score: 0, Epsilon: 0.01
# Episode: 10307, Score: 0, Epsilon: 0.01
# Episode: 10308, Score: 0, Epsilon: 0.01
# Episode: 10309, Score: 0, Epsilon: 0.01
# Episode: 10310, Score: 0, Epsilon: 0.01
# Episode: 10311, Score: 1, Epsilon: 0.01
# Episode: 10312, Score: 0, Epsilon: 0.01
# Episode: 10313, Score: 0, Epsilon: 0.01
# Episode: 10314, Score: 1, Epsilon: 0.01
# Episode: 10315, Score: 0, Epsilon: 0.01
# Episode: 10316, Score: 0, Epsilon: 0.01
# Episode: 10317, Score: 0, Epsilon: 0.01
# Episode: 10318, Score: 0, Epsilon: 0.01
# Episode: 10319, Score: 0, Epsilon: 0.01
# Episode: 10320, Score: 0, Epsilon: 0.01
# Episode: 10321, Score: 1, Epsilon: 0.01
# Episode: 10322, Score: 0, Epsilon: 0.01
# Episode: 10323, Score: 0, Epsilon: 0.01
# Episode: 10324, Score: 0, Epsilon: 0.01
# Episode: 10325, Score: 0, Epsilon: 0.01
# Episode: 10327, Score: 0, Epsilon: 0.01
# Episode: 10328, Score: 0, Epsilon: 0.01
# Episode: 10329, Score: 0, Epsilon: 0.01
# Episode: 10332, Score: 1, Epsilon: 0.01
# Episode: 10333, Score: 1, Epsilon: 0.01
# Episode: 10334, Score: 0, Epsilon: 0.01
# Episode: 10335, Score: 0, Epsilon: 0.01
# Episode: 10336, Score: 0, Epsilon: 0.01
# Episode: 10337, Score: 0, Epsilon: 0.01
# Episode: 10338, Score: 0, Epsilon: 0.01
# Episode: 10339, Score: 0, Epsilon: 0.01
# Episode: 10340, Score: 0, Epsilon: 0.01
# Episode: 10341, Score: 0, Epsilon: 0.01
# Episode: 10342, Score: 0, Epsilon: 0.01
# Episode: 10343, Score: 0, Epsilon: 0.01
# Episode: 10345, Score: 0, Epsilon: 0.01
# Episode: 10346, Score: 0, Epsilon: 0.01
# Episode: 10347, Score: 0, Epsilon: 0.01
# Episode: 10348, Score: 1, Epsilon: 0.01
# Episode: 10349, Score: 0, Epsilon: 0.01
# Episode: 10350, Score: 0, Epsilon: 0.01
# Episode: 10351, Score: 0, Epsilon: 0.01
# Episode: 10352, Score: 0, Epsilon: 0.01
# Episode: 10353, Score: 0, Epsilon: 0.01
# Episode: 10354, Score: 1, Epsilon: 0.01
# Episode: 10355, Score: 0, Epsilon: 0.01
# Episode: 10358, Score: 0, Epsilon: 0.01
# Episode: 10359, Score: 0, Epsilon: 0.01
# Episode: 10360, Score: 0, Epsilon: 0.01
# Episode: 10361, Score: 0, Epsilon: 0.01
# Episode: 10362, Score: 0, Epsilon: 0.01
# Episode: 10363, Score: 0, Epsilon: 0.01
# Episode: 10364, Score: 0, Epsilon: 0.01
# Episode: 10365, Score: 0, Epsilon: 0.01
# Episode: 10366, Score: 0, Epsilon: 0.01
# Episode: 10367, Score: 0, Epsilon: 0.01
# Episode: 10368, Score: 0, Epsilon: 0.01
# Episode: 10369, Score: 0, Epsilon: 0.01
# Episode: 10370, Score: 0, Epsilon: 0.01
# Episode: 10371, Score: 0, Epsilon: 0.01
# Episode: 10372, Score: 0, Epsilon: 0.01
# Episode: 10373, Score: 0, Epsilon: 0.01
# Episode: 10374, Score: 0, Epsilon: 0.01
# Episode: 10375, Score: 0, Epsilon: 0.01
# Episode: 10376, Score: 0, Epsilon: 0.01
# Episode: 10377, Score: 0, Epsilon: 0.01
# Episode: 10379, Score: 0, Epsilon: 0.01
# Episode: 10380, Score: 0, Epsilon: 0.01
# Episode: 10381, Score: 0, Epsilon: 0.01
# Episode: 10382, Score: 0, Epsilon: 0.01
# Episode: 10383, Score: 0, Epsilon: 0.01
# Episode: 10384, Score: 0, Epsilon: 0.01
# Episode: 10385, Score: 0, Epsilon: 0.01
# Episode: 10387, Score: 0, Epsilon: 0.01
# Episode: 10389, Score: 1, Epsilon: 0.01
# Episode: 10390, Score: 0, Epsilon: 0.01
# Episode: 10391, Score: 0, Epsilon: 0.01
# Episode: 10392, Score: 0, Epsilon: 0.01
# Episode: 10393, Score: 0, Epsilon: 0.01
# Episode: 10394, Score: 0, Epsilon: 0.01
# Episode: 10395, Score: 0, Epsilon: 0.01
# Episode: 10396, Score: 0, Epsilon: 0.01
# Episode: 10397, Score: 0, Epsilon: 0.01
# Episode: 10398, Score: 0, Epsilon: 0.01
# Episode: 10399, Score: 0, Epsilon: 0.01
# Episode: 10400, Score: 1, Epsilon: 0.01
# Episode: 10401, Score: 0, Epsilon: 0.01
# Episode: 10402, Score: 0, Epsilon: 0.01
# Episode: 10403, Score: 0, Epsilon: 0.01
# Episode: 10404, Score: 0, Epsilon: 0.01
# Episode: 10405, Score: 0, Epsilon: 0.01
# Episode: 10406, Score: 0, Epsilon: 0.01
# Episode: 10407, Score: 0, Epsilon: 0.01
# Episode: 10408, Score: 0, Epsilon: 0.01
# Episode: 10409, Score: 0, Epsilon: 0.01
# Episode: 10410, Score: 0, Epsilon: 0.01
# Episode: 10411, Score: 0, Epsilon: 0.01
# Episode: 10412, Score: 0, Epsilon: 0.01
# Episode: 10414, Score: 0, Epsilon: 0.01
# Episode: 10415, Score: 0, Epsilon: 0.01
# Episode: 10416, Score: 0, Epsilon: 0.01
# Episode: 10417, Score: 0, Epsilon: 0.01
# Episode: 10418, Score: 0, Epsilon: 0.01
# Episode: 10419, Score: 0, Epsilon: 0.01
# Episode: 10420, Score: 0, Epsilon: 0.01
# Episode: 10421, Score: 1, Epsilon: 0.01
# Episode: 10422, Score: 0, Epsilon: 0.01
# Episode: 10423, Score: 0, Epsilon: 0.01
# Episode: 10424, Score: 0, Epsilon: 0.01
# Episode: 10426, Score: 0, Epsilon: 0.01
# Episode: 10427, Score: 0, Epsilon: 0.01
# Episode: 10428, Score: 0, Epsilon: 0.01
# Episode: 10429, Score: 0, Epsilon: 0.01
# Episode: 10430, Score: 0, Epsilon: 0.01
# Episode: 10431, Score: 1, Epsilon: 0.01
# Episode: 10432, Score: 0, Epsilon: 0.01
# Episode: 10433, Score: 0, Epsilon: 0.01
# Episode: 10434, Score: 0, Epsilon: 0.01
# Episode: 10435, Score: 1, Epsilon: 0.01
# Episode: 10436, Score: 0, Epsilon: 0.01
# Episode: 10437, Score: 1, Epsilon: 0.01
# Episode: 10438, Score: 0, Epsilon: 0.01
# Episode: 10439, Score: 0, Epsilon: 0.01
# Episode: 10440, Score: 0, Epsilon: 0.01
# Episode: 10441, Score: 0, Epsilon: 0.01
# Episode: 10442, Score: 0, Epsilon: 0.01
# Episode: 10443, Score: 0, Epsilon: 0.01
# Episode: 10444, Score: 0, Epsilon: 0.01
# Episode: 10445, Score: 0, Epsilon: 0.01
# Episode: 10446, Score: 0, Epsilon: 0.01
# Episode: 10449, Score: 1, Epsilon: 0.01
# Episode: 10450, Score: 0, Epsilon: 0.01
# Episode: 10451, Score: 0, Epsilon: 0.01
# Episode: 10452, Score: 0, Epsilon: 0.01
# Episode: 10454, Score: 0, Epsilon: 0.01
# Episode: 10455, Score: 0, Epsilon: 0.01
# Episode: 10456, Score: 0, Epsilon: 0.01
# Episode: 10457, Score: 0, Epsilon: 0.01
# Episode: 10458, Score: 0, Epsilon: 0.01
# Episode: 10459, Score: 0, Epsilon: 0.01
# Episode: 10460, Score: 0, Epsilon: 0.01
# Episode: 10461, Score: 0, Epsilon: 0.01
# Episode: 10462, Score: 0, Epsilon: 0.01
# Episode: 10463, Score: 0, Epsilon: 0.01
# Episode: 10464, Score: 0, Epsilon: 0.01
# Episode: 10466, Score: 0, Epsilon: 0.01
# Episode: 10467, Score: 0, Epsilon: 0.01
# Episode: 10468, Score: 0, Epsilon: 0.01
# Episode: 10469, Score: 0, Epsilon: 0.01
# Episode: 10470, Score: 0, Epsilon: 0.01
# Episode: 10471, Score: 0, Epsilon: 0.01
# Episode: 10472, Score: 0, Epsilon: 0.01
# Episode: 10473, Score: 0, Epsilon: 0.01
# Episode: 10474, Score: 1, Epsilon: 0.01
# Episode: 10475, Score: 0, Epsilon: 0.01
# Episode: 10476, Score: 0, Epsilon: 0.01
# Episode: 10482, Score: 0, Epsilon: 0.01
# Episode: 10485, Score: 1, Epsilon: 0.01
# Episode: 10486, Score: 0, Epsilon: 0.01
# Episode: 10487, Score: 0, Epsilon: 0.01
# Episode: 10488, Score: 0, Epsilon: 0.01
# Episode: 10489, Score: 0, Epsilon: 0.01
# Episode: 10490, Score: 0, Epsilon: 0.01
# Episode: 10491, Score: 0, Epsilon: 0.01
# Episode: 10492, Score: 0, Epsilon: 0.01
# Episode: 10493, Score: 0, Epsilon: 0.01
# Episode: 10494, Score: 0, Epsilon: 0.01
# Episode: 10496, Score: 0, Epsilon: 0.01
# Episode: 10497, Score: 0, Epsilon: 0.01
# Episode: 10498, Score: 0, Epsilon: 0.01
# Episode: 10499, Score: 0, Epsilon: 0.01
# Episode: 10500, Score: 0, Epsilon: 0.01
# Saved model at episode 10500
# Training time for RNN after 10500 episodes: 5979.12 seconds
# Episode: 10501, Score: 0, Epsilon: 0.01
# Episode: 10502, Score: 0, Epsilon: 0.01
# Episode: 10503, Score: 1, Epsilon: 0.01
# Episode: 10504, Score: 0, Epsilon: 0.01
# Episode: 10505, Score: 0, Epsilon: 0.01
# Episode: 10506, Score: 0, Epsilon: 0.01
# Episode: 10507, Score: 0, Epsilon: 0.01
# Episode: 10508, Score: 0, Epsilon: 0.01
# Episode: 10509, Score: 0, Epsilon: 0.01
# Episode: 10510, Score: 0, Epsilon: 0.01
# Episode: 10511, Score: 0, Epsilon: 0.01
# Episode: 10512, Score: 1, Epsilon: 0.01
# Episode: 10513, Score: 0, Epsilon: 0.01
# Episode: 10514, Score: 0, Epsilon: 0.01
# Episode: 10515, Score: 1, Epsilon: 0.01
# Episode: 10516, Score: 0, Epsilon: 0.01
# Episode: 10517, Score: 0, Epsilon: 0.01
# Episode: 10518, Score: 0, Epsilon: 0.01
# Episode: 10519, Score: 0, Epsilon: 0.01
# Episode: 10522, Score: 0, Epsilon: 0.01
# Episode: 10523, Score: 0, Epsilon: 0.01
# Episode: 10524, Score: 0, Epsilon: 0.01
# Episode: 10525, Score: 0, Epsilon: 0.01
# Episode: 10527, Score: 0, Epsilon: 0.01
# Episode: 10528, Score: 0, Epsilon: 0.01
# Episode: 10529, Score: 0, Epsilon: 0.01
# Episode: 10530, Score: 0, Epsilon: 0.01
# Episode: 10531, Score: 0, Epsilon: 0.01
# Episode: 10532, Score: 0, Epsilon: 0.01
# Episode: 10533, Score: 0, Epsilon: 0.01
# Episode: 10534, Score: 0, Epsilon: 0.01
# Episode: 10535, Score: 0, Epsilon: 0.01
# Episode: 10536, Score: 0, Epsilon: 0.01
# Episode: 10537, Score: 0, Epsilon: 0.01
# Episode: 10538, Score: 0, Epsilon: 0.01
# Episode: 10539, Score: 0, Epsilon: 0.01
# Episode: 10540, Score: 0, Epsilon: 0.01
# Episode: 10541, Score: 0, Epsilon: 0.01
# Episode: 10542, Score: 0, Epsilon: 0.01
# Episode: 10543, Score: 0, Epsilon: 0.01
# Episode: 10544, Score: 0, Epsilon: 0.01
# Episode: 10545, Score: 0, Epsilon: 0.01
# Episode: 10546, Score: 0, Epsilon: 0.01
# Episode: 10547, Score: 0, Epsilon: 0.01
# Episode: 10548, Score: 0, Epsilon: 0.01
# Episode: 10549, Score: 1, Epsilon: 0.01
# Episode: 10550, Score: 0, Epsilon: 0.01
# Episode: 10551, Score: 0, Epsilon: 0.01
# Episode: 10552, Score: 0, Epsilon: 0.01
# Episode: 10553, Score: 0, Epsilon: 0.01
# Episode: 10554, Score: 0, Epsilon: 0.01
# Episode: 10555, Score: 0, Epsilon: 0.01
# Episode: 10556, Score: 0, Epsilon: 0.01
# Episode: 10557, Score: 0, Epsilon: 0.01
# Episode: 10558, Score: 0, Epsilon: 0.01
# Episode: 10559, Score: 0, Epsilon: 0.01
# Episode: 10560, Score: 0, Epsilon: 0.01
# Episode: 10561, Score: 0, Epsilon: 0.01
# Episode: 10562, Score: 0, Epsilon: 0.01
# Episode: 10563, Score: 0, Epsilon: 0.01
# Episode: 10564, Score: 0, Epsilon: 0.01
# Episode: 10565, Score: 0, Epsilon: 0.01
# Episode: 10566, Score: 0, Epsilon: 0.01
# Episode: 10567, Score: 0, Epsilon: 0.01
# Episode: 10568, Score: 0, Epsilon: 0.01
# Episode: 10569, Score: 1, Epsilon: 0.01
# Episode: 10570, Score: 0, Epsilon: 0.01
# Episode: 10571, Score: 0, Epsilon: 0.01
# Episode: 10572, Score: 0, Epsilon: 0.01
# Episode: 10573, Score: 0, Epsilon: 0.01
# Episode: 10574, Score: 0, Epsilon: 0.01
# Episode: 10575, Score: 0, Epsilon: 0.01
# Episode: 10576, Score: 0, Epsilon: 0.01
# Episode: 10577, Score: 0, Epsilon: 0.01
# Episode: 10578, Score: 0, Epsilon: 0.01
# Episode: 10579, Score: 0, Epsilon: 0.01
# Episode: 10580, Score: 0, Epsilon: 0.01
# Episode: 10581, Score: 0, Epsilon: 0.01
# Episode: 10582, Score: 0, Epsilon: 0.01
# Episode: 10583, Score: 1, Epsilon: 0.01
# Episode: 10584, Score: 0, Epsilon: 0.01
# Episode: 10585, Score: 0, Epsilon: 0.01
# Episode: 10586, Score: 0, Epsilon: 0.01
# Episode: 10587, Score: 0, Epsilon: 0.01
# Episode: 10590, Score: 0, Epsilon: 0.01
# Episode: 10591, Score: 0, Epsilon: 0.01
# Episode: 10592, Score: 0, Epsilon: 0.01
# Episode: 10594, Score: 0, Epsilon: 0.01
# Episode: 10595, Score: 0, Epsilon: 0.01
# Episode: 10597, Score: 0, Epsilon: 0.01
# Episode: 10598, Score: 0, Epsilon: 0.01
# Episode: 10600, Score: 0, Epsilon: 0.01
# Episode: 10601, Score: 0, Epsilon: 0.01
# Episode: 10602, Score: 0, Epsilon: 0.01
# Episode: 10603, Score: 1, Epsilon: 0.01
# Episode: 10604, Score: 0, Epsilon: 0.01
# Episode: 10605, Score: 0, Epsilon: 0.01
# Episode: 10606, Score: 0, Epsilon: 0.01
# Episode: 10607, Score: 0, Epsilon: 0.01
# Episode: 10608, Score: 0, Epsilon: 0.01
# Episode: 10609, Score: 1, Epsilon: 0.01
# Episode: 10610, Score: 0, Epsilon: 0.01
# Episode: 10611, Score: 0, Epsilon: 0.01
# Episode: 10612, Score: 0, Epsilon: 0.01
# Episode: 10613, Score: 0, Epsilon: 0.01
# Episode: 10614, Score: 0, Epsilon: 0.01
# Episode: 10615, Score: 0, Epsilon: 0.01
# Episode: 10616, Score: 0, Epsilon: 0.01
# Episode: 10617, Score: 0, Epsilon: 0.01
# Episode: 10618, Score: 0, Epsilon: 0.01
# Episode: 10619, Score: 0, Epsilon: 0.01
# Episode: 10621, Score: 0, Epsilon: 0.01
# Episode: 10622, Score: 0, Epsilon: 0.01
# Episode: 10623, Score: 0, Epsilon: 0.01
# Episode: 10624, Score: 0, Epsilon: 0.01
# Episode: 10626, Score: 0, Epsilon: 0.01
# Episode: 10627, Score: 0, Epsilon: 0.01
# Episode: 10628, Score: 0, Epsilon: 0.01
# Episode: 10629, Score: 0, Epsilon: 0.01
# Episode: 10632, Score: 0, Epsilon: 0.01
# Episode: 10635, Score: 1, Epsilon: 0.01
# Episode: 10636, Score: 0, Epsilon: 0.01
# Episode: 10637, Score: 0, Epsilon: 0.01
# Episode: 10638, Score: 0, Epsilon: 0.01
# Episode: 10639, Score: 0, Epsilon: 0.01
# Episode: 10640, Score: 0, Epsilon: 0.01
# Episode: 10641, Score: 0, Epsilon: 0.01
# Episode: 10642, Score: 0, Epsilon: 0.01
# Episode: 10643, Score: 0, Epsilon: 0.01
# Episode: 10644, Score: 0, Epsilon: 0.01
# Episode: 10646, Score: 0, Epsilon: 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 235
#     232 if __name__ == "__main__":
#     233     # 'RNN',
#     234     load_path = f"{'RNN'.lower()}_snake_model_8000.pth" if torch.cuda.is_available() else None
# --> 235     train_until_achieve_score('RNN', load_path=load_path, saved_episode = 8000)
#     236     for model_type in ['GRU', 'LSTM']:
#     237         # Specify the path to load the model if it exists, otherwise set to None
#     238         load_path = f"{model_type.lower()}_snake_model_final.pth" if torch.cuda.is_available() else None
#
# Cell In[1], line 214, in train_until_achieve_score(model_type, target_score, load_path, saved_episode)
#     212         break
#     213     if len(agent.memory) > batch_size:
# --> 214         agent.replay(batch_size)
#     215 if episode % 250 == 0:
#     216     torch.save(agent.model.state_dict(), f"{model_type.lower()}_snake_model_{episode}.pth")
#
# Cell In[1], line 98, in DQNAgent.replay(self, batch_size)
#      96 if not done:
#      97     next_hidden = self.model.init_hidden(1)
# ---> 98     target = (reward + self.gamma * torch.max(self.model(next_state, next_hidden)[0][0])).item()
#      99 target_f = self.model(state, self.model.init_hidden(1))[0]
#     100 target_f[0][action] = target
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import time
import pygame

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LSTMSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.hidden_size).to(device),
                torch.zeros(1, batch_size, self.hidden_size).to(device))

class RNNSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNNSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.rnn(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class GRUSnakeNet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GRUSnakeNet, self).__init__()
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden):
        out, hidden = self.gru(x, hidden)
        out = self.fc(out[:, -1, :])
        return out, hidden

    def init_hidden(self, batch_size):
        return torch.zeros(1, batch_size, self.hidden_size).to(device)

class DQNAgent:
    def __init__(self, state_size, action_size, hidden_size, model_type='LSTM'):
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        
        if model_type == 'RNN':
            self.model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
        elif model_type == 'GRU':
            self.model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
        else:  # Default to LSTM
            self.model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)

        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state, hidden):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size), hidden
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        action_values, hidden = self.model(state, hidden)
        return torch.argmax(action_values[0]).item(), hidden

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
            next_state = torch.FloatTensor(next_state).unsqueeze(0).unsqueeze(0).to(device)
            target = reward
            if not done:
                next_hidden = self.model.init_hidden(1)
                target = (reward + self.gamma * torch.max(self.model(next_state, next_hidden)[0][0])).item()
            target_f = self.model(state, self.model.init_hidden(1))[0]
            target_f[0][action] = target
            self.optimizer.zero_grad()
            loss = self.criterion(target_f, self.model(state, self.model.init_hidden(1))[0])
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

class SnakeGameAI:
    def __init__(self, width=640, height=480, snake_size=20):
        self.width = width
        self.height = height
        self.snake_size = snake_size
        self.reset()

    def reset(self):
        self.x1 = self.width / 2
        self.y1 = self.height / 2
        self.x1_change = 0
        self.y1_change = 0
        self.snake_List = []
        self.Length_of_snake = 1
        self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
        self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
        self.score = 0
        return self.get_state()

    def step(self, action):
        if action == 0:  # LEFT
            self.x1_change = -self.snake_size
            self.y1_change = 0
        elif action == 1:  # RIGHT
            self.x1_change = self.snake_size
            self.y1_change = 0
        elif action == 2:  # UP
            self.y1_change = -self.snake_size
            self.x1_change = 0
        elif action == 3:  # DOWN
            self.y1_change = self.snake_size
            self.x1_change = 0

        self.x1 += self.x1_change
        self.y1 += self.y1_change

        done = self.x1 >= self.width or self.x1 < 0 or self.y1 >= self.height or self.y1 < 0
        snake_Head = [self.x1, self.y1]
        self.snake_List.append(snake_Head)
        if len(self.snake_List) > self.Length_of_snake:
            del self.snake_List[0]

        for x in self.snake_List[:-1]:
            if x == snake_Head:
                done = True

        reward = 0
        if self.x1 == self.foodx and self.y1 == self.foody:
            self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
            self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
            self.Length_of_snake += 1
            reward = 10
            self.score += 1

        if done:
            reward = -10

        state = self.get_state()
        return state, reward, done

    def get_state(self):
        state = [
            self.x1, self.y1, self.foodx, self.foody,
            self.x1_change, self.y1_change,
        ]
        return np.array(state, dtype=np.float32)

    def render(self):
        window = pygame.display.set_mode((self.width, self.height))
        window.fill((0, 0, 0))
        for segment in self.snake_List:
            pygame.draw.rect(window, (0, 255, 0), [segment[0], segment[1], self.snake_size, self.snake_size])
        pygame.draw.rect(window, (255, 255, 255), [self.foodx, self.foody, self.snake_size, self.snake_size])

def load_model(model_type, model_path, state_size, hidden_size, action_size):
    if model_type == 'RNN':
        model = RNNSnakeNet(state_size, hidden_size, action_size).to(device)
    elif model_type == 'GRU':
        model = GRUSnakeNet(state_size, hidden_size, action_size).to(device)
    else:  # Default to LSTM
        model = LSTMSnakeNet(state_size, hidden_size, action_size).to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

def draw_text(surface, text, font, color, x, y):
    text_obj = font.render(text, True, color)
    text_rect = text_obj.get_rect(center=(x, y))
    surface.blit(text_obj, text_rect)

def wait_for_click():
    waiting = True
    while waiting:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                return False
            if event.type == pygame.MOUSEBUTTONDOWN:
                return True
        pygame.display.flip()
        pygame.time.Clock().tick(30)
    return False

def play_game(model, game, display=True):
    pygame.init()
    window = pygame.display.set_mode((game.width, game.height)) 
    pygame.display.set_caption("Snake Game AI")
    font = pygame.font.SysFont(None, 55)
    
    window.fill((0, 0, 0))
    draw_text(window, "Click to Start", font, (255, 255, 255), game.width // 2, game.height // 2)
    pygame.display.flip()
    
    if not wait_for_click():
        return

    state = game.reset()
    hidden = model.init_hidden(1)
    done = False
    clock = pygame.time.Clock()

    while not done:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                return

        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)
        with torch.no_grad():
            action_values, hidden = model(state, hidden)
        action = torch.argmax(action_values[0]).item()
        
        next_state, _, done = game.step(action)
        state = next_state
        
        if display:
            game.render()
            pygame.display.flip()
            clock.tick(10)

    print(f"Final Score: {game.score}")
    pygame.quit()

if __name__ == "__main__":
    model_type = 'RNN'  # Ensure this matches the model type used during training
    model_path = "rnn/rnn_snake_model_10500.pth"

    state_size = 6
    hidden_size = 64
    action_size = 4
    model = load_model(model_type, model_path, state_size, hidden_size, action_size)

    game = SnakeGameAI()

    for i in range(5):
        play_game(model, game)
# Out:
# Final Score: 0
# Final Score: 0
# Final Score: 0
# Final Score: 0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import numpy as np
import time
import pygame
import matplotlib.pyplot as plt
import csv
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

class ResidualCNN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ResidualCNN, self).__init__()
        self.conv1 = nn.Conv2d(input_dim, 64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(64, 64, stride=1)
        self.layer2 = self._make_layer(64, 128, stride=2)
        self.fc1 = nn.Linear(128 * 1 * 3, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, output_dim)

    def _make_layer(self, in_channels, out_channels, stride):
        return nn.Sequential(
            ResidualBlock(in_channels, out_channels, stride),
            ResidualBlock(out_channels, out_channels),
        )

    def forward(self, x):
        x = x.unsqueeze(2)  # Add a dummy height dimension
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = torch.relu(self.fc1(out))
        out = torch.relu(self.fc2(out))
        out = self.fc3(out)
        return out

class DQNAgent:
    def __init__(self, input_dim, action_dim):
        self.input_dim = input_dim
        self.action_dim = action_dim
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        self.model = ResidualCNN(input_dim, action_dim).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_dim)
        state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)  # Reshape to [1, 1, 1, 6]
        with torch.no_grad():
            action_values = self.model(state)
        return torch.argmax(action_values[0]).item()

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = torch.FloatTensor(state).unsqueeze(0).unsqueeze(0).to(device)  # Ensure batch dimension
            next_state = torch.FloatTensor(next_state).unsqueeze(0).unsqueeze(0).to(device)  # Ensure batch dimension
            target = reward
            if not done:
                target = (reward + self.gamma * torch.max(self.model(next_state)[0])).item()
            target_f = self.model(state)[0]
            target_f[action] = target
            self.optimizer.zero_grad()
            loss = self.criterion(target_f, self.model(state)[0])
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

class SnakeGameAI:
    def __init__(self, width=640, height=480, snake_size=20):
        self.width = width
        self.height = height
        self.snake_size = snake_size
        self.reset()

    def reset(self):
        self.x1 = self.width / 2
        self.y1 = self.height / 2
        self.x1_change = 0
        self.y1_change = 0
        self.snake_List = []
        self.Length_of_snake = 1
        self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
        self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
        self.score = 0
        return self.get_state()

    def step(self, action):
        if action == 0:  # LEFT
            self.x1_change = -self.snake_size
            self.y1_change = 0
        elif action == 1:  # RIGHT
            self.x1_change = self.snake_size
            self.y1_change = 0
        elif action == 2:  # UP
            self.y1_change = -self.snake_size
            self.x1_change = 0
        elif action == 3:  # DOWN
            self.y1_change = self.snake_size
            self.x1_change = 0

        self.x1 += self.x1_change
        self.y1 += self.y1_change

        done = self.x1 >= self.width or self.x1 < 0 or self.y1 >= self.height or self.y1 < 0
        snake_Head = [self.x1, self.y1]
        self.snake_List.append(snake_Head)
        if len(self.snake_List) > self.Length_of_snake:
            del self.snake_List[0]

        for x in self.snake_List[:-1]:
            if x == snake_Head:
                done = True

        reward = 0
        if self.x1 == self.foodx and self.y1 == self.foody:
            self.foodx = round(random.randrange(0, self.width - self.snake_size) / self.snake_size) * self.snake_size
            self.foody = round(random.randrange(0, self.height - self.snake_size) / self.snake_size) * self.snake_size
            self.Length_of_snake += 1
            reward = 10 * self.Length_of_snake
            self.score += 1

        if done:
            reward = 0

        state = self.get_state()
        return state, reward, done

    def get_state(self):
        state = [
            self.x1, self.y1, self.foodx, self.foody,
            self.x1_change, self.y1_change,
        ]
        return np.array(state, dtype=np.float32)

    def render(self):
        window = pygame.display.set_mode((self.width, self.height))
        window.fill((0, 0, 0))
        for segment in self.snake_List:
            pygame.draw.rect(window, (0, 255, 0), [segment[0], segment[1], self.snake_size, self.snake_size])
        pygame.draw.rect(window, (255, 255, 255), [self.foodx, self.foody, self.snake_size, self.snake_size])
        pygame.display.update()

def draw_text(surface, text, font, color, x, y):
    text_obj = font.render(text, True, color)
    text_rect = text_obj.get_rect(center=(x, y))
    surface.blit(text_obj, text_rect)

def wait_for_click():
    waiting = True
    while waiting:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                return False
            if event.type == pygame.MOUSEBUTTONDOWN:
                return True
        pygame.display.flip()
        pygame.time.Clock().tick(30)
    return False

def play_game(model, game, display=True):
    pygame.init()  # Initialize Pygame
    window = pygame.display.set_mode((game.width, game.height))  # Create the window
    pygame.display.set_caption("Snake Game AI")
    font = pygame.font.SysFont(None, 55)
    
    # Start screen
    window.fill((0, 0, 0))
    draw_text(window, "Click to Start", font, (255, 255, 255), game.width // 2, game.height // 2)
    pygame.display.update()
    if not wait_for_click():
        return
    
    state = game.reset()
    total_reward = 0
    for _ in range(500):
        action = model.act(state)
        next_state, reward, done = game.step(action)
        state = next_state
        total_reward += reward
        if display:
            game.render()
        if done:
            break
        pygame.time.Clock().tick(10)
    print(f"Score: {game.score}, Total Reward: {total_reward}")

def train_until_achieve_score(target_score=10, load_path=None, episode_st=0):
    state_size = 6
    input_dim = 1
    action_size = 4
    batch_size = 32
    n_episodes = 10000

    agent = DQNAgent(input_dim, action_size)
    if load_path:
        agent.model.load_state_dict(torch.load(load_path))
        print(f"Loaded model from {load_path}")

    game = SnakeGameAI()
    episode = episode_st
    start_time = time.time()
    
    scores = []
    episode_durations = []

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    csv_file = "/kaggle/input/model-esentials/training_data.csv"
    if os.path.isfile(csv_file):
        with open(csv_file, mode='r') as file:
            reader = csv.reader(file)
            next(reader)
            for row in reader:
                episode, score, duration = int(row[0]), int(row[1]), float(row[2])
                scores.append(score)
                episode_durations.append(duration)
                episode = max(episode_st, episode)

    else:
        with open(csv_file, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["Episode", "Score", "Episode Time"])

    while True:
        episode += 1
        state = game.reset()
        episode_start = time.time()
        total_reward = 0
        for time_step in range(500):
            action = agent.act(state)
            next_state, reward, done = game.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            if done:
                episode_end = time.time()
                episode_time = episode_end - episode_start
                scores.append(game.score)
                episode_durations.append(episode_time)
                print(f"Episode: {episode}, Score: {game.score}, Episode time: {episode_time:.2f} seconds")
                break
            if len(agent.memory) > batch_size:
                agent.replay(batch_size)

        if episode % 100 == 0:
            torch.save(agent.model.state_dict(), f"/kaggle/working/residual_cnn_snake_model_{episode}.pth")
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Saving after Episode: {episode}, training time since last save: {elapsed_time:.2f} seconds")
            
            with open("/kaggle/working/training_data.csv", mode='a', newline='') as file:
                writer = csv.writer(file)
                for i in range(len(scores)):
                    writer.writerow([episode - (len(scores) - i), scores[i], episode_durations[i]])

        if game.score >= target_score:
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f"Model achieved a score of {target_score} in episode {episode}")
            print(f"Training time: {elapsed_time:.2f} seconds")
            break

        ax1.clear()
        ax1.plot(scores)
        ax1.set_xlabel('Episode')
        ax1.set_ylabel('Total Reward')
        ax1.set_title('Training Progress')

        ax2.clear()
        ax2.plot(episode_durations)
        ax2.set_xlabel('Episode')
        ax2.set_ylabel('Duration (seconds)')
        ax2.set_title('Episode Duration')

        fig.savefig("/kaggle/working/training_progress.png")

    torch.save(agent.model.state_dict(), f"/kaggle/working/residual_cnn_snake_model_final.pth")

# %%
import torch
import pygame

state_size = 6
input_dim = 1
action_size = 4

agent = DQNAgent(input_dim, action_size)
game = SnakeGameAI()

model_path = "rcnn_old/residual_cnn_snake_model_11000.pth"
agent.model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda')))
agent.model.eval()

play_game(agent, game, display=True)

pygame.quit()
# Out:
# Score: 0, Total Reward: 0
